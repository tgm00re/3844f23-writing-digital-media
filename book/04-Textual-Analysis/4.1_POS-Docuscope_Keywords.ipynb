# %% [markdown]
# # 4. Part-of-Speech Tagging &amp; Docuscope's Rhetorical Tagging

# %% [markdown]
# **Goal**: Learn about the textual analysis method called speech tagging.
#
# Speech-tagging methods can help us humans computationally parse, sort, and filter sentences in a large corpus, so we can retroactively also better understand any words of interest in their contexts of use.
#
# We will be working with the English-language `docuscospacy` model in this lesson—a LLM developed by rhetoricians at Carnegie Mellon University. I'd like to thank them for providing users their helpful documentation, which I have modified to use in this lesson.
#
# In this lesson, we are limited to the English language. Yet, feel free to check out Melanie Walsh's and Quinn Dombrowski's curated tutorials to work with other languages:
#
# - [Chinese POS Tagging](Multilingual/Chinese/03-POS-Keywords-Chinese)
# - [Danish POS Tagging](Multilingual/Danish/03-POS-Keywords-Danish)
# - [Portuguese POS Tagging](Multilingual/Portuguese/03-POS-Keywords-Portuguese)
# - [Russian POS Tagging](Multilingual/Russian/03-POS-Keywords-Russian)
# - [Spanish POS Tagging](Multilingual/Spanish/03-POS-Keywords-Spanish)

# %% [markdown]
# ## 4.1 What are Part-of-Speech &amp; DocuScope Tagging?

# %% [markdown]
# ### 4.1.1 Part-of-Speech tagging

# %% [markdown]
# Part-of-speech (POS) tagging, also called grammatical tagging, is the culmination of decades of work and labor to annotate lexicons by their typical syntactical role(s) by manual and probablistic/computational means. (See [Lancaster U's summary](https://ucrel.lancs.ac.uk/annotation.html#POS) of their original process for more information about POS tagging.)
#
# If you have ever diagrammed a sentence, like below, then you have a sense about POS. Note how the parts-of-speech have been tagged in the sentence. Lookup those tags in the [Lancaster's table of POS](https://ucrel.lancs.ac.uk/annotation.html#POS).
#
# <img src="../images/pos-tagging-example.png" alt="">
#
# You may currently feel as though these syntactical relations are very dense to understand and use at first. That's normal! Eventually, with some practice, POS tagging can help you explore and surface interesting language patterns used in a particular context and domain worth reporting.

# %% [markdown]
# ### 4.1.2 DocuScope's *Categorical* Tagging

# %% [markdown]
# In addition to POS tags, Docuscope's creators — David Kaufer, Suguru Ishizaki, and Kerry Ishizaki — have been developing a LLM for over 20 years that tag texts for a variety of experiences a writer can create for readers in a text. Docuscope can detect variations of word tokens, based on its token context. For instance, consider the following variations of rhetorical patterns of "I":
#
# - "I" = self-reference
# - "I know" = self-confidence
# - "I have to do chores today" = self-reluctance
# - "I get to do chores today" = eagerness
#
# As the example above demonstrates, Docuscope's rhetorical approach to language assumes that meaning is isolated better in "streams of words," i.e., co-occurrences, rather than individual words. *In other words*, single words, when accompanied by different words, can be interpreted differently. Take the word "sick" below.
#
# - I'm feeling as sick as a dog. = I am feeling very ill.
# - That was so sick! = I thought something was really cool.
# - I'm sick of talking about AI! = I don't want to talk about AI.
#
# As of 2019, DS's database included 44,000 semantic stream classes and over 70 million unique English language patterns. The result? DocuScope's LLM offers people **categorical tags** to pair with POS tagging.
#
# Categorical tags isolate potential rhetorical patterns within the corpus. To understand what I mean by rhetorical patterns, let's consider DS's categorical tags of `Reasoning` and `Character`. `Reasoning` isolates words or streams of words that are associated with reasoning statements, such as "because," "therefore," "even if," etc., while `Character` isolates multiple dimensions of a person. For example, depending on the word's company, the name "Pauline" might be tagged in relation to work-related characteristics or other domain-specific contextual information.
#
# So, if you decide to filter your corpus by the co-occurence of Reasoning tagged words with Character words, you could analyze the top and bottom relationships between the *who* is represented in the corpus (or not!) and words related to how they *reason*. From there, you can perhaps begin to imagine how you could conduct an EDA to ask questions of the patterns.

# %% [markdown]
# #### How DS tags categories

# %% [markdown]
# According to [DS's creators](https://docuscospacy.readthedocs.io/en/latest/docuscope.html), DS "consists of an enormous lexicon organized into a 3-level taxonomy. An analogue would be the lexicons typically used in sentiment analysis." A sentiment analysis typically cateogrizes words and phrases into either positive or negative sentiments. DS works similarily, but it "organizes its strings into many more categories and is orders of magnitude larger. A typical sentiment lexicon may match 3-5 thousand strings. DocuScope matches 100s of millions."
#
# Let's walk through an example sentence and what categorical tags offer in addition to POS tags:
#
# > Jaws is a shrewd cinematic equation which not only gives you one or two very nasty turns when you least expect them but, possibly more important, knows when to make you think another is coming without actually providing it.
#
# When this sentence is analyzed by the DS, it yields the following table (headers are as follows: `tag`==POS tag, `ent`==Named Entity tag; `ent_type`==DS categorical tag).
#
# Note how in addition to POS tagging, DS categorical tags offer a helpful rhetorical and contextual dimension to the token. DS tags offer numerous other categorical tags:

# %% [markdown]
# ##### *Categorical tag* results from the "Jaws is a shrewd ..." sentence above.

# %% [markdown]
# | **** | **text**  | **tag\_** | **ent\_** | **ent\_type\_**       |
# |------|-----------|-----------|-----------|-----------------------|
# | 0    | Jaws      | NN1       | B         | Character             |
# | 1    | is        | VBZ       | B         | InformationStates     |
# | 2    | a         | AT1       | I         | InformationStates     |
# | 3    | shrewd    | JJ        | B         | Strategic             |
# | 4    | cinematic | JJ        | B         | PublicTerms           |
# | 5    | equation  | NN1       | B         | AcademicTerms         |
# | 6    | which     | DDQ       | B         | SyntacticComplexity   |
# | 7    | not       | XX        | B         | ForceStressed         |
# | 8    | only      | RR        | I         | ForceStressed         |
# | 9    | gives     | VVZ       | B         | Interactive           |
# | 10   | you       | PPY       | I         | Interactive           |
# | 11   | one       | MC1       | O         |                       |
# | 12   | or        | CC        | B         | MetadiscourseCohesive |
# | 13   | two       | MC        | B         | InformationExposition |
# | 14   | very      | RG        | B         | ConfidenceHigh        |
# | 15   | nasty     | JJ        | B         | Negative              |
# | 16   | turns     | NN2       | O         |                       |
# | 17   | when      | RRQ       | B         | Narrative             |
# | 18   | you       | PPY       | I         | Narrative             |
# | 19   | least     | RRT       | B         | InformationExposition |
# | 20   | expect    | VV0       | B         | Future                |
# | 21   | them      | PPHO2     | B         | Narrative             |
# | 22   | but       | CCB       | B         | MetadiscourseCohesive |
# | 23   | ,         | Y         | B         | Contingent            |
# | 24   | possibly  | RR        | I         | Contingent            |
# | 25   | more      | RGR       | B         | InformationExposition |
# | 26   | important | JJ        | I         | InformationExposition |
# | 27   | ,         | Y         | O         |                       |
# | 28   | knows     | VVZ       | B         | ConfidenceHigh        |
# | 29   | when      | RRQ       | I         | ConfidenceHigh        |
# | 30   | to        | TO        | O         |                       |
# | 31   | make      | VVI       | B         | Interactive           |
# | 32   | you       | PPY       | I         | Interactive           |
# | 33   | think     | VVI       | B         | Character             |
# | 34   | another   | DD1       | B         | MetadiscourseCohesive |
# | 35   | is        | VBZ       | B         | InformationStates     |
# | 36   | coming    | VVG       | O         |                       |
# | 37   | without   | IW        | O         |                       |
# | 38   | actually  | RR        | B         | ForceStressed         |
# | 39   | providing | VVG       | B         | Facilitate            |
# | 40   | it        | PPH1      | O         |                       |
# | 41   | \.        | Y         | O         |                       |

# %% [markdown]
# #### Reference Table of DS Categorical Tags

# %% [markdown]
# | **\*\*Category \(Cluster\)\*\*** | **\*\*Description\*\***                                                                                                                                                                                                                                                       | **\*\*Examples\*\***                                                                                |
# |----------------------------------|-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|-----------------------------------------------------------------------------------------------------|
# | **Academic Terms**               | Abstract, rare, specialized, or disciplinary\-specific terms that are indicative of informationally dense writing                                                                                                                                                             | \*market price\*, \*storage capacity\*, \*regulatory\*, \*distribution\*                            |
# | **Academic Writing Moves**       | Phrases and terms that indicate academic writing moves, which are common in research genres and are derived from the work of Swales \(1981\) and Cotos et al\. \(2015, 2017\)                                                                                                 | \*in the first section\*, \*the problem is that\*, \*payment methodology\*, \*point of contention\* |
# | **Character**                    | References multiple dimensions of a character or human being as a social agent, both individual and collective                                                                                                                                                                | \*Pauline\*, \*her\*, \*personnel\*, \*representatives\*                                            |
# | **Citation**                     | Language that indicates the attribution of information to, or citation of, another source\.                                                                                                                                                                                   | \*according to\*, \*is proposing that\*, \*quotes from\*                                            |
# | **Citation Authorized**          | Referencing the citation of another source that is represented as true and not arguable                                                                                                                                                                                       | \*confirm that\*, \*provide evidence\*, \*common sense\*                                            |
# | **Citation Hedged**              | Referencing the citation of another source that is presented as arguable                                                                                                                                                                                                      | \*suggest that\*, \*just one opinion\*                                                              |
# | **Confidence Hedged**            | Referencing language that presents a claim as uncertain                                                                                                                                                                                                                       | \*tends to get\*, \*maybe\*, \*it seems that\*                                                      |
# | **Confidence High**              | Referencing language that presents a claim with certainty                                                                                                                                                                                                                     | \*most likely\*, \*ensure that\*, \*know that\*, \*obviously\*                                      |
# | **Confidence Low**               | Referencing language that presents a claim as extremely unlikely                                                                                                                                                                                                              | \*unlikely\*, \*out of the question\*, \*impossible\*                                               |
# | **Contingent**                   | Referencing contingency, typically contingency in the world, rather than contingency in one's knowledge                                                                                                                                                                       | \*subject to\*, \*if possible\*, \*just in case\*, \*hypothetically\*                               |
# | **Description**                  | Language that evokes sights, sounds, smells, touches and tastes, as well as scenes and objects                                                                                                                                                                                | \*stay quiet\*, \*gas\-fired\*, \*solar panels\*, \*soft\*, \*on my desk\*                          |
# | **Facilitate**                   | Language that enables or directs one through specific tasks and actions                                                                                                                                                                                                       | \*let me\*, \*worth a try\*, \*I would suggest\*                                                    |
# | **First Person**                 | This cluster captures first person\.                                                                                                                                                                                                                                          | \*I\*, \*as soon as I\*, \*we have been\*                                                           |
# | **Force Stressed**               | Language that is forceful and stressed, often using emphatics, comparative forms, or superlative forms                                                                                                                                                                        | \*really good\*, \*the sooner the better\*, \*necessary\*                                           |
# | **Future**                       | Referencing future actions, states, or desires                                                                                                                                                                                                                                | \*will be\*, \*hope to\*, \*expected changes\*                                                      |
# | **Information Change**           | Referencing changes of information, particularly changes that are more neutral                                                                                                                                                                                                | \*changes\*, \*revised\*, \*growth\*, \*modification to\*                                           |
# | **Information Change Negative**  | Referencing negative change\.                                                                                                                                                                                                                                                 | \*going downhill\*, \*slow erosion\*, \*get worse\*                                                 |
# | **Information Change Positive**  | Referencing positive change\.                                                                                                                                                                                                                                                 | \*improving\*, \*accrued interest\*, \*boost morale\*                                               |
# | **Information Exposition**       | Information in the form of expository devices, or language that describes or explains, frequently in regards to quantities and comparisons                                                                                                                                    | \*final amount\*, \*several\*, \*three\*, \*compare\*, \*80%\*                                      |
# | **Information Place**            | Language designating places\.                                                                                                                                                                                                                                                 | \*the city\*, \*surrounding areas\*, \*Houston\*, \*home\*                                          |
# | **Information Report Verbs**     | Informational verbs and verb phrases of reporting\.                                                                                                                                                                                                                           | \*report\*, \*posted\*, \*release\*, \*point out\*                                                  |
# | **Information States**           | Referencing information states, or states of being\.                                                                                                                                                                                                                          | \*is\*, \*are\*, \*existing\*, \*been\*                                                             |
# | **Information Topics**           | Referencing topics, usually nominal subjects or objects, that indicate the “aboutness” of a text                                                                                                                                                                              | \*time\*, \*money\*, \*stock price\*, \*phone interview\*                                           |
# | **Inquiry**                      | Referencing inquiry, or language that points to some kind of inquiry or investigation                                                                                                                                                                                         | \*find out\*, \*let me know if you have any questions\*, \*wondering if\*                           |
# | **Interactive**                  | Addresses from the author to the reader or from persons in the text to other persons\. The address comes in the language of everyday conversation, colloquy, exchange, questions, attention\-getters, feedback, interactive genre markers, and the use of the second person\. | \*can you\*, \*thank you for\*, \*please see\*, \*sounds good to me\*                               |
# | **Metadiscourse Cohesive**       | The use of words to build cohesive markers that help the reader navigate the text and signal linkages in the text, which are often additive or contrastive                                                                                                                    | \*or\*, \*but\*, \*also\*, \*on the other hand\*, \*notwithstanding\*, \*that being said\*          |
# | **Metadiscourse Interactive**    | The use of words to build cohesive markers that interact with the reader                                                                                                                                                                                                      | \*I agree\*, \*let’s talk\*, \*by the way\*                                                         |
# | **Narrative**                    | Language that involves people, description, and events extending in time                                                                                                                                                                                                      | \*today\*, \*tomorrow\*, \*during the\*, \*this weekend\*                                           |
# | **Negative**                     | Referencing dimensions of negativity, including negative acts, emotions, relations, and values                                                                                                                                                                                | \*does not\*, \*sorry for\*, \*problems\*, \*confusion\*                                            |
# | **Positive**                     | Referencing dimensions of positivity, including actions, emotions, relations, and values                                                                                                                                                                                      | \*thanks\*, \*approval\*, \*agreement\*, \*looks good\*                                             |
# | **Public Terms**                 | Referencing public terms, concepts from public language, media, the language of authority, institutions, and responsibility                                                                                                                                                   | \*discussion\*, \*amendment\*, \*corporation\*, \*authority\*, \*settlement\*                       |
# | **Reasoning**                    | Language that has a reasoning focus, supporting inferences about cause, consequence, generalization, concession, and linear inference either from premise to conclusion or conclusion to premise                                                                              | \*because\*, \*therefore\*, \*analysis\*, \*even if\*, \*as a result\*, \*indicating that\*         |
# | **Responsibility**               | Referencing the language of responsibility\.                                                                                                                                                                                                                                  | \*supposed to\*, \*requirements\*, \*obligations\*                                                  |
# | **Strategic**                    | This dimension is active when the text structures strategies activism, advantage\-seeking, game\-playing cognition, plans, and goal\-seeking\.                                                                                                                                | \*plan\*, \*trying to\*, \*strategy\*, \*decision\*, \*coordinate\*, \*look at the\*                |
# | **Syntactic Complexity**         | The features in this category are often what are called “function words,” like determiners and prepositions\.                                                                                                                                                                 | \*the\*, \*to\*, \*for\*, \*in\*, \*a lot of\*                                                      |
# | **Uncertainty**                  | References uncertainty, when confidence levels are unknown\.                                                                                                                                                                                                                  | \*kind of\*, \*I have no idea\*, \*for some reason\*                                                |
# | **Updates**                      | References updates that anticipate someone searching for information and receiving it                                                                                                                                                                                         | \*already\*, \*a new\*, \*now that\*, \*here are some\*                                             |

# %% [markdown]
# ## 4.2 Why is Speech Tagging Useful?

# %% [markdown]
# <img src="https://imgs.xkcd.com/comics/language_nerd.png" alt="I don't mean to go all [Language Nerd](https://xkcd.com/1443/) on you, but parts of speech are important. Even if they seem kind of boring. *Parts of speech* are the grammatical units of language — such as (in English) nouns, verbs, adjectives, adverbs, pronouns, and prepositions. Each of these parts of speech plays a different role in a sentence.">

# %% [markdown]
# By computationally identifying parts of speech, we can start computationally exploring *syntax*, the relationship between words, rather than only focusing on words in isolation, as other analyses perform such as *tf-idf*.
#
# Though parts of speech may seem pedantic, and difficult to apply at first, the POS and DS tags (*LANGUAGE AS DIGITAL DATA!*) help us work with our computational media, i.e., computers, to work toward that ever-elusive abstract noun: *meaning*.
#
# The *xkcd* comic above nicely illustrates how words are not monolithic or static in meaning. Why? Language is a dynamic part of the human experience. Language has a history—a history that feeds into what we do with language right now, which also impacts how words develop into our future. Consequently, syntactical tagging of word relationships - even within the seemingly simple language unit that we call sentences - is difficult. Words can and do shift roles and functions and how they impact social relationships (rhetoric!), because langauge is more than a "bag of words" and their syntactical relationships, e.g. "legit" as *adjective* and *adverb*. We've tangled up language in all aspects of our world.

# %% [markdown]
# ## 4.3 Speech Tagging Lesson

# %% [markdown]
# ### 4.3.1 Install necessary libraries

# %%
# %pip install -U spacy==3.5.0 
# Special modified version of tmtoolkit to work with docuscospacy (I logged the issue with DS, so this works with 0.2.3)
# %pip install pip install https://github.com/lingeringcode/temptmtoolkit/archive/refs/heads/main.zip
# %pip install docuscospacy==0.2.3
# Run the install command for 'json' just in case you don't have it
# %pip install json
# Out:
# Collecting spacy==3.5.0
#   Using cached spacy-3.5.0-cp39-cp39-win_amd64.whl (12.2 MB)
# Requirement already satisfied: packaging>=20.0 in c:\python39\lib\site-packages (from spacy==3.5.0) (23.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\python39\lib\site-packages (from spacy==3.5.0) (2.0.10)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\python39\lib\site-packages (from spacy==3.5.0) (3.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\python39\lib\site-packages (from spacy==3.5.0) (2.0.8)
# Requirement already satisfied: pathy>=0.10.0 in c:\python39\lib\site-packages (from spacy==3.5.0) (0.10.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\python39\lib\site-packages (from spacy==3.5.0) (3.0.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\python39\lib\site-packages (from spacy==3.5.0) (1.1.2)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in c:\python39\lib\site-packages (from spacy==3.5.0) (8.1.12)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\python39\lib\site-packages (from spacy==3.5.0) (3.3.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\python39\lib\site-packages (from spacy==3.5.0) (2.31.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\python39\lib\site-packages (from spacy==3.5.0) (2.4.8)
# Requirement already satisfied: jinja2 in c:\python39\lib\site-packages (from spacy==3.5.0) (3.1.2)
# Requirement already satisfied: setuptools in c:\python39\lib\site-packages (from spacy==3.5.0) (58.1.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\python39\lib\site-packages (from spacy==3.5.0) (1.0.5)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\python39\lib\site-packages (from spacy==3.5.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\python39\lib\site-packages (from spacy==3.5.0) (4.66.1)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in c:\python39\lib\site-packages (from spacy==3.5.0) (0.7.0)
# Requirement already satisfied: numpy>=1.15.0 in c:\python39\lib\site-packages (from spacy==3.5.0) (1.24.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\python39\lib\site-packages (from spacy==3.5.0) (1.0.10)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in c:\python39\lib\site-packages (from spacy==3.5.0) (1.10.13)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\thoma\appdata\roaming\python\python39\site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy==3.5.0) (4.8.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\thoma\appdata\roaming\python\python39\site-packages (from requests<3.0.0,>=2.13.0->spacy==3.5.0) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\python39\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy==3.5.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\python39\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy==3.5.0) (2.0.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\python39\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy==3.5.0) (3.3.1)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\python39\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy==3.5.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\python39\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy==3.5.0) (0.1.3)
# Requirement already satisfied: colorama in c:\users\thoma\appdata\roaming\python\python39\site-packages (from tqdm<5.0.0,>=4.38.0->spacy==3.5.0) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\python39\lib\site-packages (from typer<0.8.0,>=0.3.0->spacy==3.5.0) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\python39\lib\site-packages (from jinja2->spacy==3.5.0) (2.1.3)
# Installing collected packages: spacy
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.7.2
#     Uninstalling spacy-3.7.2:
#       Successfully uninstalled spacy-3.7.2
#   Rolling back uninstall of spacy
#   Moving to c:\python39\lib\site-packages\spacy-3.7.2.dist-info\
#    from C:\Python39\Lib\site-packages\~pacy-3.7.2.dist-info
#   Moving to c:\python39\lib\site-packages\spacy\
#    from C:\Python39\Lib\site-packages\~pacy
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
#     WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
#   WARNING: Failed to write executable - trying to use .deleteme logic
# ERROR: Could not install packages due to an OSError: [WinError 2] The system cannot find the file specified: 'c:\\python39\\Scripts\\spacy.exe' -> 'c:\\python39\\Scripts\\spacy.exe.deleteme'
#
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: You are using pip version 21.2.3; however, version 23.3.1 is available.
# You should consider upgrading via the 'c:\python39\lib\site-packages\python.exe -m pip install --upgrade pip' command.
# Collecting https://github.com/lingeringcode/temptmtoolkit/archive/refs/heads/main.zip
#   Using cached https://github.com/lingeringcode/temptmtoolkit/archive/refs/heads/main.zip
# Requirement already satisfied: pip in c:\python39\lib\site-packages (21.2.3)
# Requirement already satisfied: install in c:\python39\lib\site-packages (1.3.5)
# Requirement already satisfied: numpy>=1.22.0 in c:\python39\lib\site-packages (from temptmtoolkit==0.11.2) (1.24.2)
# Requirement already satisfied: scipy>=1.7.0 in c:\python39\lib\site-packages (from temptmtoolkit==0.11.2) (1.10.1)
# Requirement already satisfied: globre>=0.1.5 in c:\python39\lib\site-packages (from temptmtoolkit==0.11.2) (0.1.5)
# Requirement already satisfied: pandas>=1.4.0 in c:\python39\lib\site-packages (from temptmtoolkit==0.11.2) (2.1.1)
# Requirement already satisfied: xlrd>=2.0.0 in c:\python39\lib\site-packages (from temptmtoolkit==0.11.2) (2.0.1)
# Requirement already satisfied: openpyxl>=3.0.0 in c:\python39\lib\site-packages (from temptmtoolkit==0.11.2) (3.1.2)
# Requirement already satisfied: matplotlib>=3.5.0 in c:\python39\lib\site-packages (from temptmtoolkit==0.11.2) (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\python39\lib\site-packages (from matplotlib>=3.5.0->temptmtoolkit==0.11.2) (1.1.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\python39\lib\site-packages (from matplotlib>=3.5.0->temptmtoolkit==0.11.2) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\python39\lib\site-packages (from matplotlib>=3.5.0->temptmtoolkit==0.11.2) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\python39\lib\site-packages (from matplotlib>=3.5.0->temptmtoolkit==0.11.2) (6.1.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\python39\lib\site-packages (from matplotlib>=3.5.0->temptmtoolkit==0.11.2) (10.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\python39\lib\site-packages (from matplotlib>=3.5.0->temptmtoolkit==0.11.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python39\lib\site-packages (from matplotlib>=3.5.0->temptmtoolkit==0.11.2) (4.43.1)
# Requirement already satisfied: packaging>=20.0 in c:\python39\lib\site-packages (from matplotlib>=3.5.0->temptmtoolkit==0.11.2) (23.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\python39\lib\site-packages (from matplotlib>=3.5.0->temptmtoolkit==0.11.2) (1.4.5)
# Requirement already satisfied: zipp>=3.1.0 in c:\python39\lib\site-packages (from importlib-resources>=3.2.0->matplotlib>=3.5.0->temptmtoolkit==0.11.2) (3.17.0)
# Requirement already satisfied: et-xmlfile in c:\python39\lib\site-packages (from openpyxl>=3.0.0->temptmtoolkit==0.11.2) (1.1.0)
# Requirement already satisfied: tzdata>=2022.1 in c:\python39\lib\site-packages (from pandas>=1.4.0->temptmtoolkit==0.11.2) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in c:\python39\lib\site-packages (from pandas>=1.4.0->temptmtoolkit==0.11.2) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\python39\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.5.0->temptmtoolkit==0.11.2) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: You are using pip version 21.2.3; however, version 23.3.1 is available.
# You should consider upgrading via the 'c:\python39\lib\site-packages\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: docuscospacy==0.2.3 in c:\users\thoma\appdata\roaming\python\python39\site-packages (0.2.3)
# Requirement already satisfied: tmtoolkit>=0.11.0 in c:\users\thoma\appdata\roaming\python\python39\site-packages (from docuscospacy==0.2.3) (0.12.0)
# Requirement already satisfied: spacy>=3.3.0 in c:\python39\lib\site-packages (from docuscospacy==0.2.3) (3.7.2)
# Requirement already satisfied: pandas>=1.4.0 in c:\python39\lib\site-packages (from docuscospacy==0.2.3) (2.1.1)
# Requirement already satisfied: numpy>=1.22.0 in c:\python39\lib\site-packages (from docuscospacy==0.2.3) (1.24.2)
# Requirement already satisfied: loky>=3.0.0 in c:\python39\lib\site-packages (from docuscospacy==0.2.3) (3.4.1)
# Requirement already satisfied: bidict>=0.21.0 in c:\python39\lib\site-packages (from docuscospacy==0.2.3) (0.22.1)
# Requirement already satisfied: cloudpickle in c:\python39\lib\site-packages (from loky>=3.0.0->docuscospacy==0.2.3) (3.0.0)
# Requirement already satisfied: pytz>=2020.1 in c:\python39\lib\site-packages (from pandas>=1.4.0->docuscospacy==0.2.3) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\python39\lib\site-packages (from pandas>=1.4.0->docuscospacy==0.2.3) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\python39\lib\site-packages (from pandas>=1.4.0->docuscospacy==0.2.3) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\python39\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->docuscospacy==0.2.3) (1.16.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\python39\lib\site-packages (from spacy>=3.3.0->docuscospacy==0.2.3) (3.0.9)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\python39\lib\site-packages (from spacy>=3.3.0->docuscospacy==0.2.3) (4.66.1)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\python39\lib\site-packages (from spacy>=3.3.0->docuscospacy==0.2.3) (0.7.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\python39\lib\site-packages (from spacy>=3.3.0->docuscospacy==0.2.3) (1.0.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\python39\lib\site-packages (from spacy>=3.3.0->docuscospacy==0.2.3) (1.1.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\python39\lib\site-packages (from spacy>=3.3.0->docuscospacy==0.2.3) (3.0.12)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\python39\lib\site-packages (from spacy>=3.3.0->docuscospacy==0.2.3) (2.0.10)
# Requirement already satisfied: jinja2 in c:\python39\lib\site-packages (from spacy>=3.3.0->docuscospacy==0.2.3) (3.1.2)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in c:\python39\lib\site-packages (from spacy>=3.3.0->docuscospacy==0.2.3) (8.1.12)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\python39\lib\site-packages (from spacy>=3.3.0->docuscospacy==0.2.3) (0.3.3)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\python39\lib\site-packages (from spacy>=3.3.0->docuscospacy==0.2.3) (6.4.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\python39\lib\site-packages (from spacy>=3.3.0->docuscospacy==0.2.3) (2.0.8)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\python39\lib\site-packages (from spacy>=3.3.0->docuscospacy==0.2.3) (1.0.5)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\python39\lib\site-packages (from spacy>=3.3.0->docuscospacy==0.2.3) (3.3.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\python39\lib\site-packages (from spacy>=3.3.0->docuscospacy==0.2.3) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\python39\lib\site-packages (from spacy>=3.3.0->docuscospacy==0.2.3) (1.10.13)
# Requirement already satisfied: setuptools in c:\python39\lib\site-packages (from spacy>=3.3.0->docuscospacy==0.2.3) (58.1.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\python39\lib\site-packages (from spacy>=3.3.0->docuscospacy==0.2.3) (2.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\python39\lib\site-packages (from spacy>=3.3.0->docuscospacy==0.2.3) (23.2)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\thoma\appdata\roaming\python\python39\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3.3.0->docuscospacy==0.2.3) (4.8.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\python39\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.3.0->docuscospacy==0.2.3) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\python39\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.3.0->docuscospacy==0.2.3) (3.3.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\python39\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.3.0->docuscospacy==0.2.3) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\thoma\appdata\roaming\python\python39\site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.3.0->docuscospacy==0.2.3) (2022.12.7)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\python39\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy>=3.3.0->docuscospacy==0.2.3) (0.1.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\python39\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy>=3.3.0->docuscospacy==0.2.3) (0.7.11)
# Requirement already satisfied: scipy<2.0,>=1.7.0 in c:\python39\lib\site-packages (from tmtoolkit>=0.11.0->docuscospacy==0.2.3) (1.10.1)
# Requirement already satisfied: openpyxl<4.0,>=3.0.0 in c:\python39\lib\site-packages (from tmtoolkit>=0.11.0->docuscospacy==0.2.3) (3.1.2)
# Requirement already satisfied: matplotlib<4.0,>=3.5.0 in c:\python39\lib\site-packages (from tmtoolkit>=0.11.0->docuscospacy==0.2.3) (3.8.0)
# Requirement already satisfied: xlrd>=2.0.0 in c:\python39\lib\site-packages (from tmtoolkit>=0.11.0->docuscospacy==0.2.3) (2.0.1)
# Requirement already satisfied: globre<0.2,>=0.1.5 in c:\python39\lib\site-packages (from tmtoolkit>=0.11.0->docuscospacy==0.2.3) (0.1.5)
# Requirement already satisfied: wheel<1.0,>=0.40 in c:\python39\lib\site-packages (from tmtoolkit>=0.11.0->docuscospacy==0.2.3) (0.41.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python39\lib\site-packages (from matplotlib<4.0,>=3.5.0->tmtoolkit>=0.11.0->docuscospacy==0.2.3) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\python39\lib\site-packages (from matplotlib<4.0,>=3.5.0->tmtoolkit>=0.11.0->docuscospacy==0.2.3) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in c:\python39\lib\site-packages (from matplotlib<4.0,>=3.5.0->tmtoolkit>=0.11.0->docuscospacy==0.2.3) (10.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\python39\lib\site-packages (from matplotlib<4.0,>=3.5.0->tmtoolkit>=0.11.0->docuscospacy==0.2.3) (1.1.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\python39\lib\site-packages (from matplotlib<4.0,>=3.5.0->tmtoolkit>=0.11.0->docuscospacy==0.2.3) (6.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\python39\lib\site-packages (from matplotlib<4.0,>=3.5.0->tmtoolkit>=0.11.0->docuscospacy==0.2.3) (3.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\python39\lib\site-packages (from matplotlib<4.0,>=3.5.0->tmtoolkit>=0.11.0->docuscospacy==0.2.3) (0.12.1)
# Requirement already satisfied: zipp>=3.1.0 in c:\python39\lib\site-packages (from importlib-resources>=3.2.0->matplotlib<4.0,>=3.5.0->tmtoolkit>=0.11.0->docuscospacy==0.2.3) (3.17.0)
# Requirement already satisfied: et-xmlfile in c:\python39\lib\site-packages (from openpyxl<4.0,>=3.0.0->tmtoolkit>=0.11.0->docuscospacy==0.2.3) (1.1.0)
# Requirement already satisfied: colorama in c:\users\thoma\appdata\roaming\python\python39\site-packages (from tqdm<5.0.0,>=4.38.0->spacy>=3.3.0->docuscospacy==0.2.3) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\python39\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy>=3.3.0->docuscospacy==0.2.3) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\python39\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy>=3.3.0->docuscospacy==0.2.3) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\python39\lib\site-packages (from jinja2->spacy>=3.3.0->docuscospacy==0.2.3) (2.1.3)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: You are using pip version 21.2.3; however, version 23.3.1 is available.
# You should consider upgrading via the 'c:\python39\lib\site-packages\python.exe -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# ERROR: Could not find a version that satisfies the requirement json (from versions: none)
# ERROR: No matching distribution found for json
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: You are using pip version 21.2.3; however, version 23.3.1 is available.
# You should consider upgrading via the 'c:\python39\lib\site-packages\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# ### 4.3.2 Import Libraries + EDA

# %%
import sys
sys.path.append("C:\Python39\Lib\site-packages")
import spacy
from spacy import displacy
from temptmtoolkit.corpus import Corpus, vocabulary_size, corpus_num_tokens
import re
from docuscospacy.corpus_analysis import convert_corpus, frequency_table, tags_table, ngrams_table, coll_table, tags_dtm, kwic_center_node, keyness_table
import pandas as pd
import json
import statistics

# %% [markdown]
# #### Quick EDA to understand the data

# %%
##############
## Import Data
##############

# Open/read the sample JSON file
file_adj_corpus = open('../data/04-textual-analysis/kaggle-nb-example/dict_viz_and_adjacent_cells.json', 'r')

# Convert the JSON data into python dict object
dict_adj_corpus = json.load(file_adj_corpus)

# Check the type of the Python object
print(type(dict_adj_corpus))

# Iterate through the dictionary
# And print the key: value pairs
# for key, value in dict_adj_corpus.items():
#   print(f"\nKey: {key}")
#   print(f"Value: {value}\n")

# Close the opened sample JSON file
file_adj_corpus.close()
# Out:
# <class 'dict'>

# %% [markdown]
# #### What is the sum of cells adjacent to visual cells per position?

# %% [markdown]
# **PROVENANCE**: This data comes from Kaggle.com, where data scientists share data and notebooks that analyze it. This set specifically collected notebooks that employ machine-learning techniques with the goal to understand how people used visuals throughout the process. Consequently, the data are organized by two factors:
#
# 1. whether or not a notebook cell is a "code" cell or a "Markdown" cell, and
# 2. whether the cell is positioned before or after a cell that produces a visualization.
#
# Review the summary stats work below to get to know the data some more before we use other more specific `.txt` files that I created from this particular data set.

# %%
####################################################################
# 1. What is the sum of cells adjacent to visual cells per position?
####################################################################
def sum_adj_cells(c):
  md_before_count = 0
  md_after_count = 0
  code_before_count = 0
  code_after_count = 0
  for vcell_key in c:
    if c[vcell_key]['adjacent_before'] != 'None':
      if c[vcell_key]['adjacent_before']['cell_type'] == 'markdown':
        md_before_count = md_before_count + 1
      elif c[vcell_key]['adjacent_before']['cell_type'] == 'code':
        code_before_count = code_before_count + 1
    elif c[vcell_key]['adjacent_after'] != 'None':
      if c[vcell_key]['adjacent_after']['cell_type'] == 'markdown':
        md_after_count = md_after_count + 1
      elif c[vcell_key]['adjacent_after']['cell_type'] == 'code':
        code_after_count = code_after_count + 1

  print(
    'Q1: What is the sum of cells adjacent to visual cells per posiiton?'
    '\n- md_before_count:', md_before_count,
    '\n- md_after_count:', md_after_count,
    '\n- code_before_count:', code_before_count,
    '\n- code_after_count:', code_after_count,
    '\n- TOTAL:', md_before_count+md_after_count+code_before_count+code_after_count
  )

sum_adj_cells(dict_adj_corpus)
# Out:
# Q1: What is the sum of cells adjacent to visual cells per posiiton?
# - md_before_count: 6749
# - md_after_count: 54
# - code_before_count: 3546
# - code_after_count: 53
# - TOTAL: 10402

# %% [markdown]
# #### What positions are visual cells in the notebook?

# %%
##################################################
# 2. What positions are visual cells in the notebook?
##################################################
def describe_viz_cell_positions(c):
  # Overall positioning
  cp_occurrences = 0
  ni_cp_occurrences = 0
  overall_cell_position_sum = 0
  no_import_cell_position_sum = 0
  sum_cells_sum = 0
  overall_position_list = []
  no_import_position_list = []
  sum_of_cells_list = []
  for vcell_key in c:
    # Tally occurrences
    cp_occurrences = cp_occurrences+1
    sum_cells_sum = sum_cells_sum+c[vcell_key]['total_cells_in_nb']

    # List total cells in notebooks
    sum_of_cells_list.append(c[vcell_key]['total_cells_in_nb'])

    overall_cell_position_sum = overall_cell_position_sum + c[vcell_key]['cell_position_in_nb']
    overall_position_list.append(c[vcell_key]['cell_position_in_nb'])

    # Filter out imports
    re_import = r'import\s'
    import_match = re.match(re_import, c[vcell_key]['source'])
    # print(import_match)
    if import_match == None:
      ni_cp_occurrences = ni_cp_occurrences+1
      no_import_cell_position_sum = no_import_cell_position_sum + c[vcell_key]['cell_position_in_nb']
      no_import_position_list.append(c[vcell_key]['cell_position_in_nb'])

  # MEDIAN
  # Sort the lists in ascending order
  overall_position_list = sorted(overall_position_list)
  no_import_position_list = sorted(no_import_position_list)
  sum_of_cells_list = sorted(sum_of_cells_list)

  overall_position_median = statistics.median(overall_position_list)
  no_imports_position_median = statistics.median(no_import_position_list)
  sum_cells_median = statistics.median(sum_of_cells_list)

  # MODE
  # Round numbers in list to whole number
  whole_num_overall_position_list = []
  for op in overall_position_list:
    whole_num_overall_position_list.append(round(op))
  
  whole_num_ni_position_list = []
  for nip in no_import_position_list:
    whole_num_ni_position_list.append(round(nip))
  
  overall_position_mode = statistics.mode(whole_num_overall_position_list)
  no_imports_position_mode = statistics.mode(whole_num_ni_position_list)
  sum_cells_mode = statistics.mode(sum_of_cells_list)

  print(
    '\n\nQ2: What positions are visual cells in the notebook?',
    '\n- OVERALL Avg Mean Cell Position:', overall_cell_position_sum / cp_occurrences,
    '\n- OVERALL Median Cell Position:', overall_position_median,
    '\n- OVERALL Mode Cell Position:', overall_position_mode,
    '\n- NO IMPORTS Avg Mean Cell Position:', no_import_cell_position_sum / ni_cp_occurrences,
    '\n- NO IMPORTS Median Cell Position:', no_imports_position_median,
    '\n- NO IMPORTS Mode Cell Position:', no_imports_position_mode,
    '\n- TOTAL CELLS Avg Mean:', sum_cells_sum / cp_occurrences,
    '\n- TOTAL CELLS Median:', sum_cells_median,
    '\n- TOTAL CELLS Mode:', sum_cells_mode,
    '\n- OVERALL Sum Total Cells:', cp_occurrences,
    '\n- NO IMPORTS Sum Total Cells:', ni_cp_occurrences,
    '\n- IMPORTS ONLY Sum Total Cells:', (ni_cp_occurrences-cp_occurrences),
    '\n'
  )

describe_viz_cell_positions(dict_adj_corpus)
# Out:
# Q2: What positions are visual cells in the notebook?
# - OVERALL Avg Mean Cell Position: 65.78426175765347
# - OVERALL Median Cell Position: 41.009803921568626
# - OVERALL Mode Cell Position: 2
# - NO IMPORTS Avg Mean Cell Position: 68.74707099136471
# - NO IMPORTS Median Cell Position: 43.014084507042256
# - NO IMPORTS Mode Cell Position: 21
# - TOTAL CELLS Avg Mean: 135.87084092434557
# - TOTAL CELLS Median: 99
# - TOTAL CELLS Mode: 827
# - OVERALL Sum Total Cells: 10429
# - NO IMPORTS Sum Total Cells: 9707
# - IMPORTS ONLY Sum Total Cells: -722

# %% [markdown]
# #### Other EDA?

# %% [markdown]
# Feel free to use the pandas dataframes below to do any more EDA, if you'd like. But, the main part of this lesson is to learn more about POS and Categorical tagging.

# %%
# Isolate NON-IMPORT-ADJACENT Markdown Cells
def get_non_import_adj_md_cells(c):
  list__all_cell_content = []
  list__ni_md_before_cell_content = []
  list__ni_md_after_cell_content = []
  for vcell_key in c:
    # Filter out imports
    re_import = r'import\s'
    import_match = re.match(re_import, c[vcell_key]['source'])
    if (import_match == None):
      # Before Vcell
      if c[vcell_key]['adjacent_before'] != 'None' and (c[vcell_key]['adjacent_before']['cell_type'] == 'markdown'):
        list__ni_md_before_cell_content.append(c[vcell_key]['adjacent_before']['source'])
        list__all_cell_content.append(c[vcell_key]['adjacent_before']['source'])
      # After Vcell
      elif c[vcell_key]['adjacent_after'] != 'None' and (c[vcell_key]['adjacent_after']['cell_type'] == 'markdown'):
        list__ni_md_after_cell_content.append(c[vcell_key]['adjacent_after']['source'])
        list__all_cell_content.append(c[vcell_key]['adjacent_after']['source'])

  dict__ni_md_cell_contents = [
    {'all_vcells': list__all_cell_content},
    {'before_vcells': list__ni_md_before_cell_content},
    {'after_vcells': list__ni_md_after_cell_content}
  ]

  return dict__ni_md_cell_contents

# %%
# Remove "Import" cells from samples
dict__ni_adj_corpus = get_non_import_adj_md_cells(dict_adj_corpus)

# Convert dictionaries to dataframes
df__ALL_ni_adj_corpus = pd.DataFrame(dict__ni_adj_corpus[0]['all_vcells']).rename(columns={0:'all_vcells'})
df__BEFORE_ni_adj_corpus = pd.DataFrame(dict__ni_adj_corpus[1]['before_vcells']).rename(columns={0:'before_vcells'})
df__AFTER_ni_adj_corpus = pd.DataFrame(dict__ni_adj_corpus[2]['after_vcells']).rename(columns={0:'after_vcells'})

# %%
# Optional EDA code

# %% [markdown]
# ### 4.3.3 Download LLM

# %% [markdown]
# Ok, now that you know the data a little better than before, we can start our POS and Categorical tags analysis.
#
# First, we need to download DocuScope's LLM: `en_docusco_spacy`. Their (English-only) LLM will process and make predictions about our texts.
#
# - **NOTE**: Another commonly used LLM is spacy's `en_core_web_sm`. This LLM was trained on the annotated "OntoNotes" corpus.
#
# To download and install the `en_docusco_spacy` model,
#
# 1. Execute the cell below: `%pip install en_docusco_spacy`.
# 2. Execute the subsequent cell that uses `spacy` to load the `en_docusco_spacy` model as a variable method.
#
# Now, we can use DS's LLM!

# %%
# %pip install https://huggingface.co/browndw/en_docusco_spacy/resolve/main/en_docusco_spacy-any-py3-none-any.whl
# Out:
# Collecting en-docusco-spacy==any
#   Downloading https://huggingface.co/browndw/en_docusco_spacy/resolve/main/en_docusco_spacy-any-py3-none-any.whl (7.5 MB)
# Collecting spacy<3.6.0,>=3.5.0
#   Downloading spacy-3.5.4-cp39-cp39-win_amd64.whl (12.2 MB)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\python39\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (3.0.12)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\python39\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\python39\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (0.7.0)
# Requirement already satisfied: pathy>=0.10.0 in c:\python39\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (0.10.3)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\python39\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\python39\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (4.66.1)
# Requirement already satisfied: packaging>=20.0 in c:\python39\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (23.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\python39\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (2.0.8)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\python39\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (1.0.10)
# Requirement already satisfied: numpy>=1.15.0 in c:\python39\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (1.24.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\python39\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (3.0.9)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\python39\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (1.1.2)
# Requirement already satisfied: setuptools in c:\python39\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (58.1.0)
# Requirement already satisfied: jinja2 in c:\python39\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (3.1.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\python39\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (3.3.0)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in c:\python39\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (8.1.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\python39\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (1.0.5)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in c:\python39\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (1.10.13)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\python39\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (2.4.8)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\python39\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (2.31.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\thoma\appdata\roaming\python\python39\site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (4.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\python39\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\python39\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\python39\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\thoma\appdata\roaming\python\python39\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (2022.12.7)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\python39\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\python39\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (0.1.3)
# Requirement already satisfied: colorama in c:\users\thoma\appdata\roaming\python\python39\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\python39\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\python39\lib\site-packages (from jinja2->spacy<3.6.0,>=3.5.0->en-docusco-spacy==any) (2.1.3)
# Installing collected packages: spacy
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.7.2
#     Uninstalling spacy-3.7.2:
#       Successfully uninstalled spacy-3.7.2
#   Rolling back uninstall of spacy
#   Moving to c:\python39\lib\site-packages\spacy-3.7.2.dist-info\
#    from C:\Python39\Lib\site-packages\~pacy-3.7.2.dist-info
#   Moving to c:\python39\lib\site-packages\spacy\
#    from C:\Python39\Lib\site-packages\~pacy
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
#     WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
#   WARNING: Failed to write executable - trying to use .deleteme logic
# ERROR: Could not install packages due to an OSError: [WinError 2] The system cannot find the file specified: 'c:\\python39\\Scripts\\spacy.exe' -> 'c:\\python39\\Scripts\\spacy.exe.deleteme'
#
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: You are using pip version 21.2.3; however, version 23.3.1 is available.
# You should consider upgrading via the 'c:\python39\lib\site-packages\python.exe -m pip install --upgrade pip' command.

# %%
nlp = spacy.load('en_docusco_spacy')
# Out:
# c:\python39\lib\site-packages\spacy\util.py:910: UserWarning: [W095] Model 'en_docusco_spacy' (1.3) was trained with spaCy v3.5.0 and may not be 100% compatible with the current version (3.7.2). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)

# %% [markdown]
# ### 4.3.4 Conducting a corpus analysis with docuscopacy

# %% [markdown]
# In this part of the lesson, we will follow the `docuscospacy` package's [documentation tutorial](https://docuscospacy.readthedocs.io/en/latest/corpus_analysis.html).
#
# Using this LLM, we will conduct some of the following actions to conduct a corpus analysis:
#
# - Token frequencies
# - Ngrams
# - Word collocations around a node word
# - Keyword comparisions against a reference corpus
#
# What's great about `docuscospacy` (DS) is how it provides methods by which review the results from the analysis—another form of EDA!
#
# For example, DS can render outputs, such as tables with either POS or DS tags. This will help you differentiate potential moments when a POS like *can* functions as a *noun* vs. *can as verb*. It may prove interesting! Who knows until see what language patterns may be found!
#
# In another example, we'll review how `docuscospacy` conducts and aggregates multi-token sequenced tags, e.g., where *in spite of* is tagged as a token sequence, it is combined into a signle token.
#
# Overall, our goal is to get to know the data and get creative with how we analyze it.

# %% [markdown]
# ### 4.3.5 Load Corpus Data and Pre-Processing the Corpus

# %% [markdown]
# Accurate tagging requires some processing/cleaning of the data. In the function below, we
#
# 1. Make all of the text uniformly lowercase, because remember that computers define every type of character, such as lowercase `k` vs. uppercase `K`.
# 2. Remove any potential HTML tags in this particular corpus.
# 3. Split the possessive `its` into two tokens.
# 4. Removes carriage returns, tabs, extra spaces, etc.

# %%
def pre_process(txt):
    # 1. remove lowercase
    txt=txt.lower()
    # 2. remove HTML tags
    txt=re.sub('</?.*?>','', txt)
    # 3. remove posessives
    txt = re.sub(r'\bits\b', 'it s', txt)
    txt = re.sub(r'\bIts\b', 'It s', txt)
    # Split text into tokens (tokenize it)
    txt = " ".join(txt.split())
    
    return(txt)

# %%
# You may need to change this variable, if you end up using diferent data sets
nlp.max_length = 1300000
# 1300000 for Kaggle's by-position
print(nlp.max_length)
# Out:
# 1300000

# %%
# %%time
corp = Corpus.from_folder(
    # Note how this uses a folder reference, not just a file.
    # It parses txt files divvied up into differently sorted parts of a corpus/es

    # CHOOSE YOUR CORPUS! :-) The lesson starts by using the Kaggle 'by-position' data.
    # Use this data first. Then, for your application, choose another set if you'd like

    '../data/04-textual-analysis/kaggle-nb-example/by-position', 
    # '../data/04-textual-analysis/kaggle-nb-example/by-votes',
    
    # NOTE: For the sake of file sizes and in-memory work, I randomly sampled the Jeopardy questions (10000 per document set)
    # '../data/04-textual-analysis/jeopardy/split', 
    spacy_instance=nlp, # Our loaded LLM
    raw_preproc=[pre_process], # Cleaning function
    spacy_token_attrs=['tag', 'ent_iob', 'ent_type', 'is_punct'] #Run these tagging functions
)
# Out:
# CPU times: total: 41.3 s
# Wall time: 47.4 s

# %% [markdown]
# ### 4.3.6 Basic Summary Stats About Corpus

# %% [markdown]
# It is always a good idea to calcu;ate and review some aggregated information about your corpus. These stats can help you identify potential oddities before you even begin the other work. And, some of the values will be useful later.

# %%
corpus_total = corpus_num_tokens(corp)
corpus_types = vocabulary_size(corp)
total_punct = []
for i in range(0,len(corp)):
    total_punct.append(sum(corp[i]['is_punct']))
total_punct = sum(total_punct)
non_punct = corpus_total - total_punct

print(
    'Aphanumeric tokens:', non_punct, 
    '\nPunctuation tokens:', total_punct, 
    '\nTotal tokens:', corpus_total, 
    '\nToken types:', corpus_types
)
# Out:
# Aphanumeric tokens: 404977
# Punctuation tokens: 102381
# Total tokens: 507358
# Token types: 30347

# %% [markdown]
# ### 4.3.7 Converting the corpus to a DS class object

# %% [markdown]
# Before we generate any tables, we first need to convert the corpus into a convenient object that we can manipulate. From `docuscospacy.corpus_analysis` we will import a number of functions including `convert_corpus`, which takes the object produced by the `Corpus.from_folder` function and converts it into a dictionary, whose keys are the names of the corpus files.

# %%
from docuscospacy.corpus_analysis import convert_corpus, frequency_table, tags_table, ngrams_table, coll_table, tags_dtm, kwic_center_node, keyness_table

# %%
tp = convert_corpus(corp)

# %%
# Listify the keys to review them for accuracy: Did it get all of the desired files?
list(tp.keys())
# Out:
# ['kaggle_FIRST_THIRD_CELLS_notebooks',
#  'kaggle_LAST_THIRD_CELLS_votes_notebooks',
#  'kaggle_SECOND_THIRD_CELLS_votes_notebooks']

# %%
# Listify a file's content in the dictionary by changing the positional values to change the file and tagged tokens in the file
list(tp.values())[1][10:]
# Out:
# [('this ', 'DD1', 'B-Narrative'),
#  ('section', 'NN1', 'B-AcademicTerms'),
#  (', ', 'Y', 'O-'),
#  ('we ', 'PPIS2', 'B-MetadiscourseInteractive'),
#  ('see ', 'VV0', 'I-MetadiscourseInteractive'),
#  ('the ', 'AT', 'B-Reasoning'),
#  ('impact ', 'NN1', 'I-Reasoning'),
#  ('of ', 'IO', 'I-Reasoning'),
#  ('the ', 'AT', 'B-Updates'),
#  ('main ', 'JJ', 'I-Updates'),
#  ('variables ', 'NN2', 'O-'),
#  ('discovered ', 'VVN', 'B-Inquiry'),
#  ('in ', 'II', 'O-'),
#  ('the ', 'AT', 'O-'),
#  ('previous ', 'JJ', 'B-Narrative'),
#  ('sections ', 'NN2', 'B-AcademicTerms'),
#  ('by ', 'II', 'O-'),
#  ('using ', 'VVG', 'O-'),
#  ('the ', 'AT', 'O-'),
#  ('[', 'Y', 'O-'),
#  ('pdpbox](https://pdpbox.readthedocs.io', 'NN2', 'O-'),
#  ('/', 'Y', 'O-'),
#  ('en', 'FW', 'B-Description'),
#  ('/', 'Y', 'O-'),
#  ('latest/', 'NN1', 'O-'),
#  (')', 'Y', 'O-'),
#  ('.', 'Y', 'O-'),
#  ('" ', 'Y', 'O-'),
#  ('\\n', 'FO', 'O-'),
#  ('#', 'Y', 'O-'),
#  ('# ', 'Y', 'O-'),
#  ('5', 'MC', 'B-InformationExposition'),
#  ('-', 'Y', 'O-'),
#  ('6 ', 'MC', 'B-InformationExposition'),
#  ('chart ', 'NN1', 'B-Strategic'),
#  ('analysis\\n1', 'FO', 'O-'),
#  ('. ', 'Y', 'O-'),
#  ('the ', 'AT', 'O-'),
#  ('y ', 'ZZ1', 'O-'),
#  ('axis ', 'NN1', 'B-Description'),
#  ('is ', 'VBZ', 'B-InformationStates'),
#  ('interpreted ', 'VVN', 'I-InformationStates'),
#  ('as ', 'CSA', 'O-'),
#  ('change ', 'NN1', 'B-InformationChange'),
#  ('in ', 'II', 'I-InformationChange'),
#  ('the ', 'AT', 'I-InformationChange'),
#  ('prediction ', 'NN1', 'B-Future'),
#  ('from ', 'II', 'B-Inquiry'),
#  ('what ', 'DDQ', 'I-Inquiry'),
#  ('it ', 'PPH1', 'B-Narrative'),
#  ('would ', 'VM', 'I-Narrative'),
#  ('be ', 'VBI', 'I-Narrative'),
#  ('predicted ', 'VVN', 'B-Future'),
#  ('at ', 'II', 'B-Description'),
#  ('the ', 'AT', 'I-Description'),
#  ('baseline ', 'NN1', 'B-AcademicTerms'),
#  ('or ', 'CC', 'B-MetadiscourseCohesive'),
#  ('leftmost ', 'NN1', 'O-'),
#  ('value.\\n1', 'NP1', 'O-'),
#  ('. ', 'Y', 'O-'),
#  ('a ', 'AT1', 'B-Description'),
#  ('blue ', 'JJ', 'I-Description'),
#  ('shaded ', 'JJ', 'B-Description'),
#  ('area ', 'NN1', 'B-AcademicTerms'),
#  ('indicates ', 'VVZ', 'B-InformationReportVerbs'),
#  ('level ', 'NN1', 'B-AcademicTerms'),
#  ('of ', 'IO', 'I-AcademicTerms'),
#  ('confidence ', 'NN1', 'B-Positive'),
#  ('#', 'Y', 'O-'),
#  ('#', 'Y', 'O-'),
#  ('#', 'Y', 'O-'),
#  ('# ', 'Y', 'O-'),
#  ('residence_type ', 'FO', 'O-'),
#  ('vs ', 'II', 'B-Negative'),
#  ('discrete ', 'JJ', 'B-AcademicTerms'),
#  ('features ', 'NN2', 'I-AcademicTerms'),
#  (': ', 'Y', 'O-'),
#  ('- ', 'Y', 'O-'),
#  ('the ', 'AT', 'B-Description'),
#  ('graphs ', 'NN2', 'I-Description'),
#  ('of ', 'IO', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('rural ', 'JJ', 'B-AcademicTerms'),
#  ('residence_type', 'FO', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('* ', 'Y', 'O-'),
#  ('& ', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('urban ', 'JJ', 'B-AcademicTerms'),
#  ('residence_type', 'NN1', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('* ', 'Y', 'O-'),
#  ('against ', 'II', 'B-Negative'),
#  ('discrete ', 'JJ', 'B-AcademicTerms'),
#  ('features ', 'NN2', 'I-AcademicTerms'),
#  ('w.r.t ', 'NNU', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('stroke', 'NN1', 'B-Description'),
#  ('*', 'Y', 'O-'),
#  ('* ', 'Y', 'O-'),
#  ('are ', 'VBR', 'B-InformationStates'),
#  ('identical.\\n- ', 'NN1', 'O-'),
#  ('they ', 'PPHS2', 'B-ConfidenceHedged'),
#  ('can', 'VM', 'I-ConfidenceHedged'),
#  ('not ', 'XX', 'B-Negative'),
#  ('be ', 'VBI', 'O-'),
#  ('separated ', 'VVN', 'B-Description'),
#  ('from ', 'II', 'I-Description'),
#  ('each ', 'PPX221', 'O-'),
#  ('other', 'PPX222', 'O-'),
#  ('. ', 'Y', 'B-Narrative'),
#  ('they ', 'PPHS2', 'I-Narrative'),
#  ('repeat ', 'VV0', 'B-Narrative'),
#  ('the ', 'AT', 'O-'),
#  ('insights ', 'NN2', 'O-'),
#  ('that ', 'CST', 'O-'),
#  ('have ', 'VH0', 'O-'),
#  ('been ', 'VBN', 'O-'),
#  ('highlighted ', 'VVN', 'O-'),
#  ('uptill ', 'NN1', 'B-Description'),
#  ('now', 'RT', 'B-Narrative'),
#  ('. ', 'Y', 'O-'),
#  ('#', 'Y', 'O-'),
#  ('#', 'Y', 'O-'),
#  ('#', 'Y', 'O-'),
#  ('# ', 'Y', 'O-'),
#  ('smoking_status ', 'NN1', 'O-'),
#  ('vs ', 'II', 'B-Negative'),
#  ('discrete ', 'JJ', 'B-AcademicTerms'),
#  ('features ', 'NN2', 'I-AcademicTerms'),
#  (': ', 'Y', 'O-'),
#  ('"', 'Y', 'O-'),
#  ('- ', 'Y', 'O-'),
#  ('irrespective ', 'II21', 'B-InformationExposition'),
#  ('of ', 'II22', 'I-InformationExposition'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('smoking_status', 'NN1', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  (', ', 'Y', 'O-'),
#  ('people ', 'NN', 'B-Character'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('suffering ', 'NN1', 'B-Negative'),
#  ('from ', 'II', 'I-Negative'),
#  ('stroke', 'NN1', 'B-Description'),
#  ('*', 'Y', 'O-'),
#  ('* ', 'Y', 'O-'),
#  ('have ', 'VH0', 'B-Narrative'),
#  ('been ', 'VBN', 'I-Narrative'),
#  ('detected ', 'VVN', 'B-Inquiry'),
#  ('at ', 'II', 'I-Inquiry'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('age ', 'NN1', 'B-AcademicTerms'),
#  ('around ', 'II', 'O-'),
#  ('60**.\\n- ', 'FO', 'O-'),
#  ('similar ', 'JJ', 'B-MetadiscourseCohesive'),
#  ('to ', 'II', 'I-MetadiscourseCohesive'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('age', 'NN1', 'B-AcademicTerms'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  (', ', 'Y', 'O-'),
#  ('same ', 'DA', 'B-InformationExposition'),
#  ('values ', 'NN2', 'O-'),
#  ('of ', 'IO', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('avg_glucose_level', 'JJ', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('* ', 'Y', 'O-'),
#  ('have ', 'VH0', 'B-AcademicWritingMoves'),
#  ('been ', 'VBN', 'I-AcademicWritingMoves'),
#  ('found ', 'VVN', 'I-AcademicWritingMoves'),
#  ('in ', 'II', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('stroke', 'NN1', 'B-Description'),
#  ('*', 'Y', 'O-'),
#  ('* ', 'Y', 'O-'),
#  ('cases ', 'NN2', 'B-AcademicTerms'),
#  ('irrespective ', 'II21', 'B-InformationExposition'),
#  ('of ', 'II22', 'I-InformationExposition'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('smoking_status**.\\n- ', 'NN1', 'O-'),
#  ('however', 'RR', 'B-MetadiscourseCohesive'),
#  (', ', 'Y', 'O-'),
#  ('because ', 'II21', 'B-Reasoning'),
#  ('of ', 'II22', 'I-Reasoning'),
#  ('the ', 'AT', 'I-Reasoning'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('smoking_status', 'NN1', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  (', ', 'Y', 'O-'),
#  ('range ', 'NN1', 'B-AcademicTerms'),
#  ('of ', 'IO', 'I-AcademicTerms'),
#  ('values ', 'NN2', 'O-'),
#  ('for ', 'IF', 'O-'),
#  ('which ', 'DDQ', 'O-'),
#  ('cases ', 'NN2', 'B-AcademicTerms'),
#  ('of ', 'IO', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('stroke', 'NN1', 'B-Description'),
#  ('*', 'Y', 'O-'),
#  ('* ', 'Y', 'O-'),
#  ('differ', 'NN1', 'B-InformationExposition'),
#  ('. ', 'Y', 'B-InformationExposition'),
#  ('range ', 'NN1', 'I-InformationExposition'),
#  ('of ', 'IO', 'I-InformationExposition'),
#  ('values ', 'NN2', 'O-'),
#  ('of ', 'IO', 'O-'),
#  ('people ', 'NN', 'B-Character'),
#  ('that ', 'CST', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('smokes', 'NN2', 'B-Description'),
#  ('*', 'Y', 'O-'),
#  ('* ', 'Y', 'O-'),
#  ('is ', 'VBZ', 'B-Character'),
#  ('slightly ', 'RR', 'I-Character'),
#  ('higher ', 'JJR', 'B-InformationExposition'),
#  ('than ', 'CSN', 'I-InformationExposition'),
#  ('everyone ', 'PN1', 'B-Character'),
#  ('else', 'RR', 'I-Character'),
#  ('.', 'Y', 'O-'),
#  ('" ', 'Y', 'O-'),
#  ('#', 'Y', 'O-'),
#  ('#', 'Y', 'O-'),
#  ('# ', 'Y', 'O-'),
#  ('discrete ', 'JJ', 'B-AcademicTerms'),
#  ('features ', 'NN2', 'I-AcademicTerms'),
#  ('vs ', 'II', 'B-Negative'),
#  ('discrete ', 'JJ', 'B-AcademicTerms'),
#  ('features ', 'NN2', 'I-AcademicTerms'),
#  ('w.r.t ', 'FU', 'O-'),
#  ('target ', 'NN1', 'B-Strategic'),
#  ('variable ', 'NN1', 'B-InformationChange'),
#  ('(', 'Y', 'O-'),
#  ('stroke', 'NN1', 'B-Description'),
#  (') ', 'Y', 'O-'),
#  (': ', 'Y', 'O-'),
#  ('"', 'Y', 'O-'),
#  ('- ', 'Y', 'O-'),
#  ('due ', 'II21', 'B-Reasoning'),
#  ('to ', 'II22', 'I-Reasoning'),
#  ('the ', 'AT', 'I-Reasoning'),
#  ('imbalance ', 'NN1', 'B-Negative'),
#  ('nature ', 'NN1', 'B-AcademicTerms'),
#  ('of ', 'IO', 'O-'),
#  ('the ', 'AT', 'O-'),
#  ('data', 'NN', 'B-AcademicTerms'),
#  (', ', 'Y', 'O-'),
#  ('cases ', 'NN2', 'B-AcademicTerms'),
#  ('of ', 'IO', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('stroke', 'NN1', 'B-Description'),
#  ('*', 'Y', 'O-'),
#  ('* ', 'Y', 'O-'),
#  ('& ', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('no ', 'AT', 'B-Negative'),
#  ('stroke', 'NN1', 'B-Description'),
#  ('*', 'Y', 'O-'),
#  ('* ', 'Y', 'O-'),
#  ('can', 'VM', 'B-Interactive'),
#  ('not ', 'XX', 'I-Interactive'),
#  ('be ', 'VBI', 'I-Interactive'),
#  ('separated.\\n- ', 'NN1', 'O-'),
#  ('no ', 'AT', 'B-Negative'),
#  ('insights ', 'NN2', 'O-'),
#  ('can ', 'VM', 'B-ConfidenceHedged'),
#  ('be ', 'VBI', 'I-ConfidenceHedged'),
#  ('interpreted ', 'VVN', 'B-Character'),
#  ('from ', 'II', 'O-'),
#  ('the ', 'AT', 'O-'),
#  ('above ', 'JJ', 'O-'),
#  ('graphs', 'NN2', 'B-Description'),
#  ('.', 'Y', 'O-'),
#  ('" ', 'Y', 'O-'),
#  ('"', 'Y', 'O-'),
#  ('- ', 'Y', 'O-'),
#  ('in ', 'BCL21', 'B-Strategic'),
#  ('order ', 'BCL22', 'I-Strategic'),
#  ('to ', 'TO', 'I-Strategic'),
#  ('visualize ', 'VVI', 'I-Strategic'),
#  ('the ', 'AT', 'O-'),
#  ('correlation ', 'NN1', 'B-AcademicTerms'),
#  ('matrix', 'NN1', 'B-AcademicTerms'),
#  (', ', 'Y', 'O-'),
#  ('we ', 'PPIS2', 'O-'),
#  ('create ', 'VV0', 'B-InformationChange'),
#  ('a ', 'AT1', 'I-InformationChange'),
#  ('new ', 'JJ', 'B-Narrative'),
#  ('dataframe ', 'NN1', 'B-Negative'),
#  ('that ', 'CST', 'O-'),
#  ('contains ', 'VVZ', 'B-InformationReportVerbs'),
#  ('values ', 'NN2', 'O-'),
#  ('from ', 'II', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('x_train', 'NN1', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('* ', 'Y', 'O-'),
#  ('& ', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('y_train**.\\n- ', 'NN1', 'O-'),
#  ('thus', 'RR', 'B-Reasoning'),
#  (', ', 'Y', 'O-'),
#  ('we ', 'PPIS2', 'O-'),
#  ('reject ', 'VV0', 'B-Negative'),
#  ('anything ', 'PN1', 'B-InformationExposition'),
#  ('outside ', 'II', 'B-Description'),
#  ('the ', 'AT', 'I-Description'),
#  ('training ', 'NN1', 'B-AcademicWritingMoves'),
#  ('data ', 'NN', 'I-AcademicWritingMoves'),
#  ('to ', 'TO', 'O-'),
#  ('avoid ', 'VVI', 'B-Negative'),
#  ('data ', 'NN', 'B-AcademicTerms'),
#  ('leakage', 'NNU', 'B-Negative'),
#  ('.', 'Y', 'O-'),
#  ('" ', 'Y', 'O-'),
#  ('"', 'Y', 'O-'),
#  ('- ', 'Y', 'O-'),
#  ('clearly', 'RR', 'B-ConfidenceHigh'),
#  (', ', 'Y', 'O-'),
#  ('we ', 'PPIS2', 'B-MetadiscourseInteractive'),
#  ('can ', 'VM', 'I-MetadiscourseInteractive'),
#  ('see ', 'VVI', 'I-MetadiscourseInteractive'),
#  ('the ', 'AT', 'O-'),
#  ('difference ', 'NN1', 'B-InformationExposition'),
#  ('in ', 'II', 'O-'),
#  ('values ', 'NN2', 'O-'),
#  ('between ', 'II', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('data ', 'NN', 'B-AcademicTerms'),
#  ('leakage', 'NN1', 'B-Negative'),
#  ('*', 'Y', 'O-'),
#  ('* ', 'Y', 'O-'),
#  ('& ', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('no ', 'AT', 'B-AcademicWritingMoves'),
#  ('data ', 'NN', 'I-AcademicWritingMoves'),
#  ('leakage**.\\n- ', 'NN1', 'O-'),
#  ('in ', 'II', 'B-InformationExposition'),
#  ('the ', 'AT', 'I-InformationExposition'),
#  ('case ', 'NN1', 'I-InformationExposition'),
#  ('of ', 'IO', 'I-InformationExposition'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('no ', 'AT', 'B-AcademicWritingMoves'),
#  ('data ', 'NN', 'I-AcademicWritingMoves'),
#  ('leakage', 'NN1', 'B-Negative'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  (', ', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('age', 'NN1', 'B-AcademicTerms'),
#  ('*', 'Y', 'O-'),
#  ('* ', 'Y', 'O-'),
#  ('displays ', 'VVZ', 'B-Description'),
#  ('a ', 'AT1', 'B-ForceStressed'),
#  ('strong ', 'JJ', 'I-ForceStressed'),
#  ('positive ', 'JJ', 'O-'),
#  ('correlation ', 'NN1', 'B-AcademicTerms'),
#  ('with ', 'IW', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('stroke', 'NN1', 'B-Description'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('. ', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('avg_glucose_level', 'JJ', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('* ', 'Y', 'O-'),
#  ('& ', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('ever_married', 'FU', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('* ', 'Y', 'O-'),
#  ('display ', 'NN1', 'B-Description'),
#  ('some ', 'DD', 'B-InformationExposition'),
#  ('kind ', 'NN1', 'B-Uncertainty'),
#  ('of ', 'IO', 'I-Uncertainty'),
#  ('positive ', 'JJ', 'O-'),
#  ('correlation', 'NN1', 'B-AcademicTerms'),
#  ('. ', 'Y', 'B-InformationExposition'),
#  ('opposite ', 'JJ', 'I-InformationExposition'),
#  ('to ', 'II', 'O-'),
#  ('positive ', 'JJ', 'O-'),
#  ('correlation', 'NN1', 'B-AcademicTerms'),
#  (', ', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('gender', 'NN1', 'B-AcademicTerms'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  (', ', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('residence_type', 'FO', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('* ', 'Y', 'O-'),
#  ('& ', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('work_type', 'NN1', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('* ', 'Y', 'O-'),
#  ('have ', 'VH0', 'B-InformationStates'),
#  ('negative ', 'JJ', 'B-Negative'),
#  ('correlation ', 'NN1', 'B-AcademicTerms'),
#  ('with ', 'IW', 'O-'),
#  ('the ', 'AT', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('stroke**.\\n- ', 'NN1', 'O-'),
#  ('in ', 'II', 'B-InformationExposition'),
#  ('the ', 'AT', 'I-InformationExposition'),
#  ('case ', 'NN1', 'I-InformationExposition'),
#  ('of ', 'IO', 'I-InformationExposition'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('data ', 'NN', 'B-AcademicTerms'),
#  ('leakage', 'NN1', 'B-Negative'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  (', ', 'Y', 'O-'),
#  ('none ', 'PN', 'O-'),
#  ('of ', 'IO', 'O-'),
#  ('the ', 'AT', 'O-'),
#  ('features ', 'NN2', 'O-'),
#  ('display ', 'VV0', 'B-Description'),
#  ('an ', 'AT1', 'I-Description'),
#  ('extreme ', 'JJ', 'B-ForceStressed'),
#  ('positive ', 'JJ', 'O-'),
#  ('or ', 'CC', 'B-MetadiscourseCohesive'),
#  ('negative ', 'JJ', 'B-Negative'),
#  ('correlation ', 'NN1', 'B-AcademicTerms'),
#  ('with ', 'IW', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('stroke**.\\n- ', 'NN1', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('age', 'NN1', 'B-AcademicTerms'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  (', ', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('heart_disease', 'NN1', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  (', ', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('avg_glucose_level', 'JJ', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  (', ', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('hypertension', 'NN1', 'B-AcademicTerms'),
#  ('*', 'Y', 'O-'),
#  ('* ', 'Y', 'O-'),
#  ('& ', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('ever_married', 'FU', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('* ', 'Y', 'O-'),
#  ('display ', 'NN1', 'B-Description'),
#  ('some ', 'DD', 'B-InformationExposition'),
#  ('kind ', 'NN1', 'B-Uncertainty'),
#  ('of ', 'IO', 'I-Uncertainty'),
#  ('positive ', 'JJ', 'O-'),
#  ('correlation', 'NN1', 'B-AcademicTerms'),
#  ('. ', 'Y', 'B-Reasoning'),
#  ('overall', 'RR', 'I-Reasoning'),
#  (', ', 'Y', 'B-Reasoning'),
#  ('all ', 'DB', 'I-Reasoning'),
#  ('the ', 'AT', 'O-'),
#  ('features ', 'NN2', 'O-'),
#  ('have ', 'VH0', 'B-Strategic'),
#  ('a ', 'AT1', 'I-Strategic'),
#  ('value ', 'NN1', 'O-'),
#  ('very ', 'RG', 'B-ConfidenceHigh'),
#  ('close ', 'JJ', 'B-Description'),
#  ('to ', 'II', 'I-Description'),
#  ('0', 'MC', 'B-InformationExposition'),
#  (', ', 'Y', 'O-'),
#  ('displaying ', 'VVG', 'B-Description'),
#  ('neutral ', 'JJ', 'B-InformationTopics'),
#  ('correlation ', 'NN1', 'B-AcademicTerms'),
#  ('with ', 'IW', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('stroke', 'NN1', 'B-Description'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('.', 'Y', 'O-'),
#  ('" ', 'Y', 'O-'),
#  ('#', 'Y', 'O-'),
#  ('#', 'Y', 'O-'),
#  ('#', 'Y', 'O-'),
#  ('# ', 'Y', 'O-'),
#  ('mutual ', 'JJ', 'B-Positive'),
#  ('information ', 'NN1', 'B-InformationTopics'),
#  ('test ', 'NN1', 'I-InformationTopics'),
#  (': ', 'Y', 'O-'),
#  ('"', 'Y', 'O-'),
#  ('- ', 'Y', 'O-'),
#  ('mutual ', 'JJ', 'B-AcademicTerms'),
#  ('information ', 'NN1', 'I-AcademicTerms'),
#  ('score ', 'NN1', 'B-AcademicTerms'),
#  ('of ', 'IO', 'I-AcademicTerms'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('stroke', 'NN1', 'B-Description'),
#  ('*', 'Y', 'O-'),
#  ('* ', 'Y', 'O-'),
#  ('with ', 'IW', 'O-'),
#  ('categorical ', 'JJ', 'B-AcademicTerms'),
#  ('features ', 'NN2', 'I-AcademicTerms'),
#  ('display ', 'VV0', 'B-Description'),
#  ('very ', 'RG', 'B-ConfidenceHigh'),
#  ('low ', 'JJ', 'B-AcademicTerms'),
#  ('scores ', 'NN2', 'O-'),
#  ('irrespective ', 'II21', 'B-InformationExposition'),
#  ('of ', 'II22', 'I-InformationExposition'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('data ', 'NN', 'B-AcademicTerms'),
#  ('leakage', 'NN1', 'B-Negative'),
#  ('*', 'Y', 'O-'),
#  ('* ', 'Y', 'O-'),
#  ('or ', 'CC', 'B-MetadiscourseCohesive'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('no ', 'AT', 'B-AcademicWritingMoves'),
#  ('data ', 'NN', 'I-AcademicWritingMoves'),
#  ('leakage**.\\n- ', 'NN1', 'O-'),
#  ('according ', 'II21', 'B-Citation'),
#  ('to ', 'II22', 'I-Citation'),
#  ('the ', 'AT', 'I-Citation'),
#  ('above ', 'JJ', 'O-'),
#  ('scores', 'NN2', 'O-'),
#  (', ', 'Y', 'O-'),
#  ('none ', 'PN', 'O-'),
#  ('of ', 'IO', 'O-'),
#  ('the ', 'AT', 'O-'),
#  ('features ', 'NN2', 'O-'),
#  ('should ', 'VM', 'B-Character'),
#  ('be ', 'VBI', 'I-Character'),
#  ('selected ', 'VVN', 'I-Character'),
#  ('for ', 'IF', 'O-'),
#  ('modeling', 'NN1', 'O-'),
#  ('.', 'Y', 'O-'),
#  ('" ', 'Y', 'O-'),
#  ('#', 'Y', 'O-'),
#  ('#', 'Y', 'O-'),
#  ('#', 'Y', 'O-'),
#  ('# ', 'Y', 'O-'),
#  ('chi ', 'FW', 'B-Description'),
#  ('squared ', 'VVN', 'B-InformationTopics'),
#  ('test ', 'NN1', 'I-InformationTopics'),
#  (': ', 'Y', 'O-'),
#  ('"', 'Y', 'O-'),
#  ('- ', 'Y', 'O-'),
#  ('for ', 'IF', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('no ', 'AT', 'B-AcademicWritingMoves'),
#  ('data ', 'NN', 'I-AcademicWritingMoves'),
#  ('leakage', 'NN1', 'B-Negative'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  (', ', 'Y', 'O-'),
#  ('we ', 'PPIS2', 'B-Character'),
#  ('should ', 'VM', 'I-Character'),
#  ('reject ', 'VVI', 'B-Negative'),
#  ('the ', 'AT', 'O-'),
#  ('features ', 'NN2', 'O-'),
#  ('that ', 'CST', 'O-'),
#  ('have ', 'VH0', 'O-'),
#  ('low ', 'JJ', 'B-AcademicTerms'),
#  ('values', 'NN2', 'O-'),
#  ('. ', 'Y', 'O-'),
#  ('we ', 'PPIS2', 'B-FirstPerson'),
#  ('will ', 'VM', 'I-FirstPerson'),
#  ('reject ', 'VVI', 'I-FirstPerson'),
#  ('features ', 'NN2', 'O-'),
#  ('with ', 'IW', 'O-'),
#  ('scores ', 'NN2', 'O-'),
#  ('less ', 'DAR', 'B-InformationExposition'),
#  ('than ', 'CSN', 'I-InformationExposition'),
#  ('20', 'MC', 'B-InformationExposition'),
#  ('. ', 'Y', 'B-Reasoning'),
#  ('hence', 'RR', 'I-Reasoning'),
#  (', ', 'Y', 'O-'),
#  ('we ', 'PPIS2', 'B-FirstPerson'),
#  ('will ', 'VM', 'I-FirstPerson'),
#  ('not ', 'XX', 'I-FirstPerson'),
#  ('use ', 'VVI', 'O-'),
#  (': ', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('smoking_status', 'NN1', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  (', ', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('heart_disease', 'NN1', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('* ', 'Y', 'O-'),
#  ('& ', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('hypertension', 'NN1', 'B-AcademicTerms'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('. ', 'Y', 'B-MetadiscourseCohesive'),
#  ('this ', 'DD1', 'I-MetadiscourseCohesive'),
#  ('does ', 'VDZ', 'B-ForceStressed'),
#  ('contradict ', 'VVI', 'B-Reasoning'),
#  ('with ', 'IW', 'I-Reasoning'),
#  ('the ', 'AT', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('domain ', 'NN1', 'B-AcademicTerms'),
#  ('information**.\\n- ', 'NN1', 'O-'),
#  ('for ', 'IF', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('data ', 'NN', 'B-AcademicTerms'),
#  ('leakage', 'NN1', 'B-Negative'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  (', ', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('heart ', 'NN1', 'B-AcademicTerms'),
#  ('disease', 'NN1', 'I-AcademicTerms'),
#  ('*', 'Y', 'O-'),
#  ('* ', 'Y', 'O-'),
#  ('& ', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('hypertension', 'NN1', 'B-AcademicTerms'),
#  ('*', 'Y', 'O-'),
#  ('* ', 'Y', 'O-'),
#  ('need ', 'NN1', 'B-Character'),
#  ('to ', 'TO', 'I-Character'),
#  ('be ', 'VBI', 'I-Character'),
#  ('selected ', 'VVN', 'B-Character'),
#  ('for ', 'IF', 'O-'),
#  ('modeling ', 'VVG', 'O-'),
#  ('and ', 'CC', 'O-'),
#  ('reject ', 'VVI', 'B-Negative'),
#  ('the ', 'AT', 'B-AcademicTerms'),
#  ('other ', 'JJ', 'I-AcademicTerms'),
#  ('features ', 'NN2', 'I-AcademicTerms'),
#  ('due ', 'II21', 'B-Reasoning'),
#  ('to ', 'II22', 'I-Reasoning'),
#  ('low ', 'JJ', 'B-Negative'),
#  ('chi ', 'NN2', 'I-Negative'),
#  ('squared ', 'VVN', 'O-'),
#  ('score', 'NN1', 'O-'),
#  ('. ', 'Y', 'O-'),
#  ('" ', 'Y', 'O-'),
#  ('#', 'Y', 'O-'),
#  ('#', 'Y', 'O-'),
#  ('#', 'Y', 'O-'),
#  ('# ', 'Y', 'O-'),
#  ('anova ', 'NN1', 'B-InformationTopics'),
#  ('test ', 'NN1', 'I-InformationTopics'),
#  (': ', 'Y', 'O-'),
#  ('"', 'Y', 'O-'),
#  ('- ', 'Y', 'O-'),
#  ('from ', 'II', 'O-'),
#  ('the ', 'AT', 'O-'),
#  ('above ', 'JJ', 'O-'),
#  ('anova ', 'NN1', 'B-AcademicTerms'),
#  ('scores', 'NN2', 'O-'),
#  (', ', 'Y', 'O-'),
#  ('we ', 'PPIS2', 'O-'),
#  ('ignore ', 'VV0', 'B-Negative'),
#  ('the ', 'AT', 'O-'),
#  ('features ', 'NN2', 'O-'),
#  ('with ', 'IW', 'O-'),
#  ('values ', 'NN2', 'O-'),
#  ('less ', 'DAR', 'B-InformationExposition'),
#  ('than ', 'CSN', 'I-InformationExposition'),
#  ('20', 'MC', 'B-InformationExposition'),
#  ('. ', 'Y', 'B-Reasoning'),
#  ('hence', 'RR', 'I-Reasoning'),
#  (', ', 'Y', 'O-'),
#  ('we ', 'PPIS2', 'O-'),
#  ('reject ', 'VV0', 'B-Negative'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('bmi', 'NN1', 'B-Negative'),
#  ('*', 'Y', 'O-'),
#  ('* ', 'Y', 'O-'),
#  ('for ', 'IF', 'O-'),
#  ('modeling ', 'VVG', 'O-'),
#  ('irrespective ', 'II21', 'B-InformationExposition'),
#  ('of ', 'IO', 'I-InformationExposition'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('data ', 'NN', 'B-AcademicTerms'),
#  ('leakage', 'NN1', 'B-Negative'),
#  ('*', 'Y', 'O-'),
#  ('* ', 'Y', 'O-'),
#  ('or ', 'CC', 'B-MetadiscourseCohesive'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('no ', 'AT', 'B-AcademicWritingMoves'),
#  ('data ', 'NN', 'I-AcademicWritingMoves'),
#  ('leakage**.\\n- ', 'VV0', 'O-'),
#  ('we ', 'PPIS2', 'O-'),
#  ('ready ', 'VV0', 'O-'),
#  ('the ', 'AT', 'O-'),
#  ('datasets ', 'NN2', 'B-AcademicTerms'),
#  ('for ', 'IF', 'O-'),
#  ('data ', 'NN', 'B-AcademicTerms'),
#  ('scaling ', 'VVG', 'O-'),
#  ('by ', 'II', 'O-'),
#  ('dropping ', 'VVG', 'O-'),
#  ('the ', 'AT', 'O-'),
#  ('features ', 'NN2', 'O-'),
#  ('based ', 'VVN', 'B-Reasoning'),
#  ('on ', 'II', 'I-Reasoning'),
#  ('the ', 'AT', 'I-Reasoning'),
#  ('above ', 'JJ', 'O-'),
#  ('statistical ', 'JJ', 'B-AcademicTerms'),
#  ('tests.\\n- ', 'NN1', 'O-'),
#  ('we ', 'PPIS2', 'B-FirstPerson'),
#  ('will ', 'VM', 'I-FirstPerson'),
#  ('ignore ', 'VVI', 'B-Negative'),
#  ('the ', 'AT', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('domain ', 'NN1', 'B-AcademicTerms'),
#  ('information', 'NN1', 'B-AcademicTerms'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('!', 'Y', 'B-ForceStressed'),
#  ('" ', 'Y', 'O-'),
#  ('- ', 'Y', 'O-'),
#  ('selecting ', 'VVG', 'B-Character'),
#  ('the ', 'AT', 'I-Character'),
#  ('features ', 'NN2', 'O-'),
#  ('from ', 'II', 'O-'),
#  ('the ', 'AT', 'O-'),
#  ('above ', 'JJ', 'O-'),
#  ('conducted ', 'JJ', 'B-InformationTopics'),
#  ('tests ', 'NN2', 'I-InformationTopics'),
#  ('and ', 'CC', 'O-'),
#  ('splitting ', 'VVG', 'B-Description'),
#  ('the ', 'AT', 'O-'),
#  ('data ', 'NN', 'B-AcademicTerms'),
#  ('into ', 'II', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('85 ', 'MC', 'B-InformationExposition'),
#  ('- ', 'Y', 'O-'),
#  ('15 ', 'MC', 'B-InformationExposition'),
#  ('train ', 'NN1', 'B-InformationTopics'),
#  ('- ', 'Y', 'O-'),
#  ('test', 'VV0', 'B-AcademicTerms'),
#  ('*', 'Y', 'O-'),
#  ('* ', 'Y', 'O-'),
#  ('groups', 'NN2', 'B-InformationTopics'),
#  ('. ', 'Y', 'O-'),
#  ('#', 'Y', 'O-'),
#  ('#', 'Y', 'O-'),
#  ('# ', 'Y', 'O-'),
#  ('1', 'MC', 'B-InformationExposition'),
#  ('] ', 'Y', 'O-'),
#  ('xgboostclassifier ', 'NN1', 'B-AcademicTerms'),
#  (': ', 'Y', 'O-'),
#  ('"', 'Y', 'O-'),
#  ('the ', 'AT', 'O-'),
#  ('confusion ', 'NN1', 'B-Negative'),
#  ('matrix ', 'NN1', 'B-PublicTerms'),
#  ('shows ', 'NN2', 'I-PublicTerms'),
#  ('`', 'Y', 'O-'),
#  ('3289 ', 'MC', 'O-'),
#  ('+ ', 'Y', 'O-'),
#  ('230 ', 'MC', 'B-InformationExposition'),
#  ('= ', 'Y', 'O-'),
#  ('3519 ', 'MC', 'O-'),
#  ('correct ', 'JJ', 'B-Positive'),
#  ('predictions', 'NN2', 'B-Future'),
#  ('` ', 'Y', 'O-'),
#  ('and ', 'CC', 'O-'),
#  ('`', 'Y', 'O-'),
#  ('17 ', 'MC', 'B-InformationExposition'),
#  ('+ ', 'Y', 'O-'),
#  ('44 ', 'MC', 'B-InformationExposition'),
#  ('= ', 'Y', 'O-'),
#  ('61 ', 'MC', 'B-InformationExposition'),
#  ('incorrect ', 'JJ', 'B-Negative'),
#  ('predictions`.\\n\\n\\nin ', 'FO', 'O-'),
#  ('this ', 'DD1', 'B-Narrative'),
#  ('case', 'NN1', 'B-AcademicTerms'),
#  (', ', 'Y', 'O-'),
#  ('we ', 'PPIS2', 'O-'),
#  ('have\\n\\n\\n- ', 'FU', 'O-'),
#  ('`', 'Y', 'O-'),
#  ('true ', 'JJ', 'O-'),
#  ('positives', 'NN2', 'O-'),
#  ('` ', 'Y', 'O-'),
#  ('(', 'Y', 'O-'),
#  ('actual ', 'JJ', 'B-ForceStressed'),
#  ('positive:1 ', 'NN1', 'O-'),
#  ('and ', 'CC', 'O-'),
#  ('predict ', 'VV0', 'B-Future'),
#  ('positive:1', 'NN1', 'O-'),
#  (') ', 'Y', 'O-'),
#  ('- ', 'Y', 'O-'),
#  ('3289\\n\\n\\n- ', 'MC', 'O-'),
#  ('`', 'Y', 'O-'),
#  ('true ', 'JJ', 'O-'),
#  ('negatives', 'NN2', 'B-Negative'),
#  ('` ', 'Y', 'O-'),
#  ('(', 'Y', 'O-'),
#  ('actual ', 'JJ', 'B-ForceStressed'),
#  ('negative:0 ', 'Y', 'O-'),
#  ('and ', 'CC', 'O-'),
#  ('predict ', 'VV0', 'B-Future'),
#  ('negative:0', 'Y', 'O-'),
#  (') ', 'Y', 'O-'),
#  ('- ', 'Y', 'O-'),
#  ('230\\n\\n\\n- ', 'FO', 'O-'),
#  ('`', 'Y', 'O-'),
#  ('false ', 'JJ', 'B-Negative'),
#  ('positives', 'NN2', 'I-Negative'),
#  ('` ', 'Y', 'O-'),
#  ('(', 'Y', 'O-'),
#  ('actual ', 'JJ', 'B-ForceStressed'),
#  ('negative:0 ', 'Y', 'O-'),
#  ('but ', 'CCB', 'B-MetadiscourseCohesive'),
#  ('predict ', 'VV0', 'B-Future'),
#  ('positive:1', 'NN1', 'O-'),
#  (') ', 'Y', 'O-'),
#  ('- ', 'Y', 'O-'),
#  ('17 ', 'MC', 'B-InformationExposition'),
#  ('`', 'Y', 'O-'),
#  ('(', 'Y', 'O-'),
#  ('type ', 'NN1', 'B-InformationTopics'),
#  ('i ', 'ZZ1', 'B-FirstPerson'),
#  ('error)`\\n\\n\\n- ', 'MC', 'O-'),
#  ('`', 'Y', 'O-'),
#  ('false ', 'JJ', 'B-Negative'),
#  ('negatives', 'NN2', 'O-'),
#  ('` ', 'Y', 'O-'),
#  ('(', 'Y', 'O-'),
#  ('actual ', 'JJ', 'B-ForceStressed'),
#  ('positive:1 ', 'NN1', 'O-'),
#  ('but ', 'CCB', 'B-MetadiscourseCohesive'),
#  ('predict ', 'VV0', 'B-Future'),
#  ('negative:0', 'Y', 'O-'),
#  (') ', 'Y', 'O-'),
#  ('- ', 'Y', 'O-'),
#  ('44 ', 'MC', 'B-InformationExposition'),
#  ('`', 'Y', 'O-'),
#  ('(', 'Y', 'O-'),
#  ('type ', 'NN1', 'B-InformationTopics'),
#  ('ii ', 'MC', 'B-AcademicTerms'),
#  ('error', 'NN1', 'B-Negative'),
#  (')', 'Y', 'O-'),
#  ('`', 'Y', 'O-'),
#  ('" ', 'Y', 'O-'),
#  ('# ', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('17', 'MC', 'B-InformationExposition'),
#  ('. ', 'Y', 'O-'),
#  ('classification ', 'NN1', 'B-AcademicTerms'),
#  ('metrices', 'NN2', 'B-Description'),
#  ('*', 'Y', 'O-'),
#  ('* ', 'Y', 'O-'),
#  ('\\n\\n[table ', 'FO', 'O-'),
#  ('of ', 'IO', 'O-'),
#  ('contents](#0.1', 'FO', 'O-'),
#  (') ', 'Y', 'O-'),
#  ('"', 'Y', 'O-'),
#  ('# ', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('18', 'MC', 'B-InformationExposition'),
#  ('. ', 'Y', 'B-Character'),
#  ('roc ', 'NN1', 'I-Character'),
#  ('- ', 'Y', 'O-'),
#  ('auc', 'NN1', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('* ', 'Y', 'O-'),
#  ('\\n\\n[table ', 'FO', 'O-'),
#  ('of ', 'IO', 'O-'),
#  ('contents](#0.1)\\n\\n\\n\\n', 'NP1', 'O-'),
#  ('#', 'Y', 'O-'),
#  ('#', 'Y', 'O-'),
#  ('# ', 'Y', 'O-'),
#  ('roc ', 'NN1', 'B-Description'),
#  ('curve\\n\\n\\nanother ', 'NN1', 'O-'),
#  ('tool ', 'NN1', 'B-Description'),
#  ('to ', 'TO', 'O-'),
#  ('measure ', 'VVI', 'B-InformationReportVerbs'),
#  ('the ', 'AT', 'I-InformationReportVerbs'),
#  ('classification ', 'NN1', 'B-AcademicTerms'),
#  ('model ', 'NN1', 'B-AcademicTerms'),
#  ('performance ', 'NN1', 'B-InformationTopics'),
#  ('visually ', 'RR', 'B-Description'),
#  ('is ', 'VBZ', 'B-InformationStates'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('roc ', 'NN1', 'B-Description'),
#  ('curve', 'NN1', 'B-Description'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('. ', 'Y', 'B-Character'),
#  ('roc ', 'NN1', 'I-Character'),
#  ('curve ', 'NN1', 'B-Description'),
#  ('stands ', 'VVZ', 'O-'),
#  ('for ', 'IF', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('receiver ', 'NN1', 'B-Description'),
#  ('operating ', 'NN1', 'B-InformationTopics'),
#  ('characteristic ', 'JJ', 'I-InformationTopics'),
#  ('curve', 'NN1', 'B-Description'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('. ', 'Y', 'O-'),
#  ('an ', 'AT1', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('roc ', 'NN1', 'B-Description'),
#  ('curve', 'NN1', 'B-Description'),
#  ('*', 'Y', 'O-'),
#  ('* ', 'Y', 'O-'),
#  ('is ', 'VBZ', 'B-InformationStates'),
#  ('a ', 'AT1', 'I-InformationStates'),
#  ('plot ', 'NN1', 'B-AcademicTerms'),
#  ('which ', 'DDQ', 'O-'),
#  ('shows ', 'VVZ', 'O-'),
#  ('the ', 'AT', 'O-'),
#  ('performance ', 'NN1', 'B-InformationTopics'),
#  ('of ', 'IO', 'O-'),
#  ('a ', 'AT1', 'O-'),
#  ('classification ', 'NN1', 'B-AcademicTerms'),
#  ('model ', 'NN1', 'B-AcademicTerms'),
#  ('at ', 'II', 'O-'),
#  ('various ', 'JJ', 'B-InformationTopics'),
#  ('\\nclassification ', 'NN1', 'O-'),
#  ('threshold ', 'NN1', 'B-AcademicTerms'),
#  ('levels', 'NN2', 'B-AcademicTerms'),
#  ('. ', 'Y', 'O-'),
#  ('\\n\\n\\n\\nthe ', 'AT', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('roc ', 'NN1', 'B-Description'),
#  ('curve', 'NN1', 'B-Description'),
#  ('*', 'Y', 'O-'),
#  ('* ', 'Y', 'O-'),
#  ('plots ', 'NN2', 'B-AcademicTerms'),
#  ('the ', 'AT', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('true ', 'JJ', 'O-'),
#  ('positive ', 'JJ', 'B-InformationTopics'),
#  ('rate ', 'NN1', 'I-InformationTopics'),
#  ('(', 'Y', 'O-'),
#  ('tpr', 'NN1', 'B-Description'),
#  (')', 'Y', 'O-'),
#  ('*', 'Y', 'O-'),
#  ('* ', 'Y', 'O-'),
#  ('against ', 'II', 'B-Negative'),
#  ...]

# %% [markdown]
# ### 4.3.8 Generate Frequency Tables

# %% [markdown]
# We can use DS's `frequency_table` function to easily review counts. Here's the description from the API:
#
# <blockquote>
# <h4><a href="https://docuscospacy.readthedocs.io/en/latest/api.html#corpus-analysis-frequency-table-tok-n-tokens-count-by-pos">corpus_analysis.frequency_table(tok, n_tokens, count_by=’pos’)</a></h4>
# <p>Generate a count of token frequencies.</p>
# <div><dl class="field-list simple">
# <dt class="field-odd">Parameters</dt>
# <dd class="field-odd"><ul class="simple">
# <li><p><strong>tok</strong> - A dictionary of tuples as generated by the <cite>convert_corpus</cite> function</p></li>
# <li><p><strong>n_tokens</strong> - A count of total tokens against which to normalize</p></li>
# <li><p><strong>count_by</strong> - One of ‘pos’ or ‘ds’ for aggregating tokens</p></li>
# </ul>
# </dd>
# <dt class="field-even">Return</dt>
# <dd class="field-even"><ul class="simple">
# <li><p>a dataframe of absolute frequencies, normalized frequencies (per million tokens) and ranges</p></li>
# </ul>
# </dd>
# </dl>
# </div>
# </blockquote>
#
# `frequency_table` also [normalizes](https://en.wikipedia.org/wiki/Normalization_(statistics)) the data across the corpus, so that the counts can be compared across the corpi, i.e. compare and contrast the returned absolute frequencies (col `AF`), normalized relative frequencies (per million tokens) (col `RF`), and ranges (col `Range`). token shares a common scale.

# %% [markdown]
# #### 4.3.8.1 POS tables

# %% [markdown]
# In our first frequency table, we will normalize the counts with the non_punct (or the total number of tokens that are not punctuation), because POS token counts omit tokens tagged as punctuation. Later we will count ALLTHETHINGS, since DS includes punctuation.

# %%
freq_table_POS = frequency_table(
    tok=tp, # converted corpus into dict objs
    count_by='pos', # Count by POS tags
    n_tokens=non_punct # norm the corpus by excluding punctuation
)

# %%
freq_table_POS.head(10).style.hide(axis='index').format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_fe9fa">
#   <thead>
#     <tr>
#       <th id="T_fe9fa_level0_col0" class="col_heading level0 col0" >Token</th>
#       <th id="T_fe9fa_level0_col1" class="col_heading level0 col1" >Tag</th>
#       <th id="T_fe9fa_level0_col2" class="col_heading level0 col2" >AF</th>
#       <th id="T_fe9fa_level0_col3" class="col_heading level0 col3" >RF</th>
#       <th id="T_fe9fa_level0_col4" class="col_heading level0 col4" >Range</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_fe9fa_row0_col0" class="data row0 col0" >the</td>
#       <td id="T_fe9fa_row0_col1" class="data row0 col1" >AT</td>
#       <td id="T_fe9fa_row0_col2" class="data row0 col2" >23075</td>
#       <td id="T_fe9fa_row0_col3" class="data row0 col3" >56978.54</td>
#       <td id="T_fe9fa_row0_col4" class="data row0 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_fe9fa_row1_col0" class="data row1 col0" >of</td>
#       <td id="T_fe9fa_row1_col1" class="data row1 col1" >IO</td>
#       <td id="T_fe9fa_row1_col2" class="data row1 col2" >10578</td>
#       <td id="T_fe9fa_row1_col3" class="data row1 col3" >26120.00</td>
#       <td id="T_fe9fa_row1_col4" class="data row1 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_fe9fa_row2_col0" class="data row2 col0" >and</td>
#       <td id="T_fe9fa_row2_col1" class="data row2 col1" >CC</td>
#       <td id="T_fe9fa_row2_col2" class="data row2 col2" >8013</td>
#       <td id="T_fe9fa_row2_col3" class="data row2 col3" >19786.31</td>
#       <td id="T_fe9fa_row2_col4" class="data row2 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_fe9fa_row3_col0" class="data row3 col0" >a</td>
#       <td id="T_fe9fa_row3_col1" class="data row3 col1" >AT1</td>
#       <td id="T_fe9fa_row3_col2" class="data row3 col2" >7445</td>
#       <td id="T_fe9fa_row3_col3" class="data row3 col3" >18383.76</td>
#       <td id="T_fe9fa_row3_col4" class="data row3 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_fe9fa_row4_col0" class="data row4 col0" >is</td>
#       <td id="T_fe9fa_row4_col1" class="data row4 col1" >VBZ</td>
#       <td id="T_fe9fa_row4_col2" class="data row4 col2" >6790</td>
#       <td id="T_fe9fa_row4_col3" class="data row4 col3" >16766.38</td>
#       <td id="T_fe9fa_row4_col4" class="data row4 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_fe9fa_row5_col0" class="data row5 col0" >to</td>
#       <td id="T_fe9fa_row5_col1" class="data row5 col1" >TO</td>
#       <td id="T_fe9fa_row5_col2" class="data row5 col2" >5842</td>
#       <td id="T_fe9fa_row5_col3" class="data row5 col3" >14425.51</td>
#       <td id="T_fe9fa_row5_col4" class="data row5 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_fe9fa_row6_col0" class="data row6 col0" >in</td>
#       <td id="T_fe9fa_row6_col1" class="data row6 col1" >II</td>
#       <td id="T_fe9fa_row6_col2" class="data row6 col2" >5723</td>
#       <td id="T_fe9fa_row6_col3" class="data row6 col3" >14131.67</td>
#       <td id="T_fe9fa_row6_col4" class="data row6 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_fe9fa_row7_col0" class="data row7 col0" >we</td>
#       <td id="T_fe9fa_row7_col1" class="data row7 col1" >PPIS2</td>
#       <td id="T_fe9fa_row7_col2" class="data row7 col2" >4774</td>
#       <td id="T_fe9fa_row7_col3" class="data row7 col3" >11788.32</td>
#       <td id="T_fe9fa_row7_col4" class="data row7 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_fe9fa_row8_col0" class="data row8 col0" >are</td>
#       <td id="T_fe9fa_row8_col1" class="data row8 col1" >VBR</td>
#       <td id="T_fe9fa_row8_col2" class="data row8 col2" >4039</td>
#       <td id="T_fe9fa_row8_col3" class="data row8 col3" >9973.41</td>
#       <td id="T_fe9fa_row8_col4" class="data row8 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_fe9fa_row9_col0" class="data row9 col0" >for</td>
#       <td id="T_fe9fa_row9_col1" class="data row9 col1" >IF</td>
#       <td id="T_fe9fa_row9_col2" class="data row9 col2" >3763</td>
#       <td id="T_fe9fa_row9_col3" class="data row9 col3" >9291.89</td>
#       <td id="T_fe9fa_row9_col4" class="data row9 col4" >100.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Since it's a dataframe, we can filter and sort it easily with the `query()` method. Yay!
#
# Below, we filter for an AF greater than 10 and token tags as verbs (starting with ‘V’).
#
# Refer to the [CLAWS7 POS table](https://ucrel.lancs.ac.uk/claws7tags.html) for desired speech tags to filter against.

# %%
freq_table_POS.query('AF > 10 and Tag.str.startswith("V")').head(10).style.hide(axis='index').format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_35388">
#   <thead>
#     <tr>
#       <th id="T_35388_level0_col0" class="col_heading level0 col0" >Token</th>
#       <th id="T_35388_level0_col1" class="col_heading level0 col1" >Tag</th>
#       <th id="T_35388_level0_col2" class="col_heading level0 col2" >AF</th>
#       <th id="T_35388_level0_col3" class="col_heading level0 col3" >RF</th>
#       <th id="T_35388_level0_col4" class="col_heading level0 col4" >Range</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_35388_row0_col0" class="data row0 col0" >is</td>
#       <td id="T_35388_row0_col1" class="data row0 col1" >VBZ</td>
#       <td id="T_35388_row0_col2" class="data row0 col2" >6790</td>
#       <td id="T_35388_row0_col3" class="data row0 col3" >16766.38</td>
#       <td id="T_35388_row0_col4" class="data row0 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_35388_row1_col0" class="data row1 col0" >are</td>
#       <td id="T_35388_row1_col1" class="data row1 col1" >VBR</td>
#       <td id="T_35388_row1_col2" class="data row1 col2" >4039</td>
#       <td id="T_35388_row1_col3" class="data row1 col3" >9973.41</td>
#       <td id="T_35388_row1_col4" class="data row1 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_35388_row2_col0" class="data row2 col0" >can</td>
#       <td id="T_35388_row2_col1" class="data row2 col1" >VM</td>
#       <td id="T_35388_row2_col2" class="data row2 col2" >2699</td>
#       <td id="T_35388_row2_col3" class="data row2 col3" >6664.58</td>
#       <td id="T_35388_row2_col4" class="data row2 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_35388_row3_col0" class="data row3 col0" >be</td>
#       <td id="T_35388_row3_col1" class="data row3 col1" >VBI</td>
#       <td id="T_35388_row3_col2" class="data row3 col2" >2353</td>
#       <td id="T_35388_row3_col3" class="data row3 col3" >5810.21</td>
#       <td id="T_35388_row3_col4" class="data row3 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_35388_row4_col0" class="data row4 col0" >will</td>
#       <td id="T_35388_row4_col1" class="data row4 col1" >VM</td>
#       <td id="T_35388_row4_col2" class="data row4 col2" >1605</td>
#       <td id="T_35388_row4_col3" class="data row4 col3" >3963.19</td>
#       <td id="T_35388_row4_col4" class="data row4 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_35388_row5_col0" class="data row5 col0" >have</td>
#       <td id="T_35388_row5_col1" class="data row5 col1" >VH0</td>
#       <td id="T_35388_row5_col2" class="data row5 col2" >1558</td>
#       <td id="T_35388_row5_col3" class="data row5 col3" >3847.13</td>
#       <td id="T_35388_row5_col4" class="data row5 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_35388_row6_col0" class="data row6 col0" >see</td>
#       <td id="T_35388_row6_col1" class="data row6 col1" >VVI</td>
#       <td id="T_35388_row6_col2" class="data row6 col2" >1020</td>
#       <td id="T_35388_row6_col3" class="data row6 col3" >2518.66</td>
#       <td id="T_35388_row6_col4" class="data row6 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_35388_row7_col0" class="data row7 col0" >has</td>
#       <td id="T_35388_row7_col1" class="data row7 col1" >VHZ</td>
#       <td id="T_35388_row7_col2" class="data row7 col2" >846</td>
#       <td id="T_35388_row7_col3" class="data row7 col3" >2089.01</td>
#       <td id="T_35388_row7_col4" class="data row7 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_35388_row8_col0" class="data row8 col0" >do</td>
#       <td id="T_35388_row8_col1" class="data row8 col1" >VD0</td>
#       <td id="T_35388_row8_col2" class="data row8 col2" >773</td>
#       <td id="T_35388_row8_col3" class="data row8 col3" >1908.75</td>
#       <td id="T_35388_row8_col4" class="data row8 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_35388_row9_col0" class="data row9 col0" >using</td>
#       <td id="T_35388_row9_col1" class="data row9 col1" >VVG</td>
#       <td id="T_35388_row9_col2" class="data row9 col2" >715</td>
#       <td id="T_35388_row9_col3" class="data row9 col3" >1765.53</td>
#       <td id="T_35388_row9_col4" class="data row9 col4" >100.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Filter for adverbs, yo! How are we modifying those verbs?
freq_table_POS.query('Tag.str.startswith("R")').head(20).style.hide(axis='index').format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_1894d">
#   <thead>
#     <tr>
#       <th id="T_1894d_level0_col0" class="col_heading level0 col0" >Token</th>
#       <th id="T_1894d_level0_col1" class="col_heading level0 col1" >Tag</th>
#       <th id="T_1894d_level0_col2" class="col_heading level0 col2" >AF</th>
#       <th id="T_1894d_level0_col3" class="col_heading level0 col3" >RF</th>
#       <th id="T_1894d_level0_col4" class="col_heading level0 col4" >Range</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_1894d_row0_col0" class="data row0 col0" >also</td>
#       <td id="T_1894d_row0_col1" class="data row0 col1" >RR</td>
#       <td id="T_1894d_row0_col2" class="data row0 col2" >941</td>
#       <td id="T_1894d_row0_col3" class="data row0 col3" >2323.59</td>
#       <td id="T_1894d_row0_col4" class="data row0 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1894d_row1_col0" class="data row1 col0" >very</td>
#       <td id="T_1894d_row1_col1" class="data row1 col1" >RG</td>
#       <td id="T_1894d_row1_col2" class="data row1 col2" >685</td>
#       <td id="T_1894d_row1_col3" class="data row1 col3" >1691.45</td>
#       <td id="T_1894d_row1_col4" class="data row1 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1894d_row2_col0" class="data row2 col0" >most</td>
#       <td id="T_1894d_row2_col1" class="data row2 col1" >RGT</td>
#       <td id="T_1894d_row2_col2" class="data row2 col2" >648</td>
#       <td id="T_1894d_row2_col3" class="data row2 col3" >1600.09</td>
#       <td id="T_1894d_row2_col4" class="data row2 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1894d_row3_col0" class="data row3 col0" >more</td>
#       <td id="T_1894d_row3_col1" class="data row3 col1" >RGR</td>
#       <td id="T_1894d_row3_col2" class="data row3 col2" >566</td>
#       <td id="T_1894d_row3_col3" class="data row3 col3" >1397.61</td>
#       <td id="T_1894d_row3_col4" class="data row3 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1894d_row4_col0" class="data row4 col0" >how</td>
#       <td id="T_1894d_row4_col1" class="data row4 col1" >RRQ</td>
#       <td id="T_1894d_row4_col2" class="data row4 col2" >534</td>
#       <td id="T_1894d_row4_col3" class="data row4 col3" >1318.59</td>
#       <td id="T_1894d_row4_col4" class="data row4 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1894d_row5_col0" class="data row5 col0" >only</td>
#       <td id="T_1894d_row5_col1" class="data row5 col1" >RR</td>
#       <td id="T_1894d_row5_col2" class="data row5 col2" >499</td>
#       <td id="T_1894d_row5_col3" class="data row5 col3" >1232.17</td>
#       <td id="T_1894d_row5_col4" class="data row5 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1894d_row6_col0" class="data row6 col0" >here</td>
#       <td id="T_1894d_row6_col1" class="data row6 col1" >RL</td>
#       <td id="T_1894d_row6_col2" class="data row6 col2" >453</td>
#       <td id="T_1894d_row6_col3" class="data row6 col3" >1118.58</td>
#       <td id="T_1894d_row6_col4" class="data row6 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1894d_row7_col0" class="data row7 col0" >now</td>
#       <td id="T_1894d_row7_col1" class="data row7 col1" >RT</td>
#       <td id="T_1894d_row7_col2" class="data row7 col2" >436</td>
#       <td id="T_1894d_row7_col3" class="data row7 col3" >1076.60</td>
#       <td id="T_1894d_row7_col4" class="data row7 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1894d_row8_col0" class="data row8 col0" >then</td>
#       <td id="T_1894d_row8_col1" class="data row8 col1" >RT</td>
#       <td id="T_1894d_row8_col2" class="data row8 col2" >412</td>
#       <td id="T_1894d_row8_col3" class="data row8 col3" >1017.34</td>
#       <td id="T_1894d_row8_col4" class="data row8 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1894d_row9_col0" class="data row9 col0" >so</td>
#       <td id="T_1894d_row9_col1" class="data row9 col1" >RR</td>
#       <td id="T_1894d_row9_col2" class="data row9 col2" >392</td>
#       <td id="T_1894d_row9_col3" class="data row9 col3" >967.96</td>
#       <td id="T_1894d_row9_col4" class="data row9 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1894d_row10_col0" class="data row10 col0" >just</td>
#       <td id="T_1894d_row10_col1" class="data row10 col1" >RR</td>
#       <td id="T_1894d_row10_col2" class="data row10 col2" >341</td>
#       <td id="T_1894d_row10_col3" class="data row10 col3" >842.02</td>
#       <td id="T_1894d_row10_col4" class="data row10 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1894d_row11_col0" class="data row11 col0" >out</td>
#       <td id="T_1894d_row11_col1" class="data row11 col1" >RP</td>
#       <td id="T_1894d_row11_col2" class="data row11 col2" >333</td>
#       <td id="T_1894d_row11_col3" class="data row11 col3" >822.27</td>
#       <td id="T_1894d_row11_col4" class="data row11 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1894d_row12_col0" class="data row12 col0" >however</td>
#       <td id="T_1894d_row12_col1" class="data row12 col1" >RR</td>
#       <td id="T_1894d_row12_col2" class="data row12 col2" >273</td>
#       <td id="T_1894d_row12_col3" class="data row12 col3" >674.11</td>
#       <td id="T_1894d_row12_col4" class="data row12 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1894d_row13_col0" class="data row13 col0" >how</td>
#       <td id="T_1894d_row13_col1" class="data row13 col1" >RGQ</td>
#       <td id="T_1894d_row13_col2" class="data row13 col2" >248</td>
#       <td id="T_1894d_row13_col3" class="data row13 col3" >612.38</td>
#       <td id="T_1894d_row13_col4" class="data row13 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1894d_row14_col0" class="data row14 col0" >up</td>
#       <td id="T_1894d_row14_col1" class="data row14 col1" >RP</td>
#       <td id="T_1894d_row14_col2" class="data row14 col2" >247</td>
#       <td id="T_1894d_row14_col3" class="data row14 col3" >609.91</td>
#       <td id="T_1894d_row14_col4" class="data row14 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1894d_row15_col0" class="data row15 col0" >much</td>
#       <td id="T_1894d_row15_col1" class="data row15 col1" >RR</td>
#       <td id="T_1894d_row15_col2" class="data row15 col2" >223</td>
#       <td id="T_1894d_row15_col3" class="data row15 col3" >550.65</td>
#       <td id="T_1894d_row15_col4" class="data row15 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1894d_row16_col0" class="data row16 col0" >more</td>
#       <td id="T_1894d_row16_col1" class="data row16 col1" >RRR</td>
#       <td id="T_1894d_row16_col2" class="data row16 col2" >211</td>
#       <td id="T_1894d_row16_col3" class="data row16 col3" >521.02</td>
#       <td id="T_1894d_row16_col4" class="data row16 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1894d_row17_col0" class="data row17 col0" >almost</td>
#       <td id="T_1894d_row17_col1" class="data row17 col1" >RR</td>
#       <td id="T_1894d_row17_col2" class="data row17 col2" >209</td>
#       <td id="T_1894d_row17_col3" class="data row17 col3" >516.08</td>
#       <td id="T_1894d_row17_col4" class="data row17 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1894d_row18_col0" class="data row18 col0" >below</td>
#       <td id="T_1894d_row18_col1" class="data row18 col1" >RL</td>
#       <td id="T_1894d_row18_col2" class="data row18 col2" >208</td>
#       <td id="T_1894d_row18_col3" class="data row18 col3" >513.61</td>
#       <td id="T_1894d_row18_col4" class="data row18 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1894d_row19_col0" class="data row19 col0" >above</td>
#       <td id="T_1894d_row19_col1" class="data row19 col1" >RL</td>
#       <td id="T_1894d_row19_col2" class="data row19 col2" >197</td>
#       <td id="T_1894d_row19_col3" class="data row19 col3" >486.45</td>
#       <td id="T_1894d_row19_col4" class="data row19 col4" >100.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### 4.3.8.2 DS category tables

# %% [markdown]
# Note how we normalize by ‘corpus_total’ as DocuScope includes punctuation in its tagging system.

# %%
freq_table_DS = frequency_table(
    tok=tp, 
    n_tokens=corpus_total, 
    count_by='ds'
)

# %%
freq_table_DS.head(10).style.hide(axis='index').format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_5a264">
#   <thead>
#     <tr>
#       <th id="T_5a264_level0_col0" class="col_heading level0 col0" >Token</th>
#       <th id="T_5a264_level0_col1" class="col_heading level0 col1" >Tag</th>
#       <th id="T_5a264_level0_col2" class="col_heading level0 col2" >AF</th>
#       <th id="T_5a264_level0_col3" class="col_heading level0 col3" >RF</th>
#       <th id="T_5a264_level0_col4" class="col_heading level0 col4" >Range</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5a264_row0_col0" class="data row0 col0" >the</td>
#       <td id="T_5a264_row0_col1" class="data row0 col1" >Untagged</td>
#       <td id="T_5a264_row0_col2" class="data row0 col2" >13647</td>
#       <td id="T_5a264_row0_col3" class="data row0 col3" >26898.17</td>
#       <td id="T_5a264_row0_col4" class="data row0 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_5a264_row1_col0" class="data row1 col0" >and</td>
#       <td id="T_5a264_row1_col1" class="data row1 col1" >Untagged</td>
#       <td id="T_5a264_row1_col2" class="data row1 col2" >7586</td>
#       <td id="T_5a264_row1_col3" class="data row1 col3" >14951.97</td>
#       <td id="T_5a264_row1_col4" class="data row1 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_5a264_row2_col0" class="data row2 col0" >of</td>
#       <td id="T_5a264_row2_col1" class="data row2 col1" >Untagged</td>
#       <td id="T_5a264_row2_col2" class="data row2 col2" >7246</td>
#       <td id="T_5a264_row2_col3" class="data row2 col3" >14281.83</td>
#       <td id="T_5a264_row2_col4" class="data row2 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_5a264_row3_col0" class="data row3 col0" >in</td>
#       <td id="T_5a264_row3_col1" class="data row3 col1" >Untagged</td>
#       <td id="T_5a264_row3_col2" class="data row3 col2" >4014</td>
#       <td id="T_5a264_row3_col3" class="data row3 col3" >7911.57</td>
#       <td id="T_5a264_row3_col4" class="data row3 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_5a264_row4_col0" class="data row4 col0" >a</td>
#       <td id="T_5a264_row4_col1" class="data row4 col1" >Untagged</td>
#       <td id="T_5a264_row4_col2" class="data row4 col2" >3866</td>
#       <td id="T_5a264_row4_col3" class="data row4 col3" >7619.87</td>
#       <td id="T_5a264_row4_col4" class="data row4 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_5a264_row5_col0" class="data row5 col0" >to</td>
#       <td id="T_5a264_row5_col1" class="data row5 col1" >Untagged</td>
#       <td id="T_5a264_row5_col2" class="data row5 col2" >3576</td>
#       <td id="T_5a264_row5_col3" class="data row5 col3" >7048.28</td>
#       <td id="T_5a264_row5_col4" class="data row5 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_5a264_row6_col0" class="data row6 col0" >for</td>
#       <td id="T_5a264_row6_col1" class="data row6 col1" >Untagged</td>
#       <td id="T_5a264_row6_col2" class="data row6 col2" >2958</td>
#       <td id="T_5a264_row6_col3" class="data row6 col3" >5830.20</td>
#       <td id="T_5a264_row6_col4" class="data row6 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_5a264_row7_col0" class="data row7 col0" >that</td>
#       <td id="T_5a264_row7_col1" class="data row7 col1" >Untagged</td>
#       <td id="T_5a264_row7_col2" class="data row7 col2" >2271</td>
#       <td id="T_5a264_row7_col3" class="data row7 col3" >4476.13</td>
#       <td id="T_5a264_row7_col4" class="data row7 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_5a264_row8_col0" class="data row8 col0" >with</td>
#       <td id="T_5a264_row8_col1" class="data row8 col1" >Untagged</td>
#       <td id="T_5a264_row8_col2" class="data row8 col2" >2181</td>
#       <td id="T_5a264_row8_col3" class="data row8 col3" >4298.74</td>
#       <td id="T_5a264_row8_col4" class="data row8 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_5a264_row9_col0" class="data row9 col0" >is</td>
#       <td id="T_5a264_row9_col1" class="data row9 col1" >Information States</td>
#       <td id="T_5a264_row9_col2" class="data row9 col2" >1969</td>
#       <td id="T_5a264_row9_col3" class="data row9 col3" >3880.89</td>
#       <td id="T_5a264_row9_col4" class="data row9 col4" >100.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Let's sort by DS tags!
#
# Review the DS tags in their [user docs](https://docuscospacy.readthedocs.io/en/latest/docuscope.html#categories).

# %%
# By INQUIRY
freq_table_DS.query('Tag.str.startswith("Inquiry")').head(10).style.hide(axis='index').format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_2f5c2">
#   <thead>
#     <tr>
#       <th id="T_2f5c2_level0_col0" class="col_heading level0 col0" >Token</th>
#       <th id="T_2f5c2_level0_col1" class="col_heading level0 col1" >Tag</th>
#       <th id="T_2f5c2_level0_col2" class="col_heading level0 col2" >AF</th>
#       <th id="T_2f5c2_level0_col3" class="col_heading level0 col3" >RF</th>
#       <th id="T_2f5c2_level0_col4" class="col_heading level0 col4" >Range</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_2f5c2_row0_col0" class="data row0 col0" >learning</td>
#       <td id="T_2f5c2_row0_col1" class="data row0 col1" >Inquiry</td>
#       <td id="T_2f5c2_row0_col2" class="data row0 col2" >765</td>
#       <td id="T_2f5c2_row0_col3" class="data row0 col3" >1507.81</td>
#       <td id="T_2f5c2_row0_col4" class="data row0 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_2f5c2_row1_col0" class="data row1 col0" >interesting</td>
#       <td id="T_2f5c2_row1_col1" class="data row1 col1" >Inquiry</td>
#       <td id="T_2f5c2_row1_col2" class="data row1 col2" >197</td>
#       <td id="T_2f5c2_row1_col3" class="data row1 col3" >388.29</td>
#       <td id="T_2f5c2_row1_col4" class="data row1 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_2f5c2_row2_col0" class="data row2 col0" >learn</td>
#       <td id="T_2f5c2_row2_col1" class="data row2 col1" >Inquiry</td>
#       <td id="T_2f5c2_row2_col2" class="data row2 col2" >191</td>
#       <td id="T_2f5c2_row2_col3" class="data row2 col3" >376.46</td>
#       <td id="T_2f5c2_row2_col4" class="data row2 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_2f5c2_row3_col0" class="data row3 col0" >evaluation</td>
#       <td id="T_2f5c2_row3_col1" class="data row3 col1" >Inquiry</td>
#       <td id="T_2f5c2_row3_col2" class="data row3 col2" >78</td>
#       <td id="T_2f5c2_row3_col3" class="data row3 col3" >153.74</td>
#       <td id="T_2f5c2_row3_col4" class="data row3 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_2f5c2_row4_col0" class="data row4 col0" >hypothesis</td>
#       <td id="T_2f5c2_row4_col1" class="data row4 col1" >Inquiry</td>
#       <td id="T_2f5c2_row4_col2" class="data row4 col2" >70</td>
#       <td id="T_2f5c2_row4_col3" class="data row4 col3" >137.97</td>
#       <td id="T_2f5c2_row4_col4" class="data row4 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_2f5c2_row5_col0" class="data row5 col0" >findings</td>
#       <td id="T_2f5c2_row5_col1" class="data row5 col1" >Inquiry</td>
#       <td id="T_2f5c2_row5_col2" class="data row5 col2" >47</td>
#       <td id="T_2f5c2_row5_col3" class="data row5 col3" >92.64</td>
#       <td id="T_2f5c2_row5_col4" class="data row5 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_2f5c2_row6_col0" class="data row6 col0" >to understand</td>
#       <td id="T_2f5c2_row6_col1" class="data row6 col1" >Inquiry</td>
#       <td id="T_2f5c2_row6_col2" class="data row6 col2" >42</td>
#       <td id="T_2f5c2_row6_col3" class="data row6 col3" >82.78</td>
#       <td id="T_2f5c2_row6_col4" class="data row6 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_2f5c2_row7_col0" class="data row7 col0" >find out</td>
#       <td id="T_2f5c2_row7_col1" class="data row7 col1" >Inquiry</td>
#       <td id="T_2f5c2_row7_col2" class="data row7 col2" >40</td>
#       <td id="T_2f5c2_row7_col3" class="data row7 col3" >78.84</td>
#       <td id="T_2f5c2_row7_col4" class="data row7 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_2f5c2_row8_col0" class="data row8 col0" >reviews</td>
#       <td id="T_2f5c2_row8_col1" class="data row8 col1" >Inquiry</td>
#       <td id="T_2f5c2_row8_col2" class="data row8 col2" >39</td>
#       <td id="T_2f5c2_row8_col3" class="data row8 col3" >76.87</td>
#       <td id="T_2f5c2_row8_col4" class="data row8 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_2f5c2_row9_col0" class="data row9 col0" >to learn</td>
#       <td id="T_2f5c2_row9_col1" class="data row9 col1" >Inquiry</td>
#       <td id="T_2f5c2_row9_col2" class="data row9 col2" >38</td>
#       <td id="T_2f5c2_row9_col3" class="data row9 col3" >74.90</td>
#       <td id="T_2f5c2_row9_col4" class="data row9 col4" >100.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
# By INFORMATION TOPICS
freq_table_DS.query('Tag.str.startswith("Information Topics")').head(20).style.hide(axis='index').format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_0c78e">
#   <thead>
#     <tr>
#       <th id="T_0c78e_level0_col0" class="col_heading level0 col0" >Token</th>
#       <th id="T_0c78e_level0_col1" class="col_heading level0 col1" >Tag</th>
#       <th id="T_0c78e_level0_col2" class="col_heading level0 col2" >AF</th>
#       <th id="T_0c78e_level0_col3" class="col_heading level0 col3" >RF</th>
#       <th id="T_0c78e_level0_col4" class="col_heading level0 col4" >Range</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0c78e_row0_col0" class="data row0 col0" >other</td>
#       <td id="T_0c78e_row0_col1" class="data row0 col1" >Information Topics</td>
#       <td id="T_0c78e_row0_col2" class="data row0 col2" >373</td>
#       <td id="T_0c78e_row0_col3" class="data row0 col3" >735.18</td>
#       <td id="T_0c78e_row0_col4" class="data row0 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_0c78e_row1_col0" class="data row1 col0" >data science</td>
#       <td id="T_0c78e_row1_col1" class="data row1 col1" >Information Topics</td>
#       <td id="T_0c78e_row1_col2" class="data row1 col2" >293</td>
#       <td id="T_0c78e_row1_col3" class="data row1 col3" >577.50</td>
#       <td id="T_0c78e_row1_col4" class="data row1 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_0c78e_row2_col0" class="data row2 col0" >non</td>
#       <td id="T_0c78e_row2_col1" class="data row2 col1" >Information Topics</td>
#       <td id="T_0c78e_row2_col2" class="data row2 col2" >264</td>
#       <td id="T_0c78e_row2_col3" class="data row2 col3" >520.34</td>
#       <td id="T_0c78e_row2_col4" class="data row2 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_0c78e_row3_col0" class="data row3 col0" >training</td>
#       <td id="T_0c78e_row3_col1" class="data row3 col1" >Information Topics</td>
#       <td id="T_0c78e_row3_col2" class="data row3 col2" >222</td>
#       <td id="T_0c78e_row3_col3" class="data row3 col3" >437.56</td>
#       <td id="T_0c78e_row3_col4" class="data row3 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_0c78e_row4_col0" class="data row4 col0" >time</td>
#       <td id="T_0c78e_row4_col1" class="data row4 col1" >Information Topics</td>
#       <td id="T_0c78e_row4_col2" class="data row4 col2" >190</td>
#       <td id="T_0c78e_row4_col3" class="data row4 col3" >374.49</td>
#       <td id="T_0c78e_row4_col4" class="data row4 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_0c78e_row5_col0" class="data row5 col0" >job</td>
#       <td id="T_0c78e_row5_col1" class="data row5 col1" >Information Topics</td>
#       <td id="T_0c78e_row5_col2" class="data row5 col2" >177</td>
#       <td id="T_0c78e_row5_col3" class="data row5 col3" >348.87</td>
#       <td id="T_0c78e_row5_col4" class="data row5 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_0c78e_row6_col0" class="data row6 col0" >series</td>
#       <td id="T_0c78e_row6_col1" class="data row6 col1" >Information Topics</td>
#       <td id="T_0c78e_row6_col2" class="data row6 col2" >172</td>
#       <td id="T_0c78e_row6_col3" class="data row6 col3" >339.01</td>
#       <td id="T_0c78e_row6_col4" class="data row6 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_0c78e_row7_col0" class="data row7 col0" >price</td>
#       <td id="T_0c78e_row7_col1" class="data row7 col1" >Information Topics</td>
#       <td id="T_0c78e_row7_col2" class="data row7 col2" >150</td>
#       <td id="T_0c78e_row7_col3" class="data row7 col3" >295.65</td>
#       <td id="T_0c78e_row7_col4" class="data row7 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_0c78e_row8_col0" class="data row8 col0" >group</td>
#       <td id="T_0c78e_row8_col1" class="data row8 col1" >Information Topics</td>
#       <td id="T_0c78e_row8_col2" class="data row8 col2" >147</td>
#       <td id="T_0c78e_row8_col3" class="data row8 col3" >289.74</td>
#       <td id="T_0c78e_row8_col4" class="data row8 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_0c78e_row9_col0" class="data row9 col0" >performance</td>
#       <td id="T_0c78e_row9_col1" class="data row9 col1" >Information Topics</td>
#       <td id="T_0c78e_row9_col2" class="data row9 col2" >141</td>
#       <td id="T_0c78e_row9_col3" class="data row9 col3" >277.91</td>
#       <td id="T_0c78e_row9_col4" class="data row9 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_0c78e_row10_col0" class="data row10 col0" >type</td>
#       <td id="T_0c78e_row10_col1" class="data row10 col1" >Information Topics</td>
#       <td id="T_0c78e_row10_col2" class="data row10 col2" >139</td>
#       <td id="T_0c78e_row10_col3" class="data row10 col3" >273.97</td>
#       <td id="T_0c78e_row10_col4" class="data row10 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_0c78e_row11_col0" class="data row11 col0" >output</td>
#       <td id="T_0c78e_row11_col1" class="data row11 col1" >Information Topics</td>
#       <td id="T_0c78e_row11_col2" class="data row11 col2" >128</td>
#       <td id="T_0c78e_row11_col3" class="data row11 col3" >252.29</td>
#       <td id="T_0c78e_row11_col4" class="data row11 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_0c78e_row12_col0" class="data row12 col0" >sales</td>
#       <td id="T_0c78e_row12_col1" class="data row12 col1" >Information Topics</td>
#       <td id="T_0c78e_row12_col2" class="data row12 col2" >124</td>
#       <td id="T_0c78e_row12_col3" class="data row12 col3" >244.40</td>
#       <td id="T_0c78e_row12_col4" class="data row12 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_0c78e_row13_col0" class="data row13 col0" >online</td>
#       <td id="T_0c78e_row13_col1" class="data row13 col1" >Information Topics</td>
#       <td id="T_0c78e_row13_col2" class="data row13 col2" >120</td>
#       <td id="T_0c78e_row13_col3" class="data row13 col3" >236.52</td>
#       <td id="T_0c78e_row13_col4" class="data row13 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_0c78e_row14_col0" class="data row14 col0" >sample</td>
#       <td id="T_0c78e_row14_col1" class="data row14 col1" >Information Topics</td>
#       <td id="T_0c78e_row14_col2" class="data row14 col2" >117</td>
#       <td id="T_0c78e_row14_col3" class="data row14 col3" >230.61</td>
#       <td id="T_0c78e_row14_col4" class="data row14 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_0c78e_row15_col0" class="data row15 col0" >various</td>
#       <td id="T_0c78e_row15_col1" class="data row15 col1" >Information Topics</td>
#       <td id="T_0c78e_row15_col2" class="data row15 col2" >110</td>
#       <td id="T_0c78e_row15_col3" class="data row15 col3" >216.81</td>
#       <td id="T_0c78e_row15_col4" class="data row15 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_0c78e_row16_col0" class="data row16 col0" >space</td>
#       <td id="T_0c78e_row16_col1" class="data row16 col1" >Information Topics</td>
#       <td id="T_0c78e_row16_col2" class="data row16 col2" >100</td>
#       <td id="T_0c78e_row16_col3" class="data row16 col3" >197.10</td>
#       <td id="T_0c78e_row16_col4" class="data row16 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_0c78e_row17_col0" class="data row17 col0" >color</td>
#       <td id="T_0c78e_row17_col1" class="data row17 col1" >Information Topics</td>
#       <td id="T_0c78e_row17_col2" class="data row17 col2" >95</td>
#       <td id="T_0c78e_row17_col3" class="data row17 col3" >187.24</td>
#       <td id="T_0c78e_row17_col4" class="data row17 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_0c78e_row18_col0" class="data row18 col0" >survival rate</td>
#       <td id="T_0c78e_row18_col1" class="data row18 col1" >Information Topics</td>
#       <td id="T_0c78e_row18_col2" class="data row18 col2" >93</td>
#       <td id="T_0c78e_row18_col3" class="data row18 col3" >183.30</td>
#       <td id="T_0c78e_row18_col4" class="data row18 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_0c78e_row19_col0" class="data row19 col0" >company</td>
#       <td id="T_0c78e_row19_col1" class="data row19 col1" >Information Topics</td>
#       <td id="T_0c78e_row19_col2" class="data row19 col2" >91</td>
#       <td id="T_0c78e_row19_col3" class="data row19 col3" >179.36</td>
#       <td id="T_0c78e_row19

# %%
# By INFORMATION REPORT VERBS
freq_table_DS.query('Tag.str.startswith("Information Report Verbs")').head(20).style.hide(axis='index').format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_c98f7">
#   <thead>
#     <tr>
#       <th id="T_c98f7_level0_col0" class="col_heading level0 col0" >Token</th>
#       <th id="T_c98f7_level0_col1" class="col_heading level0 col1" >Tag</th>
#       <th id="T_c98f7_level0_col2" class="col_heading level0 col2" >AF</th>
#       <th id="T_c98f7_level0_col3" class="col_heading level0 col3" >RF</th>
#       <th id="T_c98f7_level0_col4" class="col_heading level0 col4" >Range</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c98f7_row0_col0" class="data row0 col0" >make</td>
#       <td id="T_c98f7_row0_col1" class="data row0 col1" >Information Report Verbs</td>
#       <td id="T_c98f7_row0_col2" class="data row0 col2" >190</td>
#       <td id="T_c98f7_row0_col3" class="data row0 col3" >374.49</td>
#       <td id="T_c98f7_row0_col4" class="data row0 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_c98f7_row1_col0" class="data row1 col0" >experience</td>
#       <td id="T_c98f7_row1_col1" class="data row1 col1" >Information Report Verbs</td>
#       <td id="T_c98f7_row1_col2" class="data row1 col2" >166</td>
#       <td id="T_c98f7_row1_col3" class="data row1 col3" >327.19</td>
#       <td id="T_c98f7_row1_col4" class="data row1 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_c98f7_row2_col0" class="data row2 col0" >made</td>
#       <td id="T_c98f7_row2_col1" class="data row2 col1" >Information Report Verbs</td>
#       <td id="T_c98f7_row2_col2" class="data row2 col2" >99</td>
#       <td id="T_c98f7_row2_col3" class="data row2 col3" >195.13</td>
#       <td id="T_c98f7_row2_col4" class="data row2 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_c98f7_row3_col0" class="data row3 col0" >create</td>
#       <td id="T_c98f7_row3_col1" class="data row3 col1" >Information Report Verbs</td>
#       <td id="T_c98f7_row3_col2" class="data row3 col2" >90</td>
#       <td id="T_c98f7_row3_col3" class="data row3 col3" >177.39</td>
#       <td id="T_c98f7_row3_col4" class="data row3 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_c98f7_row4_col0" class="data row4 col0" >build</td>
#       <td id="T_c98f7_row4_col1" class="data row4 col1" >Information Report Verbs</td>
#       <td id="T_c98f7_row4_col2" class="data row4 col2" >81</td>
#       <td id="T_c98f7_row4_col3" class="data row4 col3" >159.65</td>
#       <td id="T_c98f7_row4_col4" class="data row4 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_c98f7_row5_col0" class="data row5 col0" >generated</td>
#       <td id="T_c98f7_row5_col1" class="data row5 col1" >Information Report Verbs</td>
#       <td id="T_c98f7_row5_col2" class="data row5 col2" >80</td>
#       <td id="T_c98f7_row5_col3" class="data row5 col3" >157.68</td>
#       <td id="T_c98f7_row5_col4" class="data row5 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_c98f7_row6_col0" class="data row6 col0" >building</td>
#       <td id="T_c98f7_row6_col1" class="data row6 col1" >Information Report Verbs</td>
#       <td id="T_c98f7_row6_col2" class="data row6 col2" >76</td>
#       <td id="T_c98f7_row6_col3" class="data row6 col3" >149.80</td>
#       <td id="T_c98f7_row6_col4" class="data row6 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_c98f7_row7_col0" class="data row7 col0" >created</td>
#       <td id="T_c98f7_row7_col1" class="data row7 col1" >Information Report Verbs</td>
#       <td id="T_c98f7_row7_col2" class="data row7 col2" >75</td>
#       <td id="T_c98f7_row7_col3" class="data row7 col3" >147.82</td>
#       <td id="T_c98f7_row7_col4" class="data row7 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_c98f7_row8_col0" class="data row8 col0" >contains</td>
#       <td id="T_c98f7_row8_col1" class="data row8 col1" >Information Report Verbs</td>
#       <td id="T_c98f7_row8_col2" class="data row8 col2" >70</td>
#       <td id="T_c98f7_row8_col3" class="data row8 col3" >137.97</td>
#       <td id="T_c98f7_row8_col4" class="data row8 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_c98f7_row9_col0" class="data row9 col0" >making</td>
#       <td id="T_c98f7_row9_col1" class="data row9 col1" >Information Report Verbs</td>
#       <td id="T_c98f7_row9_col2" class="data row9 col2" >70</td>
#       <td id="T_c98f7_row9_col3" class="data row9 col3" >137.97</td>
#       <td id="T_c98f7_row9_col4" class="data row9 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_c98f7_row10_col0" class="data row10 col0" >remove</td>
#       <td id="T_c98f7_row10_col1" class="data row10 col1" >Information Report Verbs</td>
#       <td id="T_c98f7_row10_col2" class="data row10 col2" >65</td>
#       <td id="T_c98f7_row10_col3" class="data row10 col3" >128.11</td>
#       <td id="T_c98f7_row10_col4" class="data row10 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_c98f7_row11_col0" class="data row11 col0" >include</td>
#       <td id="T_c98f7_row11_col1" class="data row11 col1" >Information Report Verbs</td>
#       <td id="T_c98f7_row11_col2" class="data row11 col2" >64</td>
#       <td id="T_c98f7_row11_col3" class="data row11 col3" >126.14</td>
#       <td id="T_c98f7_row11_col4" class="data row11 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_c98f7_row12_col0" class="data row12 col0" >observe</td>
#       <td id="T_c98f7_row12_col1" class="data row12 col1" >Information Report Verbs</td>
#       <td id="T_c98f7_row12_col2" class="data row12 col2" >61</td>
#       <td id="T_c98f7_row12_col3" class="data row12 col3" >120.23</td>
#       <td id="T_c98f7_row12_col4" class="data row12 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_c98f7_row13_col0" class="data row13 col0" >makes</td>
#       <td id="T_c98f7_row13_col1" class="data row13 col1" >Information Report Verbs</td>
#       <td id="T_c98f7_row13_col2" class="data row13 col2" >54</td>
#       <td id="T_c98f7_row13_col3" class="data row13 col3" >106.43</td>
#       <td id="T_c98f7_row13_col4" class="data row13 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_c98f7_row14_col0" class="data row14 col0" >indicates</td>
#       <td id="T_c98f7_row14_col1" class="data row14 col1" >Information Report Verbs</td>
#       <td id="T_c98f7_row14_col2" class="data row14 col2" >50</td>
#       <td id="T_c98f7_row14_col3" class="data row14 col3" >98.55</td>
#       <td id="T_c98f7_row14_col4" class="data row14 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_c98f7_row15_col0" class="data row15 col0" >generate</td>
#       <td id="T_c98f7_row15_col1" class="data row15 col1" >Information Report Verbs</td>
#       <td id="T_c98f7_row15_col2" class="data row15 col2" >48</td>
#       <td id="T_c98f7_row15_col3" class="data row15 col3" >94.61</td>
#       <td id="T_c98f7_row15_col4" class="data row15 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_c98f7_row16_col0" class="data row16 col0" >built</td>
#       <td id="T_c98f7_row16_col1" class="data row16 col1" >Information Report Verbs</td>
#       <td id="T_c98f7_row16_col2" class="data row16 col2" >46</td>
#       <td id="T_c98f7_row16_col3" class="data row16 col3" >90.67</td>
#       <td id="T_c98f7_row16_col4" class="data row16 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_c98f7_row17_col0" class="data row17 col0" >depending on</td>
#       <td id="T_c98f7_row17_col1" class="data row17 col1" >Information Report Verbs</td>
#       <td id="T_c98f7_row17_col2" class="data row17 col2" >46</td>
#       <td id="T_c98f7_row17_col3" class="data row17 col3" >90.67</td>
#       <td id="T_c98f7_row17_col4" class="data row17 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_c98f7_row18_col0" class="data row18 col0" >observed</td>
#       <td id="T_c98f7_row18_col1" class="data row18 col1" >Information Report Verbs</td>
#       <td id="T_c98f7_row18_col2" class="data row18 col2" >43</td>
#       <td id="T_c98f7_row18_col3" class="data row18 col3" >84.75</td>
#       <td id="T_c98f7_row18_col4" class="data row18 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_c98f7_row19_col0" class="data row19 col0" >creating</td>
#       <td id="T_c98f7_row19_col1" class="data row19 col1" >Information Report Verbs</td>
#       <td id="T_c98f7_row19_col2" class="data row

# %%
# By INFORMATION CHANGE
freq_table_DS.query('Tag.str.startswith("Information Change")').head(10).style.hide(axis='index').format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_4aedc">
#   <thead>
#     <tr>
#       <th id="T_4aedc_level0_col0" class="col_heading level0 col0" >Token</th>
#       <th id="T_4aedc_level0_col1" class="col_heading level0 col1" >Tag</th>
#       <th id="T_4aedc_level0_col2" class="col_heading level0 col2" >AF</th>
#       <th id="T_4aedc_level0_col3" class="col_heading level0 col3" >RF</th>
#       <th id="T_4aedc_level0_col4" class="col_heading level0 col4" >Range</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4aedc_row0_col0" class="data row0 col0" >variable</td>
#       <td id="T_4aedc_row0_col1" class="data row0 col1" >Information Change</td>
#       <td id="T_4aedc_row0_col2" class="data row0 col2" >302</td>
#       <td id="T_4aedc_row0_col3" class="data row0 col3" >595.24</td>
#       <td id="T_4aedc_row0_col4" class="data row0 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_4aedc_row1_col0" class="data row1 col0" >variables</td>
#       <td id="T_4aedc_row1_col1" class="data row1 col1" >Information Change</td>
#       <td id="T_4aedc_row1_col2" class="data row1 col2" >257</td>
#       <td id="T_4aedc_row1_col3" class="data row1 col3" >506.55</td>
#       <td id="T_4aedc_row1_col4" class="data row1 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_4aedc_row2_col0" class="data row2 col0" >scatter</td>
#       <td id="T_4aedc_row2_col1" class="data row2 col1" >Information Change</td>
#       <td id="T_4aedc_row2_col2" class="data row2 col2" >104</td>
#       <td id="T_4aedc_row2_col3" class="data row2 col3" >204.98</td>
#       <td id="T_4aedc_row2_col4" class="data row2 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_4aedc_row3_col0" class="data row3 col0" >increases</td>
#       <td id="T_4aedc_row3_col1" class="data row3 col1" >Information Change</td>
#       <td id="T_4aedc_row3_col2" class="data row3 col2" >79</td>
#       <td id="T_4aedc_row3_col3" class="data row3 col3" >155.71</td>
#       <td id="T_4aedc_row3_col4" class="data row3 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_4aedc_row4_col0" class="data row4 col0" >create a</td>
#       <td id="T_4aedc_row4_col1" class="data row4 col1" >Information Change</td>
#       <td id="T_4aedc_row4_col2" class="data row4 col2" >71</td>
#       <td id="T_4aedc_row4_col3" class="data row4 col3" >139.94</td>
#       <td id="T_4aedc_row4_col4" class="data row4 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_4aedc_row5_col0" class="data row5 col0" >transformation</td>
#       <td id="T_4aedc_row5_col1" class="data row5 col1" >Information Change</td>
#       <td id="T_4aedc_row5_col2" class="data row5 col2" >71</td>
#       <td id="T_4aedc_row5_col3" class="data row5 col3" >139.94</td>
#       <td id="T_4aedc_row5_col4" class="data row5 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_4aedc_row6_col0" class="data row6 col0" >into a</td>
#       <td id="T_4aedc_row6_col1" class="data row6 col1" >Information Change</td>
#       <td id="T_4aedc_row6_col2" class="data row6 col2" >64</td>
#       <td id="T_4aedc_row6_col3" class="data row6 col3" >126.14</td>
#       <td id="T_4aedc_row6_col4" class="data row6 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_4aedc_row7_col0" class="data row7 col0" >growth</td>
#       <td id="T_4aedc_row7_col1" class="data row7 col1" >Information Change</td>
#       <td id="T_4aedc_row7_col2" class="data row7 col2" >56</td>
#       <td id="T_4aedc_row7_col3" class="data row7 col3" >110.38</td>
#       <td id="T_4aedc_row7_col4" class="data row7 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_4aedc_row8_col0" class="data row8 col0" >change</td>
#       <td id="T_4aedc_row8_col1" class="data row8 col1" >Information Change</td>
#       <td id="T_4aedc_row8_col2" class="data row8 col2" >54</td>
#       <td id="T_4aedc_row8_col3" class="data row8 col3" >106.43</td>
#       <td id="T_4aedc_row8_col4" class="data row8 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_4aedc_row9_col0" class="data row9 col0" >increase in</td>
#       <td id="T_4aedc_row9_col1" class="data row9 col1" >Information Change Positive</td>
#       <td id="T_4aedc_row9_col2" class="data row9 col2" >53</td>
#       <td id="T_4aedc_row9_col3" class="data row9 col3" >104.46</td>
#       <td id="T_4aedc_row9_col4" class="data row9 col4" >100.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
# By REASONING
freq_table_DS.query('Tag.str.startswith("Reasoning")').head(10).style.hide(axis='index').format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_99c15">
#   <thead>
#     <tr>
#       <th id="T_99c15_level0_col0" class="col_heading level0 col0" >Token</th>
#       <th id="T_99c15_level0_col1" class="col_heading level0 col1" >Tag</th>
#       <th id="T_99c15_level0_col2" class="col_heading level0 col2" >AF</th>
#       <th id="T_99c15_level0_col3" class="col_heading level0 col3" >RF</th>
#       <th id="T_99c15_level0_col4" class="col_heading level0 col4" >Range</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_99c15_row0_col0" class="data row0 col0" >models</td>
#       <td id="T_99c15_row0_col1" class="data row0 col1" >Reasoning</td>
#       <td id="T_99c15_row0_col2" class="data row0 col2" >405</td>
#       <td id="T_99c15_row0_col3" class="data row0 col3" >798.25</td>
#       <td id="T_99c15_row0_col4" class="data row0 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_99c15_row1_col0" class="data row1 col0" >analysis</td>
#       <td id="T_99c15_row1_col1" class="data row1 col1" >Reasoning</td>
#       <td id="T_99c15_row1_col2" class="data row1 col2" >221</td>
#       <td id="T_99c15_row1_col3" class="data row1 col3" >435.59</td>
#       <td id="T_99c15_row1_col4" class="data row1 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_99c15_row2_col0" class="data row2 col0" >because</td>
#       <td id="T_99c15_row2_col1" class="data row2 col1" >Reasoning</td>
#       <td id="T_99c15_row2_col2" class="data row2 col2" >197</td>
#       <td id="T_99c15_row2_col3" class="data row2 col3" >388.29</td>
#       <td id="T_99c15_row2_col4" class="data row2 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_99c15_row3_col0" class="data row3 col0" >, so</td>
#       <td id="T_99c15_row3_col1" class="data row3 col1" >Reasoning</td>
#       <td id="T_99c15_row3_col2" class="data row3 col2" >178</td>
#       <td id="T_99c15_row3_col3" class="data row3 col3" >350.84</td>
#       <td id="T_99c15_row3_col4" class="data row3 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_99c15_row4_col0" class="data row4 col0" >results</td>
#       <td id="T_99c15_row4_col1" class="data row4 col1" >Reasoning</td>
#       <td id="T_99c15_row4_col2" class="data row4 col2" >155</td>
#       <td id="T_99c15_row4_col3" class="data row4 col3" >305.50</td>
#       <td id="T_99c15_row4_col4" class="data row4 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_99c15_row5_col0" class="data row5 col0" >based on</td>
#       <td id="T_99c15_row5_col1" class="data row5 col1" >Reasoning</td>
#       <td id="T_99c15_row5_col2" class="data row5 col2" >148</td>
#       <td id="T_99c15_row5_col3" class="data row5 col3" >291.71</td>
#       <td id="T_99c15_row5_col4" class="data row5 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_99c15_row6_col0" class="data row6 col0" >categories</td>
#       <td id="T_99c15_row6_col1" class="data row6 col1" >Reasoning</td>
#       <td id="T_99c15_row6_col2" class="data row6 col2" >145</td>
#       <td id="T_99c15_row6_col3" class="data row6 col3" >285.79</td>
#       <td id="T_99c15_row6_col4" class="data row6 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_99c15_row7_col0" class="data row7 col0" >all the</td>
#       <td id="T_99c15_row7_col1" class="data row7 col1" >Reasoning</td>
#       <td id="T_99c15_row7_col2" class="data row7 col2" >141</td>
#       <td id="T_99c15_row7_col3" class="data row7 col3" >277.91</td>
#       <td id="T_99c15_row7_col4" class="data row7 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_99c15_row8_col0" class="data row8 col0" >category</td>
#       <td id="T_99c15_row8_col1" class="data row8 col1" >Reasoning</td>
#       <td id="T_99c15_row8_col2" class="data row8 col2" >126</td>
#       <td id="T_99c15_row8_col3" class="data row8 col3" >248.35</td>
#       <td id="T_99c15_row8_col4" class="data row8 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_99c15_row9_col0" class="data row9 col0" >survey</td>
#       <td id="T_99c15_row9_col1" class="data row9 col1" >Reasoning</td>
#       <td id="T_99c15_row9_col2" class="data row9 col2" >126</td>
#       <td id="T_99c15_row9_col3" class="data row9 col3" >248.35</td>
#       <td id="T_99c15_row9_col4" class="data row9 col4" >100.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
# By UNCERTAINTY
freq_table_DS.query('Tag.str.startswith("Uncertainty")').head(10).style.hide(axis='index').format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_60cbc">
#   <thead>
#     <tr>
#       <th id="T_60cbc_level0_col0" class="col_heading level0 col0" >Token</th>
#       <th id="T_60cbc_level0_col1" class="col_heading level0 col1" >Tag</th>
#       <th id="T_60cbc_level0_col2" class="col_heading level0 col2" >AF</th>
#       <th id="T_60cbc_level0_col3" class="col_heading level0 col3" >RF</th>
#       <th id="T_60cbc_level0_col4" class="col_heading level0 col4" >Range</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_60cbc_row0_col0" class="data row0 col0" >kind of</td>
#       <td id="T_60cbc_row0_col1" class="data row0 col1" >Uncertainty</td>
#       <td id="T_60cbc_row0_col2" class="data row0 col2" >60</td>
#       <td id="T_60cbc_row0_col3" class="data row0 col3" >118.26</td>
#       <td id="T_60cbc_row0_col4" class="data row0 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_60cbc_row1_col0" class="data row1 col0" >whether</td>
#       <td id="T_60cbc_row1_col1" class="data row1 col1" >Uncertainty</td>
#       <td id="T_60cbc_row1_col2" class="data row1 col2" >26</td>
#       <td id="T_60cbc_row1_col3" class="data row1 col3" >51.25</td>
#       <td id="T_60cbc_row1_col4" class="data row1 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_60cbc_row2_col0" class="data row2 col0" >whether the</td>
#       <td id="T_60cbc_row2_col1" class="data row2 col1" >Uncertainty</td>
#       <td id="T_60cbc_row2_col2" class="data row2 col2" >21</td>
#       <td id="T_60cbc_row2_col3" class="data row2 col3" >41.39</td>
#       <td id="T_60cbc_row2_col4" class="data row2 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_60cbc_row3_col0" class="data row3 col0" >whether a</td>
#       <td id="T_60cbc_row3_col1" class="data row3 col1" >Uncertainty</td>
#       <td id="T_60cbc_row3_col2" class="data row3 col2" >10</td>
#       <td id="T_60cbc_row3_col3" class="data row3 col3" >19.71</td>
#       <td id="T_60cbc_row3_col4" class="data row3 col4" >66.67</td>
#     </tr>
#     <tr>
#       <td id="T_60cbc_row4_col0" class="data row4 col0" >risk</td>
#       <td id="T_60cbc_row4_col1" class="data row4 col1" >Uncertainty</td>
#       <td id="T_60cbc_row4_col2" class="data row4 col2" >8</td>
#       <td id="T_60cbc_row4_col3" class="data row4 col3" >15.77</td>
#       <td id="T_60cbc_row4_col4" class="data row4 col4" >66.67</td>
#     </tr>
#     <tr>
#       <td id="T_60cbc_row5_col0" class="data row5 col0" >or maybe</td>
#       <td id="T_60cbc_row5_col1" class="data row5 col1" >Uncertainty</td>
#       <td id="T_60cbc_row5_col2" class="data row5 col2" >7</td>
#       <td id="T_60cbc_row5_col3" class="data row5 col3" >13.80</td>
#       <td id="T_60cbc_row5_col4" class="data row5 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_60cbc_row6_col0" class="data row6 col0" >whether or not</td>
#       <td id="T_60cbc_row6_col1" class="data row6 col1" >Uncertainty</td>
#       <td id="T_60cbc_row6_col2" class="data row6 col2" >7</td>
#       <td id="T_60cbc_row6_col3" class="data row6 col3" >13.80</td>
#       <td id="T_60cbc_row6_col4" class="data row6 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_60cbc_row7_col0" class="data row7 col0" >one or more</td>
#       <td id="T_60cbc_row7_col1" class="data row7 col1" >Uncertainty</td>
#       <td id="T_60cbc_row7_col2" class="data row7 col2" >6</td>
#       <td id="T_60cbc_row7_col3" class="data row7 col3" >11.83</td>
#       <td id="T_60cbc_row7_col4" class="data row7 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_60cbc_row8_col0" class="data row8 col0" >somehow</td>
#       <td id="T_60cbc_row8_col1" class="data row8 col1" >Uncertainty</td>
#       <td id="T_60cbc_row8_col2" class="data row8 col2" >6</td>
#       <td id="T_60cbc_row8_col3" class="data row8 col3" >11.83</td>
#       <td id="T_60cbc_row8_col4" class="data row8 col4" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_60cbc_row9_col0" class="data row9 col0" >there might be</td>
#       <td id="T_60cbc_row9_col1" class="data row9 col1" >Uncertainty</td>
#       <td id="T_60cbc_row9_col2" class="data row9 col2" >6</td>
#       <td id="T_60cbc_row9_col3" class="data row9 col3" >11.83</td>
#       <td id="T_60cbc_row9_col4" class="data row9 col4" >100.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### 4.3.8.3 Tags Frequency Tables

# %% [markdown]
# We can focus on the tag counts by using the `tags_table` function. It works just like the `frequency_table` function, taking a dictionary created by the `convert_corpus` function, an integer against which to normalize, and a `count_by` argument of either `‘pos’` or `‘ds’`.

# %%
tags_freq_table_POS = tags_table(
    tok=tp,
    n_tokens=non_punct,
    count_by='pos'
)

# %%
tags_freq_table_POS.head(10).style.hide(axis='index').format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_1cbde">
#   <thead>
#     <tr>
#       <th id="T_1cbde_level0_col0" class="col_heading level0 col0" >Tag</th>
#       <th id="T_1cbde_level0_col1" class="col_heading level0 col1" >AF</th>
#       <th id="T_1cbde_level0_col2" class="col_heading level0 col2" >RF</th>
#       <th id="T_1cbde_level0_col3" class="col_heading level0 col3" >Range</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_1cbde_row0_col0" class="data row0 col0" >NN1</td>
#       <td id="T_1cbde_row0_col1" class="data row0 col1" >76759</td>
#       <td id="T_1cbde_row0_col2" class="data row0 col2" >18.95</td>
#       <td id="T_1cbde_row0_col3" class="data row0 col3" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1cbde_row1_col0" class="data row1 col0" >JJ</td>
#       <td id="T_1cbde_row1_col1" class="data row1 col1" >28686</td>
#       <td id="T_1cbde_row1_col2" class="data row1 col2" >7.08</td>
#       <td id="T_1cbde_row1_col3" class="data row1 col3" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1cbde_row2_col0" class="data row2 col0" >NN2</td>
#       <td id="T_1cbde_row2_col1" class="data row2 col1" >27968</td>
#       <td id="T_1cbde_row2_col2" class="data row2 col2" >6.91</td>
#       <td id="T_1cbde_row2_col3" class="data row2 col3" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1cbde_row3_col0" class="data row3 col0" >AT</td>
#       <td id="T_1cbde_row3_col1" class="data row3 col1" >23810</td>
#       <td id="T_1cbde_row3_col2" class="data row3 col2" >5.88</td>
#       <td id="T_1cbde_row3_col3" class="data row3 col3" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1cbde_row4_col0" class="data row4 col0" >II</td>
#       <td id="T_1cbde_row4_col1" class="data row4 col1" >22685</td>
#       <td id="T_1cbde_row4_col2" class="data row4 col2" >5.60</td>
#       <td id="T_1cbde_row4_col3" class="data row4 col3" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1cbde_row5_col0" class="data row5 col0" >VVI</td>
#       <td id="T_1cbde_row5_col1" class="data row5 col1" >11460</td>
#       <td id="T_1cbde_row5_col2" class="data row5 col2" >2.83</td>
#       <td id="T_1cbde_row5_col3" class="data row5 col3" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1cbde_row6_col0" class="data row6 col0" >MC</td>
#       <td id="T_1cbde_row6_col1" class="data row6 col1" >11009</td>
#       <td id="T_1cbde_row6_col2" class="data row6 col2" >2.72</td>
#       <td id="T_1cbde_row6_col3" class="data row6 col3" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1cbde_row7_col0" class="data row7 col0" >IO</td>
#       <td id="T_1cbde_row7_col1" class="data row7 col1" >10579</td>
#       <td id="T_1cbde_row7_col2" class="data row7 col2" >2.61</td>
#       <td id="T_1cbde_row7_col3" class="data row7 col3" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1cbde_row8_col0" class="data row8 col0" >RR</td>
#       <td id="T_1cbde_row8_col1" class="data row8 col1" >10234</td>
#       <td id="T_1cbde_row8_col2" class="data row8 col2" >2.53</td>
#       <td id="T_1cbde_row8_col3" class="data row8 col3" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_1cbde_row9_col0" class="data row9 col0" >CC</td>
#       <td id="T_1cbde_row9_col1" class="data row9 col1" >9729</td>
#       <td id="T_1cbde_row9_col2" class="data row9 col2" >2.40</td>
#       <td id="T_1cbde_row9_col3" class="data row9 col3" >100.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# And by DocuScope category:

# %%
tags_freq_table_DS = tags_table(
    tok=tp,
    n_tokens=corpus_total,
    count_by='ds'
)

# %%
tags_freq_table_DS.sort_values('RF', ascending=False).head(10).style.hide(axis='index').format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_76a0a">
#   <thead>
#     <tr>
#       <th id="T_76a0a_level0_col0" class="col_heading level0 col0" >Tag</th>
#       <th id="T_76a0a_level0_col1" class="col_heading level0 col1" >AF</th>
#       <th id="T_76a0a_level0_col2" class="col_heading level0 col2" >RF</th>
#       <th id="T_76a0a_level0_col3" class="col_heading level0 col3" >Range</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_76a0a_row0_col0" class="data row0 col0" >Academic Terms</td>
#       <td id="T_76a0a_row0_col1" class="data row0 col1" >32284</td>
#       <td id="T_76a0a_row0_col2" class="data row0 col2" >6.36</td>
#       <td id="T_76a0a_row0_col3" class="data row0 col3" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_76a0a_row1_col0" class="data row1 col0" >Description</td>
#       <td id="T_76a0a_row1_col1" class="data row1 col1" >24589</td>
#       <td id="T_76a0a_row1_col2" class="data row1 col2" >4.85</td>
#       <td id="T_76a0a_row1_col3" class="data row1 col3" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_76a0a_row2_col0" class="data row2 col0" >Information Exposition</td>
#       <td id="T_76a0a_row2_col1" class="data row2 col1" >22511</td>
#       <td id="T_76a0a_row2_col2" class="data row2 col2" >4.44</td>
#       <td id="T_76a0a_row2_col3" class="data row2 col3" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_76a0a_row3_col0" class="data row3 col0" >Narrative</td>
#       <td id="T_76a0a_row3_col1" class="data row3 col1" >15842</td>
#       <td id="T_76a0a_row3_col2" class="data row3 col2" >3.12</td>
#       <td id="T_76a0a_row3_col3" class="data row3 col3" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_76a0a_row4_col0" class="data row4 col0" >Character</td>
#       <td id="T_76a0a_row4_col1" class="data row4 col1" >13693</td>
#       <td id="T_76a0a_row4_col2" class="data row4 col2" >2.70</td>
#       <td id="T_76a0a_row4_col3" class="data row4 col3" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_76a0a_row5_col0" class="data row5 col0" >Information Topics</td>
#       <td id="T_76a0a_row5_col1" class="data row5 col1" >10509</td>
#       <td id="T_76a0a_row5_col2" class="data row5 col2" >2.07</td>
#       <td id="T_76a0a_row5_col3" class="data row5 col3" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_76a0a_row6_col0" class="data row6 col0" >Negative</td>
#       <td id="T_76a0a_row6_col1" class="data row6 col1" >7082</td>
#       <td id="T_76a0a_row6_col2" class="data row6 col2" >1.40</td>
#       <td id="T_76a0a_row6_col3" class="data row6 col3" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_76a0a_row7_col0" class="data row7 col0" >Force Stressed</td>
#       <td id="T_76a0a_row7_col1" class="data row7 col1" >7026</td>
#       <td id="T_76a0a_row7_col2" class="data row7 col2" >1.38</td>
#       <td id="T_76a0a_row7_col3" class="data row7 col3" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_76a0a_row8_col0" class="data row8 col0" >Positive</td>
#       <td id="T_76a0a_row8_col1" class="data row8 col1" >6799</td>
#       <td id="T_76a0a_row8_col2" class="data row8 col2" >1.34</td>
#       <td id="T_76a0a_row8_col3" class="data row8 col3" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_76a0a_row9_col0" class="data row9 col0" >Metadiscourse Cohesive</td>
#       <td id="T_76a0a_row9_col1" class="data row9 col1" >6119</td>
#       <td id="T_76a0a_row9_col2" class="data row9 col2" >1.21</td>
#       <td id="T_76a0a_row9_col3" class="data row9 col3" >100.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### 4.3.8.4 N-gram Frequency Tables

# %% [markdown]
# Ngrams (between bigrams and 5-grams) can be calculated using the `ngrams_table` function. It works much like the `frequency_table` function but with the addition of a span argument `ng_span` consisting of an integer between 2 and 5.
#
# This will return a table of 3-grams:

# %%
ngram_freq_table_POS = ngrams_table(
    tok=tp,
    ng_span=3,
    n_tokens=non_punct,
    count_by='pos'
)

# %% [markdown]
# The returned data frame includes both the sequence of tokens, as well as the sequence of tags:

# %%
ngram_freq_table_POS.head(10).style.hide(axis='index').format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_8bf3c">
#   <thead>
#     <tr>
#       <th id="T_8bf3c_level0_col0" class="col_heading level0 col0" >Token1</th>
#       <th id="T_8bf3c_level0_col1" class="col_heading level0 col1" >Token2</th>
#       <th id="T_8bf3c_level0_col2" class="col_heading level0 col2" >Token3</th>
#       <th id="T_8bf3c_level0_col3" class="col_heading level0 col3" >Tag1</th>
#       <th id="T_8bf3c_level0_col4" class="col_heading level0 col4" >Tag2</th>
#       <th id="T_8bf3c_level0_col5" class="col_heading level0 col5" >Tag3</th>
#       <th id="T_8bf3c_level0_col6" class="col_heading level0 col6" >AF</th>
#       <th id="T_8bf3c_level0_col7" class="col_heading level0 col7" >RF</th>
#       <th id="T_8bf3c_level0_col8" class="col_heading level0 col8" >Range</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_8bf3c_row0_col0" class="data row0 col0" >we</td>
#       <td id="T_8bf3c_row0_col1" class="data row0 col1" >can</td>
#       <td id="T_8bf3c_row0_col2" class="data row0 col2" >see</td>
#       <td id="T_8bf3c_row0_col3" class="data row0 col3" >PPIS2</td>
#       <td id="T_8bf3c_row0_col4" class="data row0 col4" >VM</td>
#       <td id="T_8bf3c_row0_col5" class="data row0 col5" >VVI</td>
#       <td id="T_8bf3c_row0_col6" class="data row0 col6" >380</td>
#       <td id="T_8bf3c_row0_col7" class="data row0 col7" >938.32</td>
#       <td id="T_8bf3c_row0_col8" class="data row0 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_8bf3c_row1_col0" class="data row1 col0" >the</td>
#       <td id="T_8bf3c_row1_col1" class="data row1 col1" >number</td>
#       <td id="T_8bf3c_row1_col2" class="data row1 col2" >of</td>
#       <td id="T_8bf3c_row1_col3" class="data row1 col3" >AT</td>
#       <td id="T_8bf3c_row1_col4" class="data row1 col4" >NN1</td>
#       <td id="T_8bf3c_row1_col5" class="data row1 col5" >IO</td>
#       <td id="T_8bf3c_row1_col6" class="data row1 col6" >332</td>
#       <td id="T_8bf3c_row1_col7" class="data row1 col7" >819.80</td>
#       <td id="T_8bf3c_row1_col8" class="data row1 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_8bf3c_row2_col0" class="data row2 col0" >most</td>
#       <td id="T_8bf3c_row2_col1" class="data row2 col1" >of</td>
#       <td id="T_8bf3c_row2_col2" class="data row2 col2" >the</td>
#       <td id="T_8bf3c_row2_col3" class="data row2 col3" >DAT</td>
#       <td id="T_8bf3c_row2_col4" class="data row2 col4" >IO</td>
#       <td id="T_8bf3c_row2_col5" class="data row2 col5" >AT</td>
#       <td id="T_8bf3c_row2_col6" class="data row2 col6" >214</td>
#       <td id="T_8bf3c_row2_col7" class="data row2 col7" >528.43</td>
#       <td id="T_8bf3c_row2_col8" class="data row2 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_8bf3c_row3_col0" class="data row3 col0" >can</td>
#       <td id="T_8bf3c_row3_col1" class="data row3 col1" >see</td>
#       <td id="T_8bf3c_row3_col2" class="data row3 col2" >that</td>
#       <td id="T_8bf3c_row3_col3" class="data row3 col3" >VM</td>
#       <td id="T_8bf3c_row3_col4" class="data row3 col4" >VVI</td>
#       <td id="T_8bf3c_row3_col5" class="data row3 col5" >CST</td>
#       <td id="T_8bf3c_row3_col6" class="data row3 col6" >192</td>
#       <td id="T_8bf3c_row3_col7" class="data row3 col7" >474.10</td>
#       <td id="T_8bf3c_row3_col8" class="data row3 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_8bf3c_row4_col0" class="data row4 col0" >there</td>
#       <td id="T_8bf3c_row4_col1" class="data row4 col1" >is</td>
#       <td id="T_8bf3c_row4_col2" class="data row4 col2" >a</td>
#       <td id="T_8bf3c_row4_col3" class="data row4 col3" >EX</td>
#       <td id="T_8bf3c_row4_col4" class="data row4 col4" >VBZ</td>
#       <td id="T_8bf3c_row4_col5" class="data row4 col5" >AT1</td>
#       <td id="T_8bf3c_row4_col6" class="data row4 col6" >192</td>
#       <td id="T_8bf3c_row4_col7" class="data row4 col7" >474.10</td>
#       <td id="T_8bf3c_row4_col8" class="data row4 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_8bf3c_row5_col0" class="data row5 col0" >the</td>
#       <td id="T_8bf3c_row5_col1" class="data row5 col1" >distribution</td>
#       <td id="T_8bf3c_row5_col2" class="data row5 col2" >of</td>
#       <td id="T_8bf3c_row5_col3" class="data row5 col3" >AT</td>
#       <td id="T_8bf3c_row5_col4" class="data row5 col4" >NN1</td>
#       <td id="T_8bf3c_row5_col5" class="data row5 col5" >IO</td>
#       <td id="T_8bf3c_row5_col6" class="data row5 col6" >189</td>
#       <td id="T_8bf3c_row5_col7" class="data row5 col7" >466.69</td>
#       <td id="T_8bf3c_row5_col8" class="data row5 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_8bf3c_row6_col0" class="data row6 col0" >of</td>
#       <td id="T_8bf3c_row6_col1" class="data row6 col1" >the</td>
#       <td id="T_8bf3c_row6_col2" class="data row6 col2" >following</td>
#       <td id="T_8bf3c_row6_col3" class="data row6 col3" >IO</td>
#       <td id="T_8bf3c_row6_col4" class="data row6 col4" >AT</td>
#       <td id="T_8bf3c_row6_col5" class="data row6 col5" >JJ</td>
#       <td id="T_8bf3c_row6_col6" class="data row6 col6" >158</td>
#       <td id="T_8bf3c_row6_col7" class="data row6 col7" >390.15</td>
#       <td id="T_8bf3c_row6_col8" class="data row6 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_8bf3c_row7_col0" class="data row7 col0" >a</td>
#       <td id="T_8bf3c_row7_col1" class="data row7 col1" >lot</td>
#       <td id="T_8bf3c_row7_col2" class="data row7 col2" >of</td>
#       <td id="T_8bf3c_row7_col3" class="data row7 col3" >AT1</td>
#       <td id="T_8bf3c_row7_col4" class="data row7 col4" >NN1</td>
#       <td id="T_8bf3c_row7_col5" class="data row7 col5" >IO</td>
#       <td id="T_8bf3c_row7_col6" class="data row7 col6" >140</td>
#       <td id="T_8bf3c_row7_col7" class="data row7 col7" >345.70</td>
#       <td id="T_8bf3c_row7_col8" class="data row7 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_8bf3c_row8_col0" class="data row8 col0" >of</td>
#       <td id="T_8bf3c_row8_col1" class="data row8 col1" >the</td>
#       <td id="T_8bf3c_row8_col2" class="data row8 col2" >data</td>
#       <td id="T_8bf3c_row8_col3" class="data row8 col3" >IO</td>
#       <td id="T_8bf3c_row8_col4" class="data row8 col4" >AT</td>
#       <td id="T_8bf3c_row8_col5" class="data row8 col5" >NN</td>
#       <td id="T_8bf3c_row8_col6" class="data row8 col6" >139</td>
#       <td id="T_8bf3c_row8_col7" class="data row8 col7" >343.23</td>
#       <td id="T_8bf3c_row8_col8" class="data row8 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_8bf3c_row9_col0" class="data row9 col0" >we</td>
#       <td id="T_8bf3c_row9_col1" class="data row9 col1" >need</td>
#       <td id="T_8bf3c_row9_col2" class="data row9 col2" >to</td>
#       <td id="T_8bf3c_row9_col3" class="data row9 col3" >PPIS2</td>
#       <td id="T_8bf3c_row9_col4" class="data row9 col4" >VV0</td>
#       <td id="T_8bf3c_row9_col5" class="data row9 col5" >TO</td>
#       <td id="T_8bf3c_row9_col6" class="data row9 col6" >122</td>
#       <td id="T_8bf3c_row9_col7" class="data row9 col7" >301.25</td>
#       <td id="T_8bf3c_row9_col8" class="data row9 col8" >100.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Now we can filter ngrams that, for example, start with a verb:

# %%
ngram_freq_table_POS.query('Tag1.str.startswith("V")').head(20).style.hide(axis='index').format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_ab878">
#   <thead>
#     <tr>
#       <th id="T_ab878_level0_col0" class="col_heading level0 col0" >Token1</th>
#       <th id="T_ab878_level0_col1" class="col_heading level0 col1" >Token2</th>
#       <th id="T_ab878_level0_col2" class="col_heading level0 col2" >Token3</th>
#       <th id="T_ab878_level0_col3" class="col_heading level0 col3" >Tag1</th>
#       <th id="T_ab878_level0_col4" class="col_heading level0 col4" >Tag2</th>
#       <th id="T_ab878_level0_col5" class="col_heading level0 col5" >Tag3</th>
#       <th id="T_ab878_level0_col6" class="col_heading level0 col6" >AF</th>
#       <th id="T_ab878_level0_col7" class="col_heading level0 col7" >RF</th>
#       <th id="T_ab878_level0_col8" class="col_heading level0 col8" >Range</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ab878_row0_col0" class="data row0 col0" >can</td>
#       <td id="T_ab878_row0_col1" class="data row0 col1" >see</td>
#       <td id="T_ab878_row0_col2" class="data row0 col2" >that</td>
#       <td id="T_ab878_row0_col3" class="data row0 col3" >VM</td>
#       <td id="T_ab878_row0_col4" class="data row0 col4" >VVI</td>
#       <td id="T_ab878_row0_col5" class="data row0 col5" >CST</td>
#       <td id="T_ab878_row0_col6" class="data row0 col6" >192</td>
#       <td id="T_ab878_row0_col7" class="data row0 col7" >474.10</td>
#       <td id="T_ab878_row0_col8" class="data row0 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_ab878_row1_col0" class="data row1 col0" >see</td>
#       <td id="T_ab878_row1_col1" class="data row1 col1" >that</td>
#       <td id="T_ab878_row1_col2" class="data row1 col2" >the</td>
#       <td id="T_ab878_row1_col3" class="data row1 col3" >VVI</td>
#       <td id="T_ab878_row1_col4" class="data row1 col4" >CST</td>
#       <td id="T_ab878_row1_col5" class="data row1 col5" >AT</td>
#       <td id="T_ab878_row1_col6" class="data row1 col6" >92</td>
#       <td id="T_ab878_row1_col7" class="data row1 col7" >227.17</td>
#       <td id="T_ab878_row1_col8" class="data row1 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_ab878_row2_col0" class="data row2 col0" >look</td>
#       <td id="T_ab878_row2_col1" class="data row2 col1" >at</td>
#       <td id="T_ab878_row2_col2" class="data row2 col2" >the</td>
#       <td id="T_ab878_row2_col3" class="data row2 col3" >VVI</td>
#       <td id="T_ab878_row2_col4" class="data row2 col4" >II</td>
#       <td id="T_ab878_row2_col5" class="data row2 col5" >AT</td>
#       <td id="T_ab878_row2_col6" class="data row2 col6" >84</td>
#       <td id="T_ab878_row2_col7" class="data row2 col7" >207.42</td>
#       <td id="T_ab878_row2_col8" class="data row2 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_ab878_row3_col0" class="data row3 col0" >seems</td>
#       <td id="T_ab878_row3_col1" class="data row3 col1" >to</td>
#       <td id="T_ab878_row3_col2" class="data row3 col2" >be</td>
#       <td id="T_ab878_row3_col3" class="data row3 col3" >VVZ</td>
#       <td id="T_ab878_row3_col4" class="data row3 col4" >TO</td>
#       <td id="T_ab878_row3_col5" class="data row3 col5" >VBI</td>
#       <td id="T_ab878_row3_col6" class="data row3 col6" >76</td>
#       <td id="T_ab878_row3_col7" class="data row3 col7" >187.66</td>
#       <td id="T_ab878_row3_col8" class="data row3 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_ab878_row4_col0" class="data row4 col0" >based</td>
#       <td id="T_ab878_row4_col1" class="data row4 col1" >on</td>
#       <td id="T_ab878_row4_col2" class="data row4 col2" >the</td>
#       <td id="T_ab878_row4_col3" class="data row4 col3" >VVN</td>
#       <td id="T_ab878_row4_col4" class="data row4 col4" >II</td>
#       <td id="T_ab878_row4_col5" class="data row4 col5" >AT</td>
#       <td id="T_ab878_row4_col6" class="data row4 col6" >68</td>
#       <td id="T_ab878_row4_col7" class="data row4 col7" >167.91</td>
#       <td id="T_ab878_row4_col8" class="data row4 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_ab878_row5_col0" class="data row5 col0" >can</td>
#       <td id="T_ab878_row5_col1" class="data row5 col1" >be</td>
#       <td id="T_ab878_row5_col2" class="data row5 col2" >seen</td>
#       <td id="T_ab878_row5_col3" class="data row5 col3" >VM</td>
#       <td id="T_ab878_row5_col4" class="data row5 col4" >VBI</td>
#       <td id="T_ab878_row5_col5" class="data row5 col5" >VVN</td>
#       <td id="T_ab878_row5_col6" class="data row5 col6" >68</td>
#       <td id="T_ab878_row5_col7" class="data row5 col7" >167.91</td>
#       <td id="T_ab878_row5_col8" class="data row5 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_ab878_row6_col0" class="data row6 col0" >use</td>
#       <td id="T_ab878_row6_col1" class="data row6 col1" >any</td>
#       <td id="T_ab878_row6_col2" class="data row6 col2" >of</td>
#       <td id="T_ab878_row6_col3" class="data row6 col3" >VV0</td>
#       <td id="T_ab878_row6_col4" class="data row6 col4" >DD</td>
#       <td id="T_ab878_row6_col5" class="data row6 col5" >IO</td>
#       <td id="T_ab878_row6_col6" class="data row6 col6" >68</td>
#       <td id="T_ab878_row6_col7" class="data row6 col7" >167.91</td>
#       <td id="T_ab878_row6_col8" class="data row6 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_ab878_row7_col0" class="data row7 col0" >are</td>
#       <td id="T_ab878_row7_col1" class="data row7 col1" >the</td>
#       <td id="T_ab878_row7_col2" class="data row7 col2" >most</td>
#       <td id="T_ab878_row7_col3" class="data row7 col3" >VBR</td>
#       <td id="T_ab878_row7_col4" class="data row7 col4" >AT</td>
#       <td id="T_ab878_row7_col5" class="data row7 col5" >RGT</td>
#       <td id="T_ab878_row7_col6" class="data row7 col6" >67</td>
#       <td id="T_ab878_row7_col7" class="data row7 col7" >165.44</td>
#       <td id="T_ab878_row7_col8" class="data row7 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_ab878_row8_col0" class="data row8 col0" >can</td>
#       <td id="T_ab878_row8_col1" class="data row8 col1" >see</td>
#       <td id="T_ab878_row8_col2" class="data row8 col2" >the</td>
#       <td id="T_ab878_row8_col3" class="data row8 col3" >VM</td>
#       <td id="T_ab878_row8_col4" class="data row8 col4" >VVI</td>
#       <td id="T_ab878_row8_col5" class="data row8 col5" >AT</td>
#       <td id="T_ab878_row8_col6" class="data row8 col6" >67</td>
#       <td id="T_ab878_row8_col7" class="data row8 col7" >165.44</td>
#       <td id="T_ab878_row8_col8" class="data row8 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_ab878_row9_col0" class="data row9 col0" >is</td>
#       <td id="T_ab878_row9_col1" class="data row9 col1" >the</td>
#       <td id="T_ab878_row9_col2" class="data row9 col2" >most</td>
#       <td id="T_ab878_row9_col3" class="data row9 col3" >VBZ</td>
#       <td id="T_ab878_row9_col4" class="data row9 col4" >AT</td>
#       <td id="T_ab878_row9_col5" class="data row9 col5" >RGT</td>
#       <td id="T_ab878_row9_col6" class="data row9 col6" >64</td>
#       <td id="T_ab878_row9_col7" class="data row9 col7" >158.03</td>
#       <td id="T_ab878_row9_col8" class="data row9 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_ab878_row10_col0" class="data row10 col0" >let 's</td>
#       <td id="T_ab878_row10_col1" class="data row10 col1" >look</td>
#       <td id="T_ab878_row10_col2" class="data row10 col2" >at</td>
#       <td id="T_ab878_row10_col3" class="data row10 col3" >VM</td>
#       <td id="T_ab878_row10_col4" class="data row10 col4" >VVI</td>
#       <td id="T_ab878_row10_col5" class="data row10 col5" >II</td>
#       <td id="T_ab878_row10_col6" class="data row10 col6" >64</td>
#       <td id="T_ab878_row10_col7" class="data row10 col7" >158.03</td>
#       <td id="T_ab878_row10_col8" class="data row10 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_ab878_row11_col0" class="data row11 col0" >looking</td>
#       <td id="T_ab878_row11_col1" class="data row11 col1" >at</td>
#       <td id="T_ab878_row11_col2" class="data row11 col2" >the</td>
#       <td id="T_ab878_row11_col3" class="data row11 col3" >VVG</td>
#       <td id="T_ab878_row11_col4" class="data row11 col4" >II</td>
#       <td id="T_ab878_row11_col5"

# %% [markdown]
# Or sequences that end with a *past participle* (‘VVN’) preceded by a *to be verb* (‘VB’), thus showing passive constructions:

# %%
ngram_freq_table_POS.query('Tag3.str.startswith("VVN") and Tag2.str.startswith("VB")').head(15).style.hide(axis='index').format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_9b1e0">
#   <thead>
#     <tr>
#       <th id="T_9b1e0_level0_col0" class="col_heading level0 col0" >Token1</th>
#       <th id="T_9b1e0_level0_col1" class="col_heading level0 col1" >Token2</th>
#       <th id="T_9b1e0_level0_col2" class="col_heading level0 col2" >Token3</th>
#       <th id="T_9b1e0_level0_col3" class="col_heading level0 col3" >Tag1</th>
#       <th id="T_9b1e0_level0_col4" class="col_heading level0 col4" >Tag2</th>
#       <th id="T_9b1e0_level0_col5" class="col_heading level0 col5" >Tag3</th>
#       <th id="T_9b1e0_level0_col6" class="col_heading level0 col6" >AF</th>
#       <th id="T_9b1e0_level0_col7" class="col_heading level0 col7" >RF</th>
#       <th id="T_9b1e0_level0_col8" class="col_heading level0 col8" >Range</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9b1e0_row0_col0" class="data row0 col0" >can</td>
#       <td id="T_9b1e0_row0_col1" class="data row0 col1" >be</td>
#       <td id="T_9b1e0_row0_col2" class="data row0 col2" >seen</td>
#       <td id="T_9b1e0_row0_col3" class="data row0 col3" >VM</td>
#       <td id="T_9b1e0_row0_col4" class="data row0 col4" >VBI</td>
#       <td id="T_9b1e0_row0_col5" class="data row0 col5" >VVN</td>
#       <td id="T_9b1e0_row0_col6" class="data row0 col6" >68</td>
#       <td id="T_9b1e0_row0_col7" class="data row0 col7" >167.91</td>
#       <td id="T_9b1e0_row0_col8" class="data row0 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_9b1e0_row1_col0" class="data row1 col0" >can</td>
#       <td id="T_9b1e0_row1_col1" class="data row1 col1" >be</td>
#       <td id="T_9b1e0_row1_col2" class="data row1 col2" >used</td>
#       <td id="T_9b1e0_row1_col3" class="data row1 col3" >VM</td>
#       <td id="T_9b1e0_row1_col4" class="data row1 col4" >VBI</td>
#       <td id="T_9b1e0_row1_col5" class="data row1 col5" >VVN</td>
#       <td id="T_9b1e0_row1_col6" class="data row1 col6" >59</td>
#       <td id="T_9b1e0_row1_col7" class="data row1 col7" >145.69</td>
#       <td id="T_9b1e0_row1_col8" class="data row1 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_9b1e0_row2_col0" class="data row2 col0" >will</td>
#       <td id="T_9b1e0_row2_col1" class="data row2 col1" >be</td>
#       <td id="T_9b1e0_row2_col2" class="data row2 col2" >used</td>
#       <td id="T_9b1e0_row2_col3" class="data row2 col3" >VM</td>
#       <td id="T_9b1e0_row2_col4" class="data row2 col4" >VBI</td>
#       <td id="T_9b1e0_row2_col5" class="data row2 col5" >VVN</td>
#       <td id="T_9b1e0_row2_col6" class="data row2 col6" >31</td>
#       <td id="T_9b1e0_row2_col7" class="data row2 col7" >76.55</td>
#       <td id="T_9b1e0_row2_col8" class="data row2 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_9b1e0_row3_col0" class="data row3 col0" >can</td>
#       <td id="T_9b1e0_row3_col1" class="data row3 col1" >be</td>
#       <td id="T_9b1e0_row3_col2" class="data row3 col2" >found</td>
#       <td id="T_9b1e0_row3_col3" class="data row3 col3" >VM</td>
#       <td id="T_9b1e0_row3_col4" class="data row3 col4" >VBI</td>
#       <td id="T_9b1e0_row3_col5" class="data row3 col5" >VVN</td>
#       <td id="T_9b1e0_row3_col6" class="data row3 col6" >23</td>
#       <td id="T_9b1e0_row3_col7" class="data row3 col7" >56.79</td>
#       <td id="T_9b1e0_row3_col8" class="data row3 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_9b1e0_row4_col0" class="data row4 col0" >can</td>
#       <td id="T_9b1e0_row4_col1" class="data row4 col1" >be</td>
#       <td id="T_9b1e0_row4_col2" class="data row4 col2" >observed</td>
#       <td id="T_9b1e0_row4_col3" class="data row4 col3" >VM</td>
#       <td id="T_9b1e0_row4_col4" class="data row4 col4" >VBI</td>
#       <td id="T_9b1e0_row4_col5" class="data row4 col5" >VVN</td>
#       <td id="T_9b1e0_row4_col6" class="data row4 col6" >19</td>
#       <td id="T_9b1e0_row4_col7" class="data row4 col7" >46.92</td>
#       <td id="T_9b1e0_row4_col8" class="data row4 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_9b1e0_row5_col0" class="data row5 col0" >ratings</td>
#       <td id="T_9b1e0_row5_col1" class="data row5 col1" >are</td>
#       <td id="T_9b1e0_row5_col2" class="data row5 col2" >spread</td>
#       <td id="T_9b1e0_row5_col3" class="data row5 col3" >NN2</td>
#       <td id="T_9b1e0_row5_col4" class="data row5 col4" >VBR</td>
#       <td id="T_9b1e0_row5_col5" class="data row5 col5" >VVN</td>
#       <td id="T_9b1e0_row5_col6" class="data row5 col6" >14</td>
#       <td id="T_9b1e0_row5_col7" class="data row5 col7" >34.57</td>
#       <td id="T_9b1e0_row5_col8" class="data row5 col8" >33.33</td>
#     </tr>
#     <tr>
#       <td id="T_9b1e0_row6_col0" class="data row6 col0" >can</td>
#       <td id="T_9b1e0_row6_col1" class="data row6 col1" >be</td>
#       <td id="T_9b1e0_row6_col2" class="data row6 col2" >considered</td>
#       <td id="T_9b1e0_row6_col3" class="data row6 col3" >VM</td>
#       <td id="T_9b1e0_row6_col4" class="data row6 col4" >VBI</td>
#       <td id="T_9b1e0_row6_col5" class="data row6 col5" >VVN</td>
#       <td id="T_9b1e0_row6_col6" class="data row6 col6" >9</td>
#       <td id="T_9b1e0_row6_col7" class="data row6 col7" >22.22</td>
#       <td id="T_9b1e0_row6_col8" class="data row6 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_9b1e0_row7_col0" class="data row7 col0" >can</td>
#       <td id="T_9b1e0_row7_col1" class="data row7 col1" >be</td>
#       <td id="T_9b1e0_row7_col2" class="data row7 col2" >made</td>
#       <td id="T_9b1e0_row7_col3" class="data row7 col3" >VM</td>
#       <td id="T_9b1e0_row7_col4" class="data row7 col4" >VBI</td>
#       <td id="T_9b1e0_row7_col5" class="data row7 col5" >VVN</td>
#       <td id="T_9b1e0_row7_col6" class="data row7 col6" >9</td>
#       <td id="T_9b1e0_row7_col7" class="data row7 col7" >22.22</td>
#       <td id="T_9b1e0_row7_col8" class="data row7 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_9b1e0_row8_col0" class="data row8 col0" >it</td>
#       <td id="T_9b1e0_row8_col1" class="data row8 col1" >is</td>
#       <td id="T_9b1e0_row8_col2" class="data row8 col2" >called</td>
#       <td id="T_9b1e0_row8_col3" class="data row8 col3" >PPH1</td>
#       <td id="T_9b1e0_row8_col4" class="data row8 col4" >VBZ</td>
#       <td id="T_9b1e0_row8_col5" class="data row8 col5" >VVN</td>
#       <td id="T_9b1e0_row8_col6" class="data row8 col6" >9</td>
#       <td id="T_9b1e0_row8_col7" class="data row8 col7" >22.22</td>
#       <td id="T_9b1e0_row8_col8" class="data row8 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_9b1e0_row9_col0" class="data row9 col0" >it</td>
#       <td id="T_9b1e0_row9_col1" class="data row9 col1" >is</td>
#       <td id="T_9b1e0_row9_col2" class="data row9 col2" >defined</td>
#       <td id="T_9b1e0_row9_col3" class="data row9 col3" >PPH1</td>
#       <td id="T_9b1e0_row9_col4" class="data row9 col4" >VBZ</td>
#       <td id="T_9b1e0_row9_col5" class="data row9 col5" >VVN</td>
#       <td id="T_9b1e0_row9_col6" class="data row9 col6" >8</td>
#       <td id="T_9b1e0_row9_col7" class="data row9 col7" >19.75</td>
#       <td id="T_9b1e0_row9_col8" class="data row9 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_9b1e0_row10_col0" class="data row10 col0" >this</td>
#       <td id="T_9b1e0_row10_col1" class="data row10 col1" >is</td>
#       <td id="T_9b1e0_row10_col2" class="data row10 col2" >called</td>
#       <td id="T_9b1e0_row10_col3" class="data row10 col3" >DD1</td>
#       <td id="T_9b1e0_row10_col4" class="data row10 col4" >VBZ</td>
#       <td id="T_9b1e0_row10_col5" class="data row10 col5" >VVN</td>
#       <td id="T_9b1e0_row10_col6" class="data row10 col6" >8</td>
#       <td id="T_9b1e0_row10_col7" class="data row10 col7" >19.75</td>
#       <td id="T_9b1e0_row10_col8" class="data row10 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_9b1e0_row11_col0" class="data row11 col0" >can</td>
#       <td id="T_9b1e0_row11_col1" class="data row11 col1" >be</td>
#       <td id="T_9b1e0_row11_col2" class="data row11 col2" >discarded</td>
#       <td id="T_9b1e0_row11_col3" class="data row11 col3" >VM</td>
#       <td id="T_9b1e0_row11_col4" class="data row11 col4" >VBI</td>
#       <td id="T_9

# %% [markdown]
# Similar ngram tables can be created for DocuScope sequences. Here we generate trigrams again:

# %%
ngram_freq_table_DS = ngrams_table(
    tok=tp,
    ng_span=3,
    n_tokens=corpus_total,
    count_by='ds'
)

# %%
ngram_freq_table_DS.head(10).style.hide(axis='index').format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_6c7c4">
#   <thead>
#     <tr>
#       <th id="T_6c7c4_level0_col0" class="col_heading level0 col0" >Token1</th>
#       <th id="T_6c7c4_level0_col1" class="col_heading level0 col1" >Token2</th>
#       <th id="T_6c7c4_level0_col2" class="col_heading level0 col2" >Token3</th>
#       <th id="T_6c7c4_level0_col3" class="col_heading level0 col3" >Tag1</th>
#       <th id="T_6c7c4_level0_col4" class="col_heading level0 col4" >Tag2</th>
#       <th id="T_6c7c4_level0_col5" class="col_heading level0 col5" >Tag3</th>
#       <th id="T_6c7c4_level0_col6" class="col_heading level0 col6" >AF</th>
#       <th id="T_6c7c4_level0_col7" class="col_heading level0 col7" >RF</th>
#       <th id="T_6c7c4_level0_col8" class="col_heading level0 col8" >Range</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_6c7c4_row0_col0" class="data row0 col0" >the</td>
#       <td id="T_6c7c4_row0_col1" class="data row0 col1" >number</td>
#       <td id="T_6c7c4_row0_col2" class="data row0 col2" >of</td>
#       <td id="T_6c7c4_row0_col3" class="data row0 col3" >Untagged</td>
#       <td id="T_6c7c4_row0_col4" class="data row0 col4" >Untagged</td>
#       <td id="T_6c7c4_row0_col5" class="data row0 col5" >Untagged</td>
#       <td id="T_6c7c4_row0_col6" class="data row0 col6" >181</td>
#       <td id="T_6c7c4_row0_col7" class="data row0 col7" >356.75</td>
#       <td id="T_6c7c4_row0_col8" class="data row0 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_6c7c4_row1_col0" class="data row1 col0" >%</td>
#       <td id="T_6c7c4_row1_col1" class="data row1 col1" >of</td>
#       <td id="T_6c7c4_row1_col2" class="data row1 col2" >the</td>
#       <td id="T_6c7c4_row1_col3" class="data row1 col3" >InformationExposition</td>
#       <td id="T_6c7c4_row1_col4" class="data row1 col4" >Untagged</td>
#       <td id="T_6c7c4_row1_col5" class="data row1 col5" >Untagged</td>
#       <td id="T_6c7c4_row1_col6" class="data row1 col6" >131</td>
#       <td id="T_6c7c4_row1_col7" class="data row1 col7" >258.20</td>
#       <td id="T_6c7c4_row1_col8" class="data row1 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_6c7c4_row2_col0" class="data row2 col0" >the</td>
#       <td id="T_6c7c4_row2_col1" class="data row2 col1" >distribution</td>
#       <td id="T_6c7c4_row2_col2" class="data row2 col2" >of</td>
#       <td id="T_6c7c4_row2_col3" class="data row2 col3" >Untagged</td>
#       <td id="T_6c7c4_row2_col4" class="data row2 col4" >AcademicTerms</td>
#       <td id="T_6c7c4_row2_col5" class="data row2 col5" >Untagged</td>
#       <td id="T_6c7c4_row2_col6" class="data row2 col6" >102</td>
#       <td id="T_6c7c4_row2_col7" class="data row2 col7" >201.04</td>
#       <td id="T_6c7c4_row2_col8" class="data row2 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_6c7c4_row3_col0" class="data row3 col0" >there</td>
#       <td id="T_6c7c4_row3_col1" class="data row3 col1" >is</td>
#       <td id="T_6c7c4_row3_col2" class="data row3 col2" >a</td>
#       <td id="T_6c7c4_row3_col3" class="data row3 col3" >Untagged</td>
#       <td id="T_6c7c4_row3_col4" class="data row3 col4" >Untagged</td>
#       <td id="T_6c7c4_row3_col5" class="data row3 col5" >Untagged</td>
#       <td id="T_6c7c4_row3_col6" class="data row3 col6" >97</td>
#       <td id="T_6c7c4_row3_col7" class="data row3 col7" >191.19</td>
#       <td id="T_6c7c4_row3_col8" class="data row3 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_6c7c4_row4_col0" class="data row4 col0" >some</td>
#       <td id="T_6c7c4_row4_col1" class="data row4 col1" >of</td>
#       <td id="T_6c7c4_row4_col2" class="data row4 col2" >the</td>
#       <td id="T_6c7c4_row4_col3" class="data row4 col3" >Untagged</td>
#       <td id="T_6c7c4_row4_col4" class="data row4 col4" >Untagged</td>
#       <td id="T_6c7c4_row4_col5" class="data row4 col5" >Untagged</td>
#       <td id="T_6c7c4_row4_col6" class="data row4 col6" >91</td>
#       <td id="T_6c7c4_row4_col7" class="data row4 col7" >179.36</td>
#       <td id="T_6c7c4_row4_col8" class="data row4 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_6c7c4_row5_col0" class="data row5 col0" >in</td>
#       <td id="T_6c7c4_row5_col1" class="data row5 col1" >terms</td>
#       <td id="T_6c7c4_row5_col2" class="data row5 col2" >of</td>
#       <td id="T_6c7c4_row5_col3" class="data row5 col3" >Untagged</td>
#       <td id="T_6c7c4_row5_col4" class="data row5 col4" >Untagged</td>
#       <td id="T_6c7c4_row5_col5" class="data row5 col5" >Untagged</td>
#       <td id="T_6c7c4_row5_col6" class="data row5 col6" >76</td>
#       <td id="T_6c7c4_row5_col7" class="data row5 col7" >149.80</td>
#       <td id="T_6c7c4_row5_col8" class="data row5 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_6c7c4_row6_col0" class="data row6 col0" >of</td>
#       <td id="T_6c7c4_row6_col1" class="data row6 col1" >the</td>
#       <td id="T_6c7c4_row6_col2" class="data row6 col2" >data</td>
#       <td id="T_6c7c4_row6_col3" class="data row6 col3" >Untagged</td>
#       <td id="T_6c7c4_row6_col4" class="data row6 col4" >Untagged</td>
#       <td id="T_6c7c4_row6_col5" class="data row6 col5" >AcademicTerms</td>
#       <td id="T_6c7c4_row6_col6" class="data row6 col6" >75</td>
#       <td id="T_6c7c4_row6_col7" class="data row6 col7" >147.82</td>
#       <td id="T_6c7c4_row6_col8" class="data row6 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_6c7c4_row7_col0" class="data row7 col0" >use</td>
#       <td id="T_6c7c4_row7_col1" class="data row7 col1" >on</td>
#       <td id="T_6c7c4_row7_col2" class="data row7 col2" >a</td>
#       <td id="T_6c7c4_row7_col3" class="data row7 col3" >Untagged</td>
#       <td id="T_6c7c4_row7_col4" class="data row7 col4" >Untagged</td>
#       <td id="T_6c7c4_row7_col5" class="data row7 col5" >Untagged</td>
#       <td id="T_6c7c4_row7_col6" class="data row7 col6" >70</td>
#       <td id="T_6c7c4_row7_col7" class="data row7 col7" >137.97</td>
#       <td id="T_6c7c4_row7_col8" class="data row7 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_6c7c4_row8_col0" class="data row8 col0" >as</td>
#       <td id="T_6c7c4_row8_col1" class="data row8 col1" >well</td>
#       <td id="T_6c7c4_row8_col2" class="data row8 col2" >as</td>
#       <td id="T_6c7c4_row8_col3" class="data row8 col3" >Untagged</td>
#       <td id="T_6c7c4_row8_col4" class="data row8 col4" >Untagged</td>
#       <td id="T_6c7c4_row8_col5" class="data row8 col5" >Untagged</td>
#       <td id="T_6c7c4_row8_col6" class="data row8 col6" >68</td>
#       <td id="T_6c7c4_row8_col7" class="data row8 col7" >134.03</td>
#       <td id="T_6c7c4_row8_col8" class="data row8 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_6c7c4_row9_col0" class="data row9 col0" >of</td>
#       <td id="T_6c7c4_row9_col1" class="data row9 col1" >the</td>
#       <td id="T_6c7c4_row9_col2" class="data row9 col2" >following</td>
#       <td id="T_6c7c4_row9_col3" class="data row9 col3" >Untagged</td>
#       <td id="T_6c7c4_row9_col4" class="data row9 col4" >Untagged</td>
#       <td id="T_6c7c4_row9_col5" class="data row9 col5" >Narrative</td>
#       <td id="T_6c7c4_row9_col6" class="data row9 col6" >68</td>
#       <td id="T_6c7c4_row9_col7" class="data row9 col7" >134.03</td>
#       <td id="T_6c7c4_row9_col8" class="data row9 col8" >100.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Let's find a sequence tagged as ‘Positive’ on the right and on the left we filter out Untagged (‘O’) and ‘Syntactic Complexity’:

# %%
ngram_freq_table_DS.query('Tag1.str.startswith("Positive") and (~Tag2.str.startswith("Syntactic") and ~Tag2.str.startswith("Untagged") and ~Tag3.str.startswith("Untagged"))').head(10).style.hide(axis='index').format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_ccd97">
#   <thead>
#     <tr>
#       <th id="T_ccd97_level0_col0" class="col_heading level0 col0" >Token1</th>
#       <th id="T_ccd97_level0_col1" class="col_heading level0 col1" >Token2</th>
#       <th id="T_ccd97_level0_col2" class="col_heading level0 col2" >Token3</th>
#       <th id="T_ccd97_level0_col3" class="col_heading level0 col3" >Tag1</th>
#       <th id="T_ccd97_level0_col4" class="col_heading level0 col4" >Tag2</th>
#       <th id="T_ccd97_level0_col5" class="col_heading level0 col5" >Tag3</th>
#       <th id="T_ccd97_level0_col6" class="col_heading level0 col6" >AF</th>
#       <th id="T_ccd97_level0_col7" class="col_heading level0 col7" >RF</th>
#       <th id="T_ccd97_level0_col8" class="col_heading level0 col8" >Range</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ccd97_row0_col0" class="data row0 col0" >favorite</td>
#       <td id="T_ccd97_row0_col1" class="data row0 col1" >media</td>
#       <td id="T_ccd97_row0_col2" class="data row0 col2" >sources</td>
#       <td id="T_ccd97_row0_col3" class="data row0 col3" >Positive</td>
#       <td id="T_ccd97_row0_col4" class="data row0 col4" >PublicTerms</td>
#       <td id="T_ccd97_row0_col5" class="data row0 col5" >AcademicTerms</td>
#       <td id="T_ccd97_row0_col6" class="data row0 col6" >16</td>
#       <td id="T_ccd97_row0_col7" class="data row0 col7" >31.54</td>
#       <td id="T_ccd97_row0_col8" class="data row0 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_ccd97_row1_col0" class="data row1 col0" >ethical</td>
#       <td id="T_ccd97_row1_col1" class="data row1 col1" >ai products</td>
#       <td id="T_ccd97_row1_col2" class="data row1 col2" >in your</td>
#       <td id="T_ccd97_row1_col3" class="data row1 col3" >Positive</td>
#       <td id="T_ccd97_row1_col4" class="data row1 col4" >InformationTopics</td>
#       <td id="T_ccd97_row1_col5" class="data row1 col5" >Interactive</td>
#       <td id="T_ccd97_row1_col6" class="data row1 col6" >10</td>
#       <td id="T_ccd97_row1_col7" class="data row1 col7" >19.71</td>
#       <td id="T_ccd97_row1_col8" class="data row1 col8" >33.33</td>
#     </tr>
#     <tr>
#       <td id="T_ccd97_row2_col0" class="data row2 col0" >our</td>
#       <td id="T_ccd97_row2_col1" class="data row2 col1" >machine</td>
#       <td id="T_ccd97_row2_col2" class="data row2 col2" >learning</td>
#       <td id="T_ccd97_row2_col3" class="data row2 col3" >Positive</td>
#       <td id="T_ccd97_row2_col4" class="data row2 col4" >AcademicTerms</td>
#       <td id="T_ccd97_row2_col5" class="data row2 col5" >Inquiry</td>
#       <td id="T_ccd97_row2_col6" class="data row2 col6" >10</td>
#       <td id="T_ccd97_row2_col7" class="data row2 col7" >19.71</td>
#       <td id="T_ccd97_row2_col8" class="data row2 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_ccd97_row3_col0" class="data row3 col0" >our</td>
#       <td id="T_ccd97_row3_col1" class="data row3 col1" >model</td>
#       <td id="T_ccd97_row3_col2" class="data row3 col2" >is</td>
#       <td id="T_ccd97_row3_col3" class="data row3 col3" >Positive</td>
#       <td id="T_ccd97_row3_col4" class="data row3 col4" >AcademicTerms</td>
#       <td id="T_ccd97_row3_col5" class="data row3 col5" >InformationStates</td>
#       <td id="T_ccd97_row3_col6" class="data row3 col6" >10</td>
#       <td id="T_ccd97_row3_col7" class="data row3 col7" >19.71</td>
#       <td id="T_ccd97_row3_col8" class="data row3 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_ccd97_row4_col0" class="data row4 col0" >precision</td>
#       <td id="T_ccd97_row4_col1" class="data row4 col1" >recall</td>
#       <td id="T_ccd97_row4_col2" class="data row4 col2" >curve</td>
#       <td id="T_ccd97_row4_col3" class="data row4 col3" >Positive</td>
#       <td id="T_ccd97_row4_col4" class="data row4 col4" >Character</td>
#       <td id="T_ccd97_row4_col5" class="data row4 col5" >Description</td>
#       <td id="T_ccd97_row4_col6" class="data row4 col6" >10</td>
#       <td id="T_ccd97_row4_col7" class="data row4 col7" >19.71</td>
#       <td id="T_ccd97_row4_col8" class="data row4 col8" >66.67</td>
#     </tr>
#     <tr>
#       <td id="T_ccd97_row5_col0" class="data row5 col0" >support</td>
#       <td id="T_ccd97_row5_col1" class="data row5 col1" >vector</td>
#       <td id="T_ccd97_row5_col2" class="data row5 col2" >machines</td>
#       <td id="T_ccd97_row5_col3" class="data row5 col3" >Positive</td>
#       <td id="T_ccd97_row5_col4" class="data row5 col4" >AcademicTerms</td>
#       <td id="T_ccd97_row5_col5" class="data row5 col5" >Description</td>
#       <td id="T_ccd97_row5_col6" class="data row5 col6" >9</td>
#       <td id="T_ccd97_row5_col7" class="data row5 col7" >17.74</td>
#       <td id="T_ccd97_row5_col8" class="data row5 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_ccd97_row6_col0" class="data row6 col0" >accuracy</td>
#       <td id="T_ccd97_row6_col1" class="data row6 col1" >precision</td>
#       <td id="T_ccd97_row6_col2" class="data row6 col2" >recall</td>
#       <td id="T_ccd97_row6_col3" class="data row6 col3" >Positive</td>
#       <td id="T_ccd97_row6_col4" class="data row6 col4" >Positive</td>
#       <td id="T_ccd97_row6_col5" class="data row6 col5" >Character</td>
#       <td id="T_ccd97_row6_col6" class="data row6 col6" >8</td>
#       <td id="T_ccd97_row6_col7" class="data row6 col7" >15.77</td>
#       <td id="T_ccd97_row6_col8" class="data row6 col8" >33.33</td>
#     </tr>
#     <tr>
#       <td id="T_ccd97_row7_col0" class="data row7 col0" >accepted the</td>
#       <td id="T_ccd97_row7_col1" class="data row7 col1" >personal</td>
#       <td id="T_ccd97_row7_col2" class="data row7 col2" >loan</td>
#       <td id="T_ccd97_row7_col3" class="data row7 col3" >Positive</td>
#       <td id="T_ccd97_row7_col4" class="data row7 col4" >Character</td>
#       <td id="T_ccd97_row7_col5" class="data row7 col5" >AcademicTerms</td>
#       <td id="T_ccd97_row7_col6" class="data row7 col6" >6</td>
#       <td id="T_ccd97_row7_col7" class="data row7 col7" >11.83</td>
#       <td id="T_ccd97_row7_col8" class="data row7 col8" >33.33</td>
#     </tr>
#     <tr>
#       <td id="T_ccd97_row8_col0" class="data row8 col0" >confirms</td>
#       <td id="T_ccd97_row8_col1" class="data row8 col1" >our</td>
#       <td id="T_ccd97_row8_col2" class="data row8 col2" >assumption</td>
#       <td id="T_ccd97_row8_col3" class="data row8 col3" >Positive</td>
#       <td id="T_ccd97_row8_col4" class="data row8 col4" >Positive</td>
#       <td id="T_ccd97_row8_col5" class="data row8 col5" >Character</td>
#       <td id="T_ccd97_row8_col6" class="data row8 col6" >6</td>
#       <td id="T_ccd97_row8_col7" class="data row8 col7" >11.83</td>
#       <td id="T_ccd97_row8_col8" class="data row8 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_ccd97_row9_col0" class="data row9 col0" >our</td>
#       <td id="T_ccd97_row9_col1" class="data row9 col1" >classifying</td>
#       <td id="T_ccd97_row9_col2" class="data row9 col2" >assumption</td>
#       <td id="T_ccd97_row9_col3" class="data row9 col3" >Positive</td>
#       <td id="T_ccd97_row9_col4" class="data row9 col4" >Description</td>
#       <td id="T_ccd97_row9_col5" class="data row9 col5" >Character</td>
#       <td id="T_ccd97_row9_col6" class="data row9 col6" >6</td>
#       <td id="T_ccd97_row9_col7" class="data row9 col7" >11.83</td>
#       <td id="T_ccd97_row9_col8" class="data row9 col8" >66.67</td>
#     </tr>
#   </tbody>
# </table>

# %%
ngram_freq_table_DS.query('Tag1.str.startswith("Negative") and (~Tag2.str.startswith("Syntactic") and ~Tag2.str.startswith("Untagged") and ~Tag3.str.startswith("Untagged"))').head(10).style.hide(axis='index').format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_67ff5">
#   <thead>
#     <tr>
#       <th id="T_67ff5_level0_col0" class="col_heading level0 col0" >Token1</th>
#       <th id="T_67ff5_level0_col1" class="col_heading level0 col1" >Token2</th>
#       <th id="T_67ff5_level0_col2" class="col_heading level0 col2" >Token3</th>
#       <th id="T_67ff5_level0_col3" class="col_heading level0 col3" >Tag1</th>
#       <th id="T_67ff5_level0_col4" class="col_heading level0 col4" >Tag2</th>
#       <th id="T_67ff5_level0_col5" class="col_heading level0 col5" >Tag3</th>
#       <th id="T_67ff5_level0_col6" class="col_heading level0 col6" >AF</th>
#       <th id="T_67ff5_level0_col7" class="col_heading level0 col7" >RF</th>
#       <th id="T_67ff5_level0_col8" class="col_heading level0 col8" >Range</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_67ff5_row0_col0" class="data row0 col0" >against the</td>
#       <td id="T_67ff5_row0_col1" class="data row0 col1" >false</td>
#       <td id="T_67ff5_row0_col2" class="data row0 col2" >positive rate</td>
#       <td id="T_67ff5_row0_col3" class="data row0 col3" >Negative</td>
#       <td id="T_67ff5_row0_col4" class="data row0 col4" >Negative</td>
#       <td id="T_67ff5_row0_col5" class="data row0 col5" >InformationTopics</td>
#       <td id="T_67ff5_row0_col6" class="data row0 col6" >7</td>
#       <td id="T_67ff5_row0_col7" class="data row0 col7" >13.80</td>
#       <td id="T_67ff5_row0_col8" class="data row0 col8" >33.33</td>
#     </tr>
#     <tr>
#       <td id="T_67ff5_row1_col0" class="data row1 col0" >onlinebackup</td>
#       <td id="T_67ff5_row1_col1" class="data row1 col1" >deviceprotection</td>
#       <td id="T_67ff5_row1_col2" class="data row1 col2" >techsupport</td>
#       <td id="T_67ff5_row1_col3" class="data row1 col3" >Negative</td>
#       <td id="T_67ff5_row1_col4" class="data row1 col4" >Description</td>
#       <td id="T_67ff5_row1_col5" class="data row1 col5" >Description</td>
#       <td id="T_67ff5_row1_col6" class="data row1 col6" >7</td>
#       <td id="T_67ff5_row1_col7" class="data row1 col7" >13.80</td>
#       <td id="T_67ff5_row1_col8" class="data row1 col8" >66.67</td>
#     </tr>
#     <tr>
#       <td id="T_67ff5_row2_col0" class="data row2 col0" >onlinesecurity</td>
#       <td id="T_67ff5_row2_col1" class="data row2 col1" >onlinebackup</td>
#       <td id="T_67ff5_row2_col2" class="data row2 col2" >deviceprotection</td>
#       <td id="T_67ff5_row2_col3" class="data row2 col3" >Negative</td>
#       <td id="T_67ff5_row2_col4" class="data row2 col4" >Negative</td>
#       <td id="T_67ff5_row2_col5" class="data row2 col5" >Description</td>
#       <td id="T_67ff5_row2_col6" class="data row2 col6" >7</td>
#       <td id="T_67ff5_row2_col7" class="data row2 col7" >13.80</td>
#       <td id="T_67ff5_row2_col8" class="data row2 col8" >66.67</td>
#     </tr>
#     <tr>
#       <td id="T_67ff5_row3_col0" class="data row3 col0" >false</td>
#       <td id="T_67ff5_row3_col1" class="data row3 col1" >positive rate</td>
#       <td id="T_67ff5_row3_col2" class="data row3 col2" >fpr</td>
#       <td id="T_67ff5_row3_col3" class="data row3 col3" >Negative</td>
#       <td id="T_67ff5_row3_col4" class="data row3 col4" >InformationTopics</td>
#       <td id="T_67ff5_row3_col5" class="data row3 col5" >Description</td>
#       <td id="T_67ff5_row3_col6" class="data row3 col6" >6</td>
#       <td id="T_67ff5_row3_col7" class="data row3 col7" >11.83</td>
#       <td id="T_67ff5_row3_col8" class="data row3 col8" >66.67</td>
#     </tr>
#     <tr>
#       <td id="T_67ff5_row4_col0" class="data row4 col0" >partial</td>
#       <td id="T_67ff5_row4_col1" class="data row4 col1" >autocorrelation</td>
#       <td id="T_67ff5_row4_col2" class="data row4 col2" >function</td>
#       <td id="T_67ff5_row4_col3" class="data row4 col3" >Negative</td>
#       <td id="T_67ff5_row4_col4" class="data row4 col4" >AcademicTerms</td>
#       <td id="T_67ff5_row4_col5" class="data row4 col5" >AcademicTerms</td>
#       <td id="T_67ff5_row4_col6" class="data row4 col6" >6</td>
#       <td id="T_67ff5_row4_col7" class="data row4 col7" >11.83</td>
#       <td id="T_67ff5_row4_col8" class="data row4 col8" >33.33</td>
#     </tr>
#     <tr>
#       <td id="T_67ff5_row5_col0" class="data row5 col0" >suffering from</td>
#       <td id="T_67ff5_row5_col1" class="data row5 col1" >heart disease</td>
#       <td id="T_67ff5_row5_col2" class="data row5 col2" >target</td>
#       <td id="T_67ff5_row5_col3" class="data row5 col3" >Negative</td>
#       <td id="T_67ff5_row5_col4" class="data row5 col4" >AcademicTerms</td>
#       <td id="T_67ff5_row5_col5" class="data row5 col5" >Strategic</td>
#       <td id="T_67ff5_row5_col6" class="data row5 col6" >6</td>
#       <td id="T_67ff5_row5_col7" class="data row5 col7" >11.83</td>
#       <td id="T_67ff5_row5_col8" class="data row5 col8" >33.33</td>
#     </tr>
#     <tr>
#       <td id="T_67ff5_row6_col0" class="data row6 col0" >vs</td>
#       <td id="T_67ff5_row6_col1" class="data row6 col1" >group</td>
#       <td id="T_67ff5_row6_col2" class="data row6 col2" >2 :</td>
#       <td id="T_67ff5_row6_col3" class="data row6 col3" >Negative</td>
#       <td id="T_67ff5_row6_col4" class="data row6 col4" >InformationTopics</td>
#       <td id="T_67ff5_row6_col5" class="data row6 col5" >InformationExposition</td>
#       <td id="T_67ff5_row6_col6" class="data row6 col6" >6</td>
#       <td id="T_67ff5_row6_col7" class="data row6 col7" >11.83</td>
#       <td id="T_67ff5_row6_col8" class="data row6 col8" >33.33</td>
#     </tr>
#     <tr>
#       <td id="T_67ff5_row7_col0" class="data row7 col0" >. it is</td>
#       <td id="T_67ff5_row7_col1" class="data row7 col1" >defined as the</td>
#       <td id="T_67ff5_row7_col2" class="data row7 col2" >ratio</td>
#       <td id="T_67ff5_row7_col3" class="data row7 col3" >Negative</td>
#       <td id="T_67ff5_row7_col4" class="data row7 col4" >InformationExposition</td>
#       <td id="T_67ff5_row7_col5" class="data row7 col5" >AcademicTerms</td>
#       <td id="T_67ff5_row7_col6" class="data row7 col6" >5</td>
#       <td id="T_67ff5_row7_col7" class="data row7 col7" >9.85</td>
#       <td id="T_67ff5_row7_col8" class="data row7 col8" >33.33</td>
#     </tr>
#     <tr>
#       <td id="T_67ff5_row8_col0" class="data row8 col0" >no</td>
#       <td id="T_67ff5_row8_col1" class="data row8 col1" >formal</td>
#       <td id="T_67ff5_row8_col2" class="data row8 col2" >education</td>
#       <td id="T_67ff5_row8_col3" class="data row8 col3" >Negative</td>
#       <td id="T_67ff5_row8_col4" class="data row8 col4" >AcademicTerms</td>
#       <td id="T_67ff5_row8_col5" class="data row8 col5" >AcademicTerms</td>
#       <td id="T_67ff5_row8_col6" class="data row8 col6" >5</td>
#       <td id="T_67ff5_row8_col7" class="data row8 col7" >9.85</td>
#       <td id="T_67ff5_row8_col8" class="data row8 col8" >100.00</td>
#     </tr>
#     <tr>
#       <td id="T_67ff5_row9_col0" class="data row9 col0" >weak</td>
#       <td id="T_67ff5_row9_col1" class="data row9 col1" >negative</td>
#       <td id="T_67ff5_row9_col2" class="data row9 col2" >correlation</td>
#       <td id="T_67ff5_row9_col3" class="data row9 col3" >Negative</td>
#       <td id="T_67ff5_row9_col4" class="data row9 col4" >Negative</td>
#       <td id="T_67ff5_row9_col5" class="data row9 col5" >AcademicTerms</td>
#       <td id="T_67ff5_row9_col6" class="data row9 col6" >5</td>
#       <td id="T_67ff5_row9_col7" class="data row9 col7" >9.85</td>
#       <td id="T_67ff5_row9_col8" class="data row9 col8" >66.67</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### 4.3.8.5 Collocation Frequency Tables

# %% [markdown]
# Calculate *collocations* within a left-and-right span of a node word can be calculated according to several association measures.
#
# Default span is 4 tokens to the left and 4 tokens to the right of the node word.
#
# Like `frequency_table`, `coll_table` requires a dictionary of the type generated by the `convert_corpus` function. It also requires
#
# - a node word,
# - a node tag, and
# - an association measure statistic
#
# <blockquote>
# <h4><a href="https://docuscospacy.readthedocs.io/en/latest/api.html#corpus-analysis-coll-table-tok-node-word-l-span-4-r-span-4-statistic-pmi-count-by-pos-node-tag-none-tag-ignore-false">corpus_analysis.coll_table(tok, node_word, l_span=4, r_span=4, statistic=’pmi’, count_by=’pos’, node_tag=None, tag_ignore=False)</a></h4>
# <div><dl class="field-list simple">
# <dt class="field-odd">Parameters</dt>
# <dd class="field-odd"><ul class="simple">
# <li><p><strong>tok</strong> - A dictionary of tuples as generated by the <cite>convert_corpus</cite> function</p></li>
# <li><p><strong>node_word</strong> - The token around with collocations are measured</p></li>
# <li><p><strong>l_span</strong> - An integer between 0 and 9 representing the span to the left of the node word</p></li>
# <li><p><strong>r_span</strong> - An integer between 0 and 9 representing the span to the right of the node word</p></li>
# <li><p><strong>statistic</strong> - The association measure to be calculated. One of: ‘pmi’, ‘npmi’, ‘pmi2’, ‘pmi3’</p></li>
# <li><p><strong>count_by</strong> - One of ‘pos’ or ‘ds’ for aggregating tokens</p></li>
# <li><p><strong>node_tag</strong> - A value specifying the tag of the node word. If the node_word were ‘can’, a node_tag ‘V’ would search for can as a verb.</p></li>
# <li><p><strong>tag_ignore</strong> - A boolean value indicating whether or not tags should be ignored during analysis.</p></li>
# </ul>
# </dd>
# <dt class="field-even">Return</dt>
# <dd class="field-even"><ul class="simple">
# <li><p>a dataframe containing collocate tokens, tags, the absolute frequency the collocate in the corpus, the absolute frequency of the collocate within the designated span, and the association measure.</p></li>
# </ul>
# </dd>
# </dl>
# </div>
# </blockquote>

# %% [markdown]
# ##### POS tags

# %%
collocations_freq_table_POS = coll_table(
    tok=tp,
    node_word='can',
    node_tag='V',
    statistic='pmi',
    count_by='pos'
)
collocations_freq_table_POS.head(10).style.hide(axis='index').format(precision=2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\thoma\OneDrive\Documents\GitHub\3844f23-writing-digital-media\book\04-Textual-Analysis\4.1_POS-Docuscope_Keywords.ipynb Cell 99 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/thoma/OneDrive/Documents/GitHub/3844f23-writing-digital-media/book/04-Textual-Analysis/4.1_POS-Docuscope_Keywords.ipynb#Y200sZmlsZQ%3D%3D?line=0'>1</a> collocations_freq_table_POS = coll_table(
#       <a href='vscode-notebook-cell:/c%3A/Users/thoma/OneDrive/Documents/GitHub/3844f23-writing-digital-media/book/04-Textual-Analysis/4.1_POS-Docuscope_Keywords.ipynb#Y200sZmlsZQ%3D%3D?line=1'>2</a>     tok=tp,
#       <a href='vscode-notebook-cell:/c%3A/Users/thoma/OneDrive/Documents/GitHub/3844f23-writing-digital-media/book/04-Textual-Analysis/4.1_POS-Docuscope_Keywords.ipynb#Y200sZmlsZQ%3D%3D?line=2'>3</a>     node_word='can',
#       <a href='vscode-notebook-cell:/c%3A/Users/thoma/OneDrive/Documents/GitHub/3844f23-writing-digital-media/book/04-Textual-Analysis/4.1_POS-Docuscope_Keywords.ipynb#Y200sZmlsZQ%3D%3D?line=3'>4</a>     node_tag='V',
#       <a href='vscode-notebook-cell:/c%3A/Users/thoma/OneDrive/Documents/GitHub/3844f23-writing-digital-media/book/04-Textual-Analysis/4.1_POS-Docuscope_Keywords.ipynb#Y200sZmlsZQ%3D%3D?line=4'>5</a>     statistic='pmi',
#       <a href='vscode-notebook-cell:/c%3A/Users/thoma/OneDrive/Documents/GitHub/3844f23-writing-digital-media/book/04-Textual-Analysis/4.1_POS-Docuscope_Keywords.ipynb#Y200sZmlsZQ%3D%3D?line=5'>6</a>     count_by='pos'
#       <a href='vscode-notebook-cell:/c%3A/Users/thoma/OneDrive/Documents/GitHub/3844f23-writing-digital-media/book/04-Textual-Analysis/4.1_POS-Docuscope_Keywords.ipynb#Y200sZmlsZQ%3D%3D?line=6'>7</a> )
#       <a href='vscode-notebook-cell:/c%3A/Users/thoma/OneDrive/Documents/GitHub/3844f23-writing-digital-media/book/04-Textual-Analysis/4.1_POS-Docuscope_Keywords.ipynb#Y200sZmlsZQ%3D%3D?line=7'>8</a> collocations_freq_table_POS.head(10).style.hide(axis='index').format(precision=2)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\docuscospacy\corpus_analysis.py:249, in coll_table(tok, node_word, l_span, r_span, statistic, count_by, node_tag, tag_ignore)
#     247     df = pd.merge(df_span, df_total, how='inner', on=['Token', 'Tag'])
#     248 if statistic=='pmi':
# --> 249     df['MI'] = pmi(node_freq, df['Freq Total'], df['Freq Span'], sum(df_total['Freq Total']), normalize=False)
#     250 if statistic=='npmi':
#     251     df['MI'] = pmi(node_freq, df['Freq Total'], df['Freq Span'], sum(df_total['Freq Total']), normalize=True)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tmtoolkit\tokenseq\_metrics.py:62, in pmi(x, y, xy, n_total, logfn, k, alpha, normalize)
#      59 if k > 1 and normalize:
#      60     raise ValueError('normalization is only implemented for standard PMI with `k=1`')
# ---> 62 if x.ndim == 1:
#      63     if y is None or xy is None or x.shape != y.shape or x.shape != xy.shape:
#      64         raise ValueError('if `x` is given as vector, `y` and `xy` must also be given and must have the same length')
#
# AttributeError: 'int' object has no attribute 'ndim'

# %%
collocations_freq_table_POS.query('`Freq Total` > 5 and MI > 3 and Tag.str.startswith("V")').head(10).style.hide(axis='index').format(precision=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\thoma\OneDrive\Documents\GitHub\3844f23-writing-digital-media\book\04-Textual-Analysis\4.1_POS-Docuscope_Keywords.ipynb Cell 100 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/thoma/OneDrive/Documents/GitHub/3844f23-writing-digital-media/book/04-Textual-Analysis/4.1_POS-Docuscope_Keywords.ipynb#Y201sZmlsZQ%3D%3D?line=0'>1</a> collocations_freq_table_POS.query('`Freq Total` > 5 and MI > 3 and Tag.str.startswith("V")').head(10).style.hide(axis='index').format(precision=2)
#
# NameError: name 'collocations_freq_table_POS' is not defined

# %%
collocations_freq_table_POS_npmi = coll_table(
    tok=tp,
    node_word='data',
    node_tag='N',
    statistic='npmi',
    count_by='pos',
    # tag_ignore=True
)
collocations_freq_table_POS_npmi.head(10).style.hide(axis='index').format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_4d8ca">
#   <thead>
#     <tr>
#       <th id="T_4d8ca_level0_col0" class="col_heading level0 col0" >Token</th>
#       <th id="T_4d8ca_level0_col1" class="col_heading level0 col1" >Tag</th>
#       <th id="T_4d8ca_level0_col2" class="col_heading level0 col2" >Freq Span</th>
#       <th id="T_4d8ca_level0_col3" class="col_heading level0 col3" >Freq Total</th>
#       <th id="T_4d8ca_level0_col4" class="col_heading level0 col4" >MI</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4d8ca_row0_col0" class="data row0 col0" >science</td>
#       <td id="T_4d8ca_row0_col1" class="data row0 col1" >NN1</td>
#       <td id="T_4d8ca_row0_col2" class="data row0 col2" >424</td>
#       <td id="T_4d8ca_row0_col3" class="data row0 col3" >400</td>
#       <td id="T_4d8ca_row0_col4" class="data row0 col4" >0.69</td>
#     </tr>
#     <tr>
#       <td id="T_4d8ca_row1_col0" class="data row1 col0" >scientists</td>
#       <td id="T_4d8ca_row1_col1" class="data row1 col1" >NN2</td>
#       <td id="T_4d8ca_row1_col2" class="data row1 col2" >209</td>
#       <td id="T_4d8ca_row1_col3" class="data row1 col3" >220</td>
#       <td id="T_4d8ca_row1_col4" class="data row1 col4" >0.61</td>
#     </tr>
#     <tr>
#       <td id="T_4d8ca_row2_col0" class="data row2 col0" >relational</td>
#       <td id="T_4d8ca_row2_col1" class="data row2 col1" >JJ</td>
#       <td id="T_4d8ca_row2_col2" class="data row2 col2" >37</td>
#       <td id="T_4d8ca_row2_col3" class="data row2 col3" >14</td>
#       <td id="T_4d8ca_row2_col4" class="data row2 col4" >0.61</td>
#     </tr>
#     <tr>
#       <td id="T_4d8ca_row3_col0" class="data row3 col0" >scientist</td>
#       <td id="T_4d8ca_row3_col1" class="data row3 col1" >NN1</td>
#       <td id="T_4d8ca_row3_col2" class="data row3 col2" >142</td>
#       <td id="T_4d8ca_row3_col3" class="data row3 col3" >141</td>
#       <td id="T_4d8ca_row3_col4" class="data row3 col4" >0.59</td>
#     </tr>
#     <tr>
#       <td id="T_4d8ca_row4_col0" class="data row4 col0" >databases</td>
#       <td id="T_4d8ca_row4_col1" class="data row4 col1" >NN2</td>
#       <td id="T_4d8ca_row4_col2" class="data row4 col2" >37</td>
#       <td id="T_4d8ca_row4_col3" class="data row4 col3" >22</td>
#       <td id="T_4d8ca_row4_col4" class="data row4 col4" >0.56</td>
#     </tr>
#     <tr>
#       <td id="T_4d8ca_row5_col0" class="data row5 col0" >lakes</td>
#       <td id="T_4d8ca_row5_col1" class="data row5 col1" >NN2</td>
#       <td id="T_4d8ca_row5_col2" class="data row5 col2" >24</td>
#       <td id="T_4d8ca_row5_col3" class="data row5 col3" >13</td>
#       <td id="T_4d8ca_row5_col4" class="data row5 col4" >0.54</td>
#     </tr>
#     <tr>
#       <td id="T_4d8ca_row6_col0" class="data row6 col0" >exploratory</td>
#       <td id="T_4d8ca_row6_col1" class="data row6 col1" >JJ</td>
#       <td id="T_4d8ca_row6_col2" class="data row6 col2" >69</td>
#       <td id="T_4d8ca_row6_col3" class="data row6 col3" >67</td>
#       <td id="T_4d8ca_row6_col4" class="data row6 col4" >0.54</td>
#     </tr>
#     <tr>
#       <td id="T_4d8ca_row7_col0" class="data row7 col0" >warehouses</td>
#       <td id="T_4d8ca_row7_col1" class="data row7 col1" >NN2</td>
#       <td id="T_4d8ca_row7_col2" class="data row7 col2" >20</td>
#       <td id="T_4d8ca_row7_col3" class="data row7 col3" >10</td>
#       <td id="T_4d8ca_row7_col4" class="data row7 col4" >0.54</td>
#     </tr>
#     <tr>
#       <td id="T_4d8ca_row8_col0" class="data row8 col0" >analysts</td>
#       <td id="T_4d8ca_row8_col1" class="data row8 col1" >NN2</td>
#       <td id="T_4d8ca_row8_col2" class="data row8 col2" >69</td>
#       <td id="T_4d8ca_row8_col3" class="data row8 col3" >76</td>
#       <td id="T_4d8ca_row8_col4" class="data row8 col4" >0.53</td>
#     </tr>
#     <tr>
#       <td id="T_4d8ca_row9_col0" class="data row9 col0" >analyst</td>
#       <td id="T_4d8ca_row9_col1" class="data row9 col1" >NN1</td>
#       <td id="T_4d8ca_row9_col2" class="data row9 col2" >42</td>
#       <td id="T_4d8ca_row9_col3" class="data row9 col3" >44</td>
#       <td id="T_4d8ca_row9_col4" class="data row9 col4" >0.50</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ##### DS tags

# %%
# DS Time!
collocations_freq_table_DS_npmi = coll_table(
    tok=tp,
    node_word='data',
    node_tag='Academic Terms',
    statistic='npmi', 
    count_by='ds'
)
collocations_freq_table_DS_npmi.head(10).style.hide(axis='index').format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_30f40">
#   <thead>
#     <tr>
#       <th id="T_30f40_level0_col0" class="col_heading level0 col0" >Freq Span</th>
#       <th id="T_30f40_level0_col1" class="col_heading level0 col1" >Token</th>
#       <th id="T_30f40_level0_col2" class="col_heading level0 col2" >Tag</th>
#       <th id="T_30f40_level0_col3" class="col_heading level0 col3" >Freq Total</th>
#       <th id="T_30f40_level0_col4" class="col_heading level0 col4" >MI</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %% [markdown]
# We can also calculate collocations, while ignoring tags completely by setting `tag_ignore` to `True`

# %%
collocations_freq_table_DS_npmi_ignore_tag = coll_table(
    tok=tp,
    # Dial up the span of words to search for
    l_span=6,
    r_span=6,
    node_word='justice',
    tag_ignore=True, 
    statistic='npmi'
)
# Note the sorting method used too
collocations_freq_table_DS_npmi_ignore_tag.sort_values(by=['Freq Total'], ascending=False).head(10).style.hide(axis='index').format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_bd8c1">
#   <thead>
#     <tr>
#       <th id="T_bd8c1_level0_col0" class="col_heading level0 col0" >Token</th>
#       <th id="T_bd8c1_level0_col1" class="col_heading level0 col1" >Freq Span</th>
#       <th id="T_bd8c1_level0_col2" class="col_heading level0 col2" >Freq Total</th>
#       <th id="T_bd8c1_level0_col3" class="col_heading level0 col3" >MI</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_bd8c1_row0_col0" class="data row0 col0" >the</td>
#       <td id="T_bd8c1_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_bd8c1_row0_col2" class="data row0 col2" >23078</td>
#       <td id="T_bd8c1_row0_col3" class="data row0 col3" >0.22</td>
#     </tr>
#     <tr>
#       <td id="T_bd8c1_row1_col0" class="data row1 col0" >of</td>
#       <td id="T_bd8c1_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_bd8c1_row1_col2" class="data row1 col2" >10582</td>
#       <td id="T_bd8c1_row1_col3" class="data row1 col3" >0.28</td>
#     </tr>
#     <tr>
#       <td id="T_bd8c1_row2_col0" class="data row2 col0" >to</td>
#       <td id="T_bd8c1_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_bd8c1_row2_col2" class="data row2 col2" >8717</td>
#       <td id="T_bd8c1_row2_col3" class="data row2 col3" >0.29</td>
#     </tr>
#     <tr>
#       <td id="T_bd8c1_row3_col0" class="data row3 col0" >and</td>
#       <td id="T_bd8c1_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_bd8c1_row3_col2" class="data row3 col2" >8013</td>
#       <td id="T_bd8c1_row3_col3" class="data row3 col3" >0.30</td>
#     </tr>
#     <tr>
#       <td id="T_bd8c1_row4_col0" class="data row4 col0" >that</td>
#       <td id="T_bd8c1_row4_col1" class="data row4 col1" >1</td>
#       <td id="T_bd8c1_row4_col2" class="data row4 col2" >4346</td>
#       <td id="T_bd8c1_row4_col3" class="data row4 col3" >0.35</td>
#     </tr>
#     <tr>
#       <td id="T_bd8c1_row5_col0" class="data row5 col0" >it</td>
#       <td id="T_bd8c1_row5_col1" class="data row5 col1" >1</td>
#       <td id="T_bd8c1_row5_col2" class="data row5 col2" >3140</td>
#       <td id="T_bd8c1_row5_col3" class="data row5 col3" >0.37</td>
#     </tr>
#     <tr>
#       <td id="T_bd8c1_row6_col0" class="data row6 col0" >do</td>
#       <td id="T_bd8c1_row6_col1" class="data row6 col1" >1</td>
#       <td id="T_bd8c1_row6_col2" class="data row6 col2" >972</td>
#       <td id="T_bd8c1_row6_col3" class="data row6 col3" >0.47</td>
#     </tr>
#     <tr>
#       <td id="T_bd8c1_row7_col0" class="data row7 col0" >hope</td>
#       <td id="T_bd8c1_row7_col1" class="data row7 col1" >1</td>
#       <td id="T_bd8c1_row7_col2" class="data row7 col2" >39</td>
#       <td id="T_bd8c1_row7_col3" class="data row7 col3" >0.72</td>
#     </tr>
#     <tr>
#       <td id="T_bd8c1_row8_col0" class="data row8 col0" >concept</td>
#       <td id="T_bd8c1_row8_col1" class="data row8 col1" >1</td>
#       <td id="T_bd8c1_row8_col2" class="data row8 col2" >19</td>
#       <td id="T_bd8c1_row8_col3" class="data row8 col3" >0.77</td>
#     </tr>
#     <tr>
#       <td id="T_bd8c1_row9_col0" class="data row9 col0" >ensembling</td>
#       <td id="T_bd8c1_row9_col1" class="data row9 col1" >1</td>
#       <td id="T_bd8c1_row9_col2" class="data row9 col2" >14</td>
#       <td id="T_bd8c1_row9_col3" class="data row9 col3" >0.79</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 4.4 Document-term matrices for tags

# %% [markdown]
# Document-term matrices (DTMs) are basic data structures for text analysis. Each row is a document (observation) and each column is a token (variable). These can be produced by tmtoolkit) using the `dtm` function.
#
# The `docuscopspacy` package allows for the creation of DTMs with (*raw*) tag counts (rather than token counts) as variables.
#
# These are produced by the `tags_dtm` function, which takes a dictionary created by the `convert_corpus` function and a `count_by` argument of either `‘pos’` or `‘ds’`.

# %% [markdown]
# ### 4.4.1 POS DTM

# %%
dtm_POS = tags_dtm(
    tok=tp,
    count_by='pos'
)

# %%
dtm_POS.head(10).style.hide(axis='index').format(precision=0)
# Out:
# <style type="text/css">
# </style>
# <table id="T_27fb1">
#   <thead>
#     <tr>
#       <th id="T_27fb1_level0_col0" class="col_heading level0 col0" >doc_id</th>
#       <th id="T_27fb1_level0_col1" class="col_heading level0 col1" >APPGE</th>
#       <th id="T_27fb1_level0_col2" class="col_heading level0 col2" >AT</th>
#       <th id="T_27fb1_level0_col3" class="col_heading level0 col3" >AT1</th>
#       <th id="T_27fb1_level0_col4" class="col_heading level0 col4" >BCL</th>
#       <th id="T_27fb1_level0_col5" class="col_heading level0 col5" >CC</th>
#       <th id="T_27fb1_level0_col6" class="col_heading level0 col6" >CCB</th>
#       <th id="T_27fb1_level0_col7" class="col_heading level0 col7" >CS</th>
#       <th id="T_27fb1_level0_col8" class="col_heading level0 col8" >CSA</th>
#       <th id="T_27fb1_level0_col9" class="col_heading level0 col9" >CSN</th>
#       <th id="T_27fb1_level0_col10" class="col_heading level0 col10" >CST</th>
#       <th id="T_27fb1_level0_col11" class="col_heading level0 col11" >CSW</th>
#       <th id="T_27fb1_level0_col12" class="col_heading level0 col12" >DA</th>
#       <th id="T_27fb1_level0_col13" class="col_heading level0 col13" >DA1</th>
#       <th id="T_27fb1_level0_col14" class="col_heading level0 col14" >DA2</th>
#       <th id="T_27fb1_level0_col15" class="col_heading level0 col15" >DAR</th>
#       <th id="T_27fb1_level0_col16" class="col_heading level0 col16" >DAT</th>
#       <th id="T_27fb1_level0_col17" class="col_heading level0 col17" >DB</th>
#       <th id="T_27fb1_level0_col18" class="col_heading level0 col18" >DB2</th>
#       <th id="T_27fb1_level0_col19" class="col_heading level0 col19" >DD</th>
#       <th id="T_27fb1_level0_col20" class="col_heading level0 col20" >DD1</th>
#       <th id="T_27fb1_level0_col21" class="col_heading level0 col21" >DD2</th>
#       <th id="T_27fb1_level0_col22" class="col_heading level0 col22" >DDQ</th>
#       <th id="T_27fb1_level0_col23" class="col_heading level0 col23" >DDQGE</th>
#       <th id="T_27fb1_level0_col24" class="col_heading level0 col24" >DDQV</th>
#       <th id="T_27fb1_level0_col25" class="col_heading level0 col25" >EX</th>
#       <th id="T_27fb1_level0_col26" class="col_heading level0 col26" >FO</th>
#       <th id="T_27fb1_level0_col27" class="col_heading level0 col27" >FW</th>
#       <th id="T_27fb1_level0_col28" class="col_heading level0 col28" >GE</th>
#       <th id="T_27fb1_level0_col29" class="col_heading level0 col29" >IF</th>
#       <th id="T_27fb1_level0_col30" class="col_heading level0 col30" >II</th>
#       <th id="T_27fb1_level0_col31" class="col_heading level0 col31" >IO</th>
#       <th id="T_27fb1_level0_col32" class="col_heading level0 col32" >IW</th>
#       <th id="T_27fb1_level0_col33" class="col_heading level0 col33" >JJ</th>
#       <th id="T_27fb1_level0_col34" class="col_heading level0 col34" >JJR</th>
#       <th id="T_27fb1_level0_col35" class="col_heading level0 col35" >JJT</th>
#       <th id="T_27fb1_level0_col36" class="col_heading level0 col36" >JK</th>
#       <th id="T_27fb1_level0_col37" class="col_heading level0 col37" >MC</th>
#       <th id="T_27fb1_level0_col38" class="col_heading level0 col38" >MC1</th>
#       <th id="T_27fb1_level0_col39" class="col_heading level0 col39" >MC2</th>
#       <th id="T_27fb1_level0_col40" class="col_heading level0 col40" >MCMC</th>
#       <th id="T_27fb1_level0_col41" class="col_heading level0 col41" >MD</th>
#       <th id="T_27fb1_level0_col42" class="col_heading level0 col42" >MF</th>
#       <th id="T_27fb1_level0_col43" class="col_heading level0 col43" >ND1</th>
#       <th id="T_27fb1_level0_col44" class="col_heading level0 col44" >NN</th>
#       <th id="T_27fb1_level0_col45" class="col_heading level0 col45" >NN1</th>
#       <th id="T_27fb1_level0_col46" class="col_heading level0 col46" >NN2</th>
#       <th id="T_27fb1_level0_col47" class="col_heading level0 col47" >NNA</th>
#       <th id="T_27fb1_level0_col48" class="col_heading level0 col48" >NNL1</th>
#       <th id="T_27fb1_level0_col49" class="col_heading level0 col49" >NNO</th>
#       <th id="T_27fb1_level0_col50" class="col_heading level0 col50" >NNO2</th>
#       <th id="T_27fb1_level0_col51" class="col_heading level0 col51" >NNT1</th>
#       <th id="T_27fb1_level0_col52" class="col_heading level0 col52" >NNT2</th>
#       <th id="T_27fb1_level0_col53" class="col_heading level0 col53" >NNU</th>
#       <th id="T_27fb1_level0_col54" class="col_heading level0 col54" >NNU1</th>
#       <th id="T_27fb1_level0_col55" class="col_heading level0 col55" >NNU2</th>
#       <th id="T_27fb1_level0_col56" class="col_heading level0 col56" >NP</th>
#       <th id="T_27fb1_level0_col57" class="col_heading level0 col57" >NP1</th>
#       <th id="T_27fb1_level0_col58" class="col_heading level0 col58" >NP2</th>
#       <th id="T_27fb1_level0_col59" class="col_heading level0 col59" >NPD1</th>
#       <th id="T_27fb1_level0_col60" class="col_heading level0 col60" >NPM1</th>
#       <th id="T_27fb1_level0_col61" class="col_heading level0 col61" >PN</th>
#       <th id="T_27fb1_level0_col62" class="col_heading level0 col62" >PN1</th>
#       <th id="T_27fb1_level0_col63" class="col_heading level0 col63" >PNQO</th>
#       <th id="T_27fb1_level0_col64" class="col_heading level0 col64" >PNQS</th>
#       <th id="T_27fb1_level0_col65" class="col_heading level0 col65" >PNQV</th>
#       <th id="T_27fb1_level0_col66" class="col_heading level0 col66" >PPGE</th>
#       <th id="T_27fb1_level0_col67" class="col_heading level0 col67" >PPH1</th>
#       <th id="T_27fb1_level0_col68" class="col_heading level0 col68" >PPHO1</th>
#       <th id="T_27fb1_level0_col69" class="col_heading level0 col69" >PPHO2</th>
#       <th id="T_27fb1_level0_col70" class="col_heading level0 col70" >PPHS1</th>
#       <th id="T_27fb1_level0_col71" class="col_heading level0 col71" >PPHS2</th>
#       <th id="T_27fb1_level0_col72" class="col_heading level0 col72" >PPIO1</th>
#       <th id="T_27fb1_level0_col73" class="col_heading level0 col73" >PPIO2</th>
#       <th id="T_27fb1_level0_col74" class="col_heading level0 col74" >PPIS1</th>
#       <th id="T_27fb1_level0_col75" class="col_heading level0 col75" >PPIS2</th>
#       <th id="T_27fb1_level0_col76" class="col_heading level0 col76" >PPX1</th>
#       <th id="T_27fb1_level0_col77" class="col_heading level0 col77" >PPX2</th>
#       <th id="T_27fb1_level0_col78" class="col_heading level0 col78" >PPY</th>
#       <th id="T_27fb1_level0_col79" class="col_heading level0 col79" >RA</th>
#       <th id="T_27fb1_level0_col80" class="col_heading level0 col80" >REX</th>
#       <th id="T_27fb1_level0_col81" class="col_heading level0 col81" >RG</th>
#       <th id="T_27fb1_level0_col82" class="col_heading level0 col82" >RGQ</th>
#       <th id="T_27fb1_level0_col83" class="col_heading level0 col83" >RGQV</th>
#       <th id="T_27fb1_level0_col84" class="col_heading level0 col84" >RGR</th>
#       <th id="T_27fb1_level0_col85" class="col_heading level0 col85" >RGT</th>
#       <th id="T_27fb1_level0_col86" class="col_heading level0 col86" >RL</th>
#       <th id="T_27fb1_level0_col87" class="col_heading level0 col87" >RP</th>
#       <th id="T_27fb1_level0_col88" class="col_heading level0 col88" >RPK</th>
#       <th id="T_27fb1_level0_col89" class="col_heading level0 col89" >RR</th>
#       <th id="T_27fb1_level0_col90" class="col_heading level0 col90" >RRQ</th>
#       <th id="T_27fb1_level0_col91" class="col_heading level0 col91" >RRQV</th>
#       <th id="T_27fb1_level0_col92" class="col_heading level0 col92" >RRR</th>
#       <th id="T_27fb1_level0_col93" class="col_heading level0 col93" >RRT</th>
#       <th id="T_27fb1_level0_col94" class="col_heading level0 col94" >RT</th>
#       <th id="T_27fb1_level0_col95" class="col_heading level0 col95" >TO</th>
#       <th id="T_27fb1_level0_col96" class="col_heading level0 col96" >UH</th>
#       <th id="T_27fb1_level0_col97" class="col_heading level0 col97" >VB0</th>
#       <th id="T_27fb1_level0_col98" class="col_heading level0 col98" >VBDR</th>
#       <th id="T_27fb1_level0_col99" class="col_heading level0 col99" >VBDZ</th>
#       <th id="T_27fb1_level0_col1

# %% [markdown]
# ### 4.4.2 DS DTM

# %%
dtm_DS = tags_dtm(
    tok=tp,
    count_by='ds'
)
dtm_DS.head(10).style.hide(axis='index').format(precision=0)
# Out:
# <style type="text/css">
# </style>
# <table id="T_3b04f">
#   <thead>
#     <tr>
#       <th id="T_3b04f_level0_col0" class="col_heading level0 col0" >doc_id</th>
#       <th id="T_3b04f_level0_col1" class="col_heading level0 col1" >AcademicTerms</th>
#       <th id="T_3b04f_level0_col2" class="col_heading level0 col2" >AcademicWritingMoves</th>
#       <th id="T_3b04f_level0_col3" class="col_heading level0 col3" >Character</th>
#       <th id="T_3b04f_level0_col4" class="col_heading level0 col4" >Citation</th>
#       <th id="T_3b04f_level0_col5" class="col_heading level0 col5" >CitationAuthority</th>
#       <th id="T_3b04f_level0_col6" class="col_heading level0 col6" >CitationHedged</th>
#       <th id="T_3b04f_level0_col7" class="col_heading level0 col7" >ConfidenceHedged</th>
#       <th id="T_3b04f_level0_col8" class="col_heading level0 col8" >ConfidenceHigh</th>
#       <th id="T_3b04f_level0_col9" class="col_heading level0 col9" >ConfidenceLow</th>
#       <th id="T_3b04f_level0_col10" class="col_heading level0 col10" >Contingent</th>
#       <th id="T_3b04f_level0_col11" class="col_heading level0 col11" >Description</th>
#       <th id="T_3b04f_level0_col12" class="col_heading level0 col12" >Facilitate</th>
#       <th id="T_3b04f_level0_col13" class="col_heading level0 col13" >FirstPerson</th>
#       <th id="T_3b04f_level0_col14" class="col_heading level0 col14" >ForceStressed</th>
#       <th id="T_3b04f_level0_col15" class="col_heading level0 col15" >Future</th>
#       <th id="T_3b04f_level0_col16" class="col_heading level0 col16" >InformationChange</th>
#       <th id="T_3b04f_level0_col17" class="col_heading level0 col17" >InformationChangeNegative</th>
#       <th id="T_3b04f_level0_col18" class="col_heading level0 col18" >InformationChangePositive</th>
#       <th id="T_3b04f_level0_col19" class="col_heading level0 col19" >InformationExposition</th>
#       <th id="T_3b04f_level0_col20" class="col_heading level0 col20" >InformationPlace</th>
#       <th id="T_3b04f_level0_col21" class="col_heading level0 col21" >InformationReportVerbs</th>
#       <th id="T_3b04f_level0_col22" class="col_heading level0 col22" >InformationStates</th>
#       <th id="T_3b04f_level0_col23" class="col_heading level0 col23" >InformationTopics</th>
#       <th id="T_3b04f_level0_col24" class="col_heading level0 col24" >Inquiry</th>
#       <th id="T_3b04f_level0_col25" class="col_heading level0 col25" >Interactive</th>
#       <th id="T_3b04f_level0_col26" class="col_heading level0 col26" >MetadiscourseCohesive</th>
#       <th id="T_3b04f_level0_col27" class="col_heading level0 col27" >MetadiscourseInteractive</th>
#       <th id="T_3b04f_level0_col28" class="col_heading level0 col28" >Narrative</th>
#       <th id="T_3b04f_level0_col29" class="col_heading level0 col29" >Negative</th>
#       <th id="T_3b04f_level0_col30" class="col_heading level0 col30" >Positive</th>
#       <th id="T_3b04f_level0_col31" class="col_heading level0 col31" >PublicTerms</th>
#       <th id="T_3b04f_level0_col32" class="col_heading level0 col32" >Reasoning</th>
#       <th id="T_3b04f_level0_col33" class="col_heading level0 col33" >Responsibility</th>
#       <th id="T_3b04f_level0_col34" class="col_heading level0 col34" >Strategic</th>
#       <th id="T_3b04f_level0_col35" class="col_heading level0 col35" >Uncertainty</th>
#       <th id="T_3b04f_level0_col36" class="col_heading level0 col36" >Untagged</th>
#       <th id="T_3b04f_level0_col37" class="col_heading level0 col37" >Updates</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3b04f_row0_col0" class="data row0 col0" >kaggle_LAST_THIRD_CELLS_votes_notebooks</td>
#       <td id="T_3b04f_row0_col1" class="data row0 col1" >7949</td>
#       <td id="T_3b04f_row0_col2" class="data row0 col2" >575</td>
#       <td id="T_3b04f_row0_col3" class="data row0 col3" >3542</td>
#       <td id="T_3b04f_row0_col4" class="data row0 col4" >198</td>
#       <td id="T_3b04f_row0_col5" class="data row0 col5" >115</td>
#       <td id="T_3b04f_row0_col6" class="data row0 col6" >21</td>
#       <td id="T_3b04f_row0_col7" class="data row0 col7" >1009</td>
#       <td id="T_3b04f_row0_col8" class="data row0 col8" >483</td>
#       <td id="T_3b04f_row0_col9" class="data row0 col9" >5</td>
#       <td id="T_3b04f_row0_col10" class="data row0 col10" >615</td>
#       <td id="T_3b04f_row0_col11" class="data row0 col11" >6213</td>
#       <td id="T_3b04f_row0_col12" class="data row0 col12" >261</td>
#       <td id="T_3b04f_row0_col13" class="data row0 col13" >497</td>
#       <td id="T_3b04f_row0_col14" class="data row0 col14" >1809</td>
#       <td id="T_3b04f_row0_col15" class="data row0 col15" >552</td>
#       <td id="T_3b04f_row0_col16" class="data row0 col16" >810</td>
#       <td id="T_3b04f_row0_col17" class="data row0 col17" >40</td>
#       <td id="T_3b04f_row0_col18" class="data row0 col18" >196</td>
#       <td id="T_3b04f_row0_col19" class="data row0 col19" >5284</td>
#       <td id="T_3b04f_row0_col20" class="data row0 col20" >207</td>
#       <td id="T_3b04f_row0_col21" class="data row0 col21" >833</td>
#       <td id="T_3b04f_row0_col22" class="data row0 col22" >1446</td>
#       <td id="T_3b04f_row0_col23" class="data row0 col23" >2666</td>
#       <td id="T_3b04f_row0_col24" class="data row0 col24" >876</td>
#       <td id="T_3b04f_row0_col25" class="data row0 col25" >1477</td>
#       <td id="T_3b04f_row0_col26" class="data row0 col26" >1546</td>
#       <td id="T_3b04f_row0_col27" class="data row0 col27" >575</td>
#       <td id="T_3b04f_row0_col28" class="data row0 col28" >3653</td>
#       <td id="T_3b04f_row0_col29" class="data row0 col29" >1856</td>
#       <td id="T_3b04f_row0_col30" class="data row0 col30" >1661</td>
#       <td id="T_3b04f_row0_col31" class="data row0 col31" >541</td>
#       <td id="T_3b04f_row0_col32" class="data row0 col32" >1402</td>
#       <td id="T_3b04f_row0_col33" class="data row0 col33" >82</td>
#       <td id="T_3b04f_row0_col34" class="data row0 col34" >1347</td>
#       <td id="T_3b04f_row0_col35" class="data row0 col35" >80</td>
#       <td id="T_3b04f_row0_col36" class="data row0 col36" >29230</td>
#       <td id="T_3b04f_row0_col37" class="data row0 col37" >213</td>
#     </tr>
#     <tr>
#       <td id="T_3b04f_row1_col0" class="data row1 col0" >kaggle_SECOND_THIRD_CELLS_votes_notebooks</td>
#       <td id="T_3b04f_row1_col1" class="data row1 col1" >8701</td>
#       <td id="T_3b04f_row1_col2" class="data row1 col2" >573</td>
#       <td id="T_3b04f_row1_col3" class="data row1 col3" >3773</td>
#       <td id="T_3b04f_row1_col4" class="data row1 col4" >225</td>
#       <td id="T_3b04f_row1_col5" class="data row1 col5" >120</td>
#       <td id="T_3b04f_row1_col6" class="data row1 col6" >13</td>
#       <td id="T_3b04f_row1_col7" class="data row1 col7" >1234</td>
#       <td id="T_3b04f_row1_col8" class="data row1 col8" >581</td>
#       <td id="T_3b04f_row1_col9" class="data row1 col9" >4</td>
#       <td id="T_3b04f_row1_col10" class="data row1 col10" >598</td>
#       <td id="T_3b04f_row1_col11" class="data row1 col11" >6711</td>
#       <td id="T_3b04f_row1_col12" class="data row1 col12" >320</td>
#       <td id="T_3b04f_row1_col13" class="data row1 col13" >505</td>
#       <td id="T_3b04f_row1_col14" class="data row1 col14" >1888</td>
#       <td id="T_3b04f_row1_col15" class="data row1 col15" >593</td>
#       <td id="T_3b04f_row1_col16" class="data row1 col16" >910</td>
#       <td id="T_3b04f_row1_col17" class="data row1 col17" >39</td>
#       <td id="T_3b04f_row1_col18" class="data row1 col18" >146</td>
#       <td id="T_3b04f_row1_col19" class="data row1 col19" >6246</td>
#       <td id="T_3b04f_row1_col20" class="data row1 col20" >425</td>
#       <td id="T_3b04f_row1_col21" class="data row1 col21" >828</td>
#       <td id="T_3b04f_row1_col22" class="data row1 col22" >1696</td>
#       <td id="T_3b04f_row1_col23" class="data row1 col23" >2745</td>
#       <td id="T_3b04f_row1_col24" class="data row1 col24" >1017</td>
#       <td id="T_3b04f_row1_col25" class="data row1 col25" >1451</td>
#       <td id="T_3b04f_row1_col26" class="data row1 col26" >1762</td>
#       <td id="T_3b04

# %% [markdown]
# ### 4.4.3 Count frequencies, then give weight (importance) to document-term counts
#
# We can use the tmtoolkit library to create weighted counts (using its `tf_proportions` function), `tf-idf` values (using the tfidf function), or other types of data structures.

# %%
from temptmtoolkit.bow.bow_stats import tf_proportions, tfidf

# %% [markdown]
# #### 4.4.3.1 Count the document term frequencies (raw counts)

# %%
dtm_POS.set_index('doc_id', inplace=True)
dtm_POS.head(10).style.format(precision=0)
# Out:
# <style type="text/css">
# </style>
# <table id="T_b08f7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b08f7_level0_col0" class="col_heading level0 col0" >APPGE</th>
#       <th id="T_b08f7_level0_col1" class="col_heading level0 col1" >AT</th>
#       <th id="T_b08f7_level0_col2" class="col_heading level0 col2" >AT1</th>
#       <th id="T_b08f7_level0_col3" class="col_heading level0 col3" >BCL</th>
#       <th id="T_b08f7_level0_col4" class="col_heading level0 col4" >CC</th>
#       <th id="T_b08f7_level0_col5" class="col_heading level0 col5" >CCB</th>
#       <th id="T_b08f7_level0_col6" class="col_heading level0 col6" >CS</th>
#       <th id="T_b08f7_level0_col7" class="col_heading level0 col7" >CSA</th>
#       <th id="T_b08f7_level0_col8" class="col_heading level0 col8" >CSN</th>
#       <th id="T_b08f7_level0_col9" class="col_heading level0 col9" >CST</th>
#       <th id="T_b08f7_level0_col10" class="col_heading level0 col10" >CSW</th>
#       <th id="T_b08f7_level0_col11" class="col_heading level0 col11" >DA</th>
#       <th id="T_b08f7_level0_col12" class="col_heading level0 col12" >DA1</th>
#       <th id="T_b08f7_level0_col13" class="col_heading level0 col13" >DA2</th>
#       <th id="T_b08f7_level0_col14" class="col_heading level0 col14" >DAR</th>
#       <th id="T_b08f7_level0_col15" class="col_heading level0 col15" >DAT</th>
#       <th id="T_b08f7_level0_col16" class="col_heading level0 col16" >DB</th>
#       <th id="T_b08f7_level0_col17" class="col_heading level0 col17" >DB2</th>
#       <th id="T_b08f7_level0_col18" class="col_heading level0 col18" >DD</th>
#       <th id="T_b08f7_level0_col19" class="col_heading level0 col19" >DD1</th>
#       <th id="T_b08f7_level0_col20" class="col_heading level0 col20" >DD2</th>
#       <th id="T_b08f7_level0_col21" class="col_heading level0 col21" >DDQ</th>
#       <th id="T_b08f7_level0_col22" class="col_heading level0 col22" >DDQGE</th>
#       <th id="T_b08f7_level0_col23" class="col_heading level0 col23" >DDQV</th>
#       <th id="T_b08f7_level0_col24" class="col_heading level0 col24" >EX</th>
#       <th id="T_b08f7_level0_col25" class="col_heading level0 col25" >FO</th>
#       <th id="T_b08f7_level0_col26" class="col_heading level0 col26" >FW</th>
#       <th id="T_b08f7_level0_col27" class="col_heading level0 col27" >GE</th>
#       <th id="T_b08f7_level0_col28" class="col_heading level0 col28" >IF</th>
#       <th id="T_b08f7_level0_col29" class="col_heading level0 col29" >II</th>
#       <th id="T_b08f7_level0_col30" class="col_heading level0 col30" >IO</th>
#       <th id="T_b08f7_level0_col31" class="col_heading level0 col31" >IW</th>
#       <th id="T_b08f7_level0_col32" class="col_heading level0 col32" >JJ</th>
#       <th id="T_b08f7_level0_col33" class="col_heading level0 col33" >JJR</th>
#       <th id="T_b08f7_level0_col34" class="col_heading level0 col34" >JJT</th>
#       <th id="T_b08f7_level0_col35" class="col_heading level0 col35" >JK</th>
#       <th id="T_b08f7_level0_col36" class="col_heading level0 col36" >MC</th>
#       <th id="T_b08f7_level0_col37" class="col_heading level0 col37" >MC1</th>
#       <th id="T_b08f7_level0_col38" class="col_heading level0 col38" >MC2</th>
#       <th id="T_b08f7_level0_col39" class="col_heading level0 col39" >MCMC</th>
#       <th id="T_b08f7_level0_col40" class="col_heading level0 col40" >MD</th>
#       <th id="T_b08f7_level0_col41" class="col_heading level0 col41" >MF</th>
#       <th id="T_b08f7_level0_col42" class="col_heading level0 col42" >ND1</th>
#       <th id="T_b08f7_level0_col43" class="col_heading level0 col43" >NN</th>
#       <th id="T_b08f7_level0_col44" class="col_heading level0 col44" >NN1</th>
#       <th id="T_b08f7_level0_col45" class="col_heading level0 col45" >NN2</th>
#       <th id="T_b08f7_level0_col46" class="col_heading level0 col46" >NNA</th>
#       <th id="T_b08f7_level0_col47" class="col_heading level0 col47" >NNL1</th>
#       <th id="T_b08f7_level0_col48" class="col_heading level0 col48" >NNO</th>
#       <th id="T_b08f7_level0_col49" class="col_heading level0 col49" >NNO2</th>
#       <th id="T_b08f7_level0_col50" class="col_heading level0 col50" >NNT1</th>
#       <th id="T_b08f7_level0_col51" class="col_heading level0 col51" >NNT2</th>
#       <th id="T_b08f7_level0_col52" class="col_heading level0 col52" >NNU</th>
#       <th id="T_b08f7_level0_col53" class="col_heading level0 col53" >NNU1</th>
#       <th id="T_b08f7_level0_col54" class="col_heading level0 col54" >NNU2</th>
#       <th id="T_b08f7_level0_col55" class="col_heading level0 col55" >NP</th>
#       <th id="T_b08f7_level0_col56" class="col_heading level0 col56" >NP1</th>
#       <th id="T_b08f7_level0_col57" class="col_heading level0 col57" >NP2</th>
#       <th id="T_b08f7_level0_col58" class="col_heading level0 col58" >NPD1</th>
#       <th id="T_b08f7_level0_col59" class="col_heading level0 col59" >NPM1</th>
#       <th id="T_b08f7_level0_col60" class="col_heading level0 col60" >PN</th>
#       <th id="T_b08f7_level0_col61" class="col_heading level0 col61" >PN1</th>
#       <th id="T_b08f7_level0_col62" class="col_heading level0 col62" >PNQO</th>
#       <th id="T_b08f7_level0_col63" class="col_heading level0 col63" >PNQS</th>
#       <th id="T_b08f7_level0_col64" class="col_heading level0 col64" >PNQV</th>
#       <th id="T_b08f7_level0_col65" class="col_heading level0 col65" >PPGE</th>
#       <th id="T_b08f7_level0_col66" class="col_heading level0 col66" >PPH1</th>
#       <th id="T_b08f7_level0_col67" class="col_heading level0 col67" >PPHO1</th>
#       <th id="T_b08f7_level0_col68" class="col_heading level0 col68" >PPHO2</th>
#       <th id="T_b08f7_level0_col69" class="col_heading level0 col69" >PPHS1</th>
#       <th id="T_b08f7_level0_col70" class="col_heading level0 col70" >PPHS2</th>
#       <th id="T_b08f7_level0_col71" class="col_heading level0 col71" >PPIO1</th>
#       <th id="T_b08f7_level0_col72" class="col_heading level0 col72" >PPIO2</th>
#       <th id="T_b08f7_level0_col73" class="col_heading level0 col73" >PPIS1</th>
#       <th id="T_b08f7_level0_col74" class="col_heading level0 col74" >PPIS2</th>
#       <th id="T_b08f7_level0_col75" class="col_heading level0 col75" >PPX1</th>
#       <th id="T_b08f7_level0_col76" class="col_heading level0 col76" >PPX2</th>
#       <th id="T_b08f7_level0_col77" class="col_heading level0 col77" >PPY</th>
#       <th id="T_b08f7_level0_col78" class="col_heading level0 col78" >RA</th>
#       <th id="T_b08f7_level0_col79" class="col_heading level0 col79" >REX</th>
#       <th id="T_b08f7_level0_col80" class="col_heading level0 col80" >RG</th>
#       <th id="T_b08f7_level0_col81" class="col_heading level0 col81" >RGQ</th>
#       <th id="T_b08f7_level0_col82" class="col_heading level0 col82" >RGQV</th>
#       <th id="T_b08f7_level0_col83" class="col_heading level0 col83" >RGR</th>
#       <th id="T_b08f7_level0_col84" class="col_heading level0 col84" >RGT</th>
#       <th id="T_b08f7_level0_col85" class="col_heading level0 col85" >RL</th>
#       <th id="T_b08f7_level0_col86" class="col_heading level0 col86" >RP</th>
#       <th id="T_b08f7_level0_col87" class="col_heading level0 col87" >RPK</th>
#       <th id="T_b08f7_level0_col88" class="col_heading level0 col88" >RR</th>
#       <th id="T_b08f7_level0_col89" class="col_heading level0 col89" >RRQ</th>
#       <th id="T_b08f7_level0_col90" class="col_heading level0 col90" >RRQV</th>
#       <th id="T_b08f7_level0_col91" class="col_heading level0 col91" >RRR</th>
#       <th id="T_b08f7_level0_col92" class="col_heading level0 col92" >RRT</th>
#       <th id="T_b08f7_level0_col93" class="col_heading level0 col93" >RT</th>
#       <th id="T_b08f7_level0_col94" class="col_heading level0 col94" >TO</th>
#       <th id="T_b08f7_level0_col95" class="col_heading level0 col95" >UH</th>
#       <th id="T_b08f7_level0_col96" class="col_heading level0 col96" >VB0</th>
#       <th id="T_b08f7_level0_col97" class="col_heading level0 col97" >VBDR</th>
#       <th id="T_b08f7_level0_col98" class="col_heading level0 col98" >VBDZ</th>
#       <th id="T_b08f7_level0_col99" class="col_heading level0 col99" >V

# %%
dtm_DS.set_index('doc_id', inplace=True)
dtm_DS.head(10).style.format(precision=0)
# Out:
# <style type="text/css">
# </style>
# <table id="T_8b65b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8b65b_level0_col0" class="col_heading level0 col0" >AcademicTerms</th>
#       <th id="T_8b65b_level0_col1" class="col_heading level0 col1" >AcademicWritingMoves</th>
#       <th id="T_8b65b_level0_col2" class="col_heading level0 col2" >Character</th>
#       <th id="T_8b65b_level0_col3" class="col_heading level0 col3" >Citation</th>
#       <th id="T_8b65b_level0_col4" class="col_heading level0 col4" >CitationAuthority</th>
#       <th id="T_8b65b_level0_col5" class="col_heading level0 col5" >CitationHedged</th>
#       <th id="T_8b65b_level0_col6" class="col_heading level0 col6" >ConfidenceHedged</th>
#       <th id="T_8b65b_level0_col7" class="col_heading level0 col7" >ConfidenceHigh</th>
#       <th id="T_8b65b_level0_col8" class="col_heading level0 col8" >ConfidenceLow</th>
#       <th id="T_8b65b_level0_col9" class="col_heading level0 col9" >Contingent</th>
#       <th id="T_8b65b_level0_col10" class="col_heading level0 col10" >Description</th>
#       <th id="T_8b65b_level0_col11" class="col_heading level0 col11" >Facilitate</th>
#       <th id="T_8b65b_level0_col12" class="col_heading level0 col12" >FirstPerson</th>
#       <th id="T_8b65b_level0_col13" class="col_heading level0 col13" >ForceStressed</th>
#       <th id="T_8b65b_level0_col14" class="col_heading level0 col14" >Future</th>
#       <th id="T_8b65b_level0_col15" class="col_heading level0 col15" >InformationChange</th>
#       <th id="T_8b65b_level0_col16" class="col_heading level0 col16" >InformationChangeNegative</th>
#       <th id="T_8b65b_level0_col17" class="col_heading level0 col17" >InformationChangePositive</th>
#       <th id="T_8b65b_level0_col18" class="col_heading level0 col18" >InformationExposition</th>
#       <th id="T_8b65b_level0_col19" class="col_heading level0 col19" >InformationPlace</th>
#       <th id="T_8b65b_level0_col20" class="col_heading level0 col20" >InformationReportVerbs</th>
#       <th id="T_8b65b_level0_col21" class="col_heading level0 col21" >InformationStates</th>
#       <th id="T_8b65b_level0_col22" class="col_heading level0 col22" >InformationTopics</th>
#       <th id="T_8b65b_level0_col23" class="col_heading level0 col23" >Inquiry</th>
#       <th id="T_8b65b_level0_col24" class="col_heading level0 col24" >Interactive</th>
#       <th id="T_8b65b_level0_col25" class="col_heading level0 col25" >MetadiscourseCohesive</th>
#       <th id="T_8b65b_level0_col26" class="col_heading level0 col26" >MetadiscourseInteractive</th>
#       <th id="T_8b65b_level0_col27" class="col_heading level0 col27" >Narrative</th>
#       <th id="T_8b65b_level0_col28" class="col_heading level0 col28" >Negative</th>
#       <th id="T_8b65b_level0_col29" class="col_heading level0 col29" >Positive</th>
#       <th id="T_8b65b_level0_col30" class="col_heading level0 col30" >PublicTerms</th>
#       <th id="T_8b65b_level0_col31" class="col_heading level0 col31" >Reasoning</th>
#       <th id="T_8b65b_level0_col32" class="col_heading level0 col32" >Responsibility</th>
#       <th id="T_8b65b_level0_col33" class="col_heading level0 col33" >Strategic</th>
#       <th id="T_8b65b_level0_col34" class="col_heading level0 col34" >Uncertainty</th>
#       <th id="T_8b65b_level0_col35" class="col_heading level0 col35" >Untagged</th>
#       <th id="T_8b65b_level0_col36" class="col_heading level0 col36" >Updates</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >doc_id</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#       <th class="blank col22" >&nbsp;</th>
#       <th class="blank col23" >&nbsp;</th>
#       <th class="blank col24" >&nbsp;</th>
#       <th class="blank col25" >&nbsp;</th>
#       <th class="blank col26" >&nbsp;</th>
#       <th class="blank col27" >&nbsp;</th>
#       <th class="blank col28" >&nbsp;</th>
#       <th class="blank col29" >&nbsp;</th>
#       <th class="blank col30" >&nbsp;</th>
#       <th class="blank col31" >&nbsp;</th>
#       <th class="blank col32" >&nbsp;</th>
#       <th class="blank col33" >&nbsp;</th>
#       <th class="blank col34" >&nbsp;</th>
#       <th class="blank col35" >&nbsp;</th>
#       <th class="blank col36" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8b65b_level0_row0" class="row_heading level0 row0" >kaggle_LAST_THIRD_CELLS_votes_notebooks</th>
#       <td id="T_8b65b_row0_col0" class="data row0 col0" >7949</td>
#       <td id="T_8b65b_row0_col1" class="data row0 col1" >575</td>
#       <td id="T_8b65b_row0_col2" class="data row0 col2" >3542</td>
#       <td id="T_8b65b_row0_col3" class="data row0 col3" >198</td>
#       <td id="T_8b65b_row0_col4" class="data row0 col4" >115</td>
#       <td id="T_8b65b_row0_col5" class="data row0 col5" >21</td>
#       <td id="T_8b65b_row0_col6" class="data row0 col6" >1009</td>
#       <td id="T_8b65b_row0_col7" class="data row0 col7" >483</td>
#       <td id="T_8b65b_row0_col8" class="data row0 col8" >5</td>
#       <td id="T_8b65b_row0_col9" class="data row0 col9" >615</td>
#       <td id="T_8b65b_row0_col10" class="data row0 col10" >6213</td>
#       <td id="T_8b65b_row0_col11" class="data row0 col11" >261</td>
#       <td id="T_8b65b_row0_col12" class="data row0 col12" >497</td>
#       <td id="T_8b65b_row0_col13" class="data row0 col13" >1809</td>
#       <td id="T_8b65b_row0_col14" class="data row0 col14" >552</td>
#       <td id="T_8b65b_row0_col15" class="data row0 col15" >810</td>
#       <td id="T_8b65b_row0_col16" class="data row0 col16" >40</td>
#       <td id="T_8b65b_row0_col17" class="data row0 col17" >196</td>
#       <td id="T_8b65b_row0_col18" class="data row0 col18" >5284</td>
#       <td id="T_8b65b_row0_col19" class="data row0 col19" >207</td>
#       <td id="T_8b65b_row0_col20" class="data row0 col20" >833</td>
#       <td id="T_8b65b_row0_col21" class="data row0 col21" >1446</td>
#       <td id="T_8b65b_row0_col22" class="data row0 col22" >2666</td>
#       <td id="T_8b65b_row0_col23" class="data row0 col23" >876</td>
#       <td id="T_8b65b_row0_col24" class="data row0 col24" >1477</td>
#       <td id="T_8b65b_row0_col25" class="data row0 col25" >1546</td>
#       <td id="T_8b65b_row0_col26" class="data row0 col26" >575</td>
#       <td id="T_8b65b_row0_col27" class="data row0 col27" >3653</td>
#       <td id="T_8b65b_row0_col28" class="data row0 col28" >1856</td>
#       <td id="T_8b65b_row0_col29" class="data row0 col29" >1661</td>
#       <td id="T_8b65b_row0_col30" class="data row0 col30" >541</td>
#       <td id="T_8b65b_row0_col31" class="data row0 col31" >1402</td>
#       <td id="T_8b65b_row0_col32" class="data row0 col32" >82</td>
#       <td id="T_8b65b_row0_col33" class="data row0 col33" >1347</td>
#       <td id="T_8b65b_row0_col34" class="data row0 col34" >80</td>
#       <td id="T_8b65b_row0_col35" class="data row0 col35" >29230</td>
#       <td id="T_8b65b_row0_col36" class="data row0 col36" >213</td>
#     </tr>
#     <tr>
#       <th id="T_8b65b_level0_row1" class="row_heading level0 row1" >kaggle_SECOND_THIRD_CELLS_votes_notebooks</th>
#       <td id="T_8b65b_row1_col0" class="data row1 col0" >8701</td>
#       <td id="T_8b65b_row1_col1" class="data row1 col1" >573</td>
#       <td id=

# %% [markdown]
# #### 4.4.3.2 Weigh the document-terms by proportions
#
# Simply take the percentage of the frequencies across the sum across the corpus, e.g., AT () below comes out to roughly 6% of the corpus across the documents.

# %%
tf_proportions(dtm_POS).head(10)
# Out:
#                                               APPGE        AT       AT1  \
# doc_id
# kaggle_LAST_THIRD_CELLS_votes_notebooks    0.005298  0.060252  0.022153
# kaggle_SECOND_THIRD_CELLS_votes_notebooks  0.006363  0.062831  0.022562
# kaggle_FIRST_THIRD_CELLS_notebooks         0.006683  0.062287  0.022563
#
#                                                 BCL        CC       CCB  \
# doc_id
# kaggle_LAST_THIRD_CELLS_votes_notebooks    0.000320  0.024342  0.002959
# kaggle_SECOND_THIRD_CELLS_votes_notebooks  0.000288  0.025278  0.002706
# kaggle_FIRST_THIRD_CELLS_notebooks         0.000397  0.025773  0.002567
#
#                                                  CS       CSA       CSN  \
# doc_id
# kaggle_LAST_THIRD_CELLS_votes_notebooks    0.008769  0.003632  0.002692
# kaggle_SECOND_THIRD_CELLS_votes_notebooks  0.008023  0.003522  0.002726
# kaggle_FIRST_THIRD_CELLS_notebooks         0.008827  0.003082  0.002476
#
#                                                 CST  ...       VVD       VVG  \
# doc_id                                               ...
# kaggle_LAST_THIRD_CELLS_votes_notebooks    0.009378  ...  0.005629  0.017068
# kaggle_SECOND_THIRD_CELLS_votes_notebooks  0.009347  ...  0.006296  0.015365
# kaggle_FIRST_THIRD_CELLS_notebooks         0.008564  ...  0.005574  0.017831
#
#                                                VVGK       VVI       VVN  \
# doc_id
# kaggle_LAST_THIRD_CELLS_votes_notebooks    0.000459  0.028957  0.017677
# kaggle_SECOND_THIRD_CELLS_votes_notebooks  0.000173  0.029299  0.017111
# kaggle_FIRST_THIRD_CELLS_notebooks         0.000343  0.030527  0.017434
#
#                                                VVNK       VVZ        XX  \
# doc_id
# kaggle_LAST_THIRD_CELLS_votes_notebooks    0.000000  0.012091  0.005981
# kaggle_SECOND_THIRD_CELLS_votes_notebooks  0.000000  0.011699  0.006248
# kaggle_FIRST_THIRD_CELLS_notebooks         0.000005  0.011496  0.005032
#
#                                                 ZZ1       ZZ2
# doc_id
# kaggle_LAST_THIRD_CELLS_votes_notebooks    0.008257  0.000000
# kaggle_SECOND_THIRD_CELLS_votes_notebooks  0.006871  0.000010
# kaggle_FIRST_THIRD_CELLS_notebooks         0.006828  0.000011
#
# [3 rows x 130 columns]

# %%
tf_proportions(dtm_DS).head(10)
# Out:
#                                            AcademicTerms  \
# doc_id
# kaggle_LAST_THIRD_CELLS_votes_notebooks         0.099530
# kaggle_SECOND_THIRD_CELLS_votes_notebooks       0.097932
# kaggle_FIRST_THIRD_CELLS_notebooks              0.098136
#
#                                            AcademicWritingMoves  Character  \
# doc_id
# kaggle_LAST_THIRD_CELLS_votes_notebooks                0.007200   0.044350
# kaggle_SECOND_THIRD_CELLS_votes_notebooks              0.006449   0.042466
# kaggle_FIRST_THIRD_CELLS_notebooks                     0.008644   0.040035
#
#                                            Citation  CitationAuthority  \
# doc_id
# kaggle_LAST_THIRD_CELLS_votes_notebooks    0.002479           0.001440
# kaggle_SECOND_THIRD_CELLS_votes_notebooks  0.002532           0.001351
# kaggle_FIRST_THIRD_CELLS_notebooks         0.002329           0.001193
#
#                                            CitationHedged  ConfidenceHedged  \
# doc_id
# kaggle_LAST_THIRD_CELLS_votes_notebooks          0.000263          0.012634
# kaggle_SECOND_THIRD_CELLS_votes_notebooks        0.000146          0.013889
# kaggle_FIRST_THIRD_CELLS_notebooks               0.000094          0.011757
#
#                                            ConfidenceHigh  ConfidenceLow  \
# doc_id
# kaggle_LAST_THIRD_CELLS_votes_notebooks          0.006048       0.000063
# kaggle_SECOND_THIRD_CELLS_votes_notebooks        0.006539       0.000045
# kaggle_FIRST_THIRD_CELLS_notebooks               0.006239       0.000082
#
#                                            Contingent  ...  Narrative  \
# doc_id                                                 ...
# kaggle_LAST_THIRD_CELLS_votes_notebooks      0.007700  ...   0.045740
# kaggle_SECOND_THIRD_CELLS_votes_notebooks    0.006731  ...   0.047948
# kaggle_FIRST_THIRD_CELLS_notebooks           0.006252  ...   0.049771
#
#                                            Negative  Positive  PublicTerms  \
# doc_id
# kaggle_LAST_THIRD_CELLS_votes_notebooks    0.023239  0.020798     0.006774
# kaggle_SECOND_THIRD_CELLS_votes_notebooks  0.021982  0.020473     0.006382
# kaggle_FIRST_THIRD_CELLS_notebooks         0.020545  0.020834     0.008706
#
#                                            Reasoning  Responsibility  \
# doc_id
# kaggle_LAST_THIRD_CELLS_votes_notebooks     0.017555        0.001027
# kaggle_SECOND_THIRD_CELLS_votes_notebooks   0.017637        0.000754
# kaggle_FIRST_THIRD_CELLS_notebooks          0.017626        0.001067
#
#                                            Strategic  Uncertainty  Untagged  \
# doc_id
# kaggle_LAST_THIRD_CELLS_votes_notebooks     0.016866     0.001002  0.365993
# kaggle_SECOND_THIRD_CELLS_votes_notebooks   0.015802     0.001418  0.373586
# kaggle_FIRST_THIRD_CELLS_notebooks          0.017036     0.001174  0.373984
#
#                                             Updates
# doc_id
# kaggle_LAST_THIRD_CELLS_votes_notebooks    0.002667
# kaggle_SECOND_THIRD_CELLS_votes_notebooks  0.002566
# kaggle_FIRST_THIRD_CELLS_notebooks         0.002869
#
# [3 rows x 37 columns]

# %% [markdown]
# #### 4.4.3.3 Weigh document terms by Term Frequencies in relation to Inverse Document Frequency (TF-IDF)

# %% [markdown]
# What's TF-IDF? It solves the raw-count problem, where all terms are treated equally. For instance, we would expect a corpus about pets to include high frequencies of terms like the nouns of pets: *cat*, *dog*, etc. Those raw counts aren't necessarily helpful in many cases, so one way to weigh the importance of terms to derive more targeted meaning from the corpus is by calculating either TF, IDF (Inverse Document Frequency), or TF-IDF.
#
# - TF: Relative frequency of a term within document by taking the sum of the term and dividing it by the sum total of all words in the document.
# - IDF: Calculation that diminishes the weight of terms that occur very frequently in the document set and increases the weight of terms that occur rarely. Hence, the IDF of a rare term is high, whereas the IDF of a frequent term is likely to be low.
#
# TF-IDF is the composite measure of TF and IDF. The tf-idf weighting scheme considers each document in a corpus as a vector, so it assigns to term $t$ a weight in document $d$. The end result? Each term can be considered in the following ways:
#
# 1. highest when $t$ occurs many times within a small number of documents (thus lending high discriminating power to those documents);
# 2. lower when the term occurs fewer times in a document, or occurs in many documents (thus offering a less pronounced relevance signal);
# 3. lowest when the term occurs in virtually all documents.
#
# <p style="background-color:#FFCCCB;color:black;margin:1rem;padding:1rem;font-size:0.9rem"><strong>NOTE</strong>: IDF should be based on a decently large corpora and should be representative of texts you would be using to extract keywords. Several articles on the web compute the IDF using only a handful of documents, so just be aware of this requirement.<br><br>To understand why IDF should be based on a fairly large collection, please read this <a href="./readings/IDF-explainer.pdf" target"_blank" rel="noopenner noreferrer">page from Standford's IR book</a> (<a href="https://nlp.stanford.edu/IR-book/html/htmledition/inverse-document-frequency-1.html" target"_blank" rel="noopenner noreferrer">original src</a>).</p>
#
# **Factoid**: Approximately 83% of digital libraries use text-based recommender systems that employ TF-IDF. (See Breitinger, Corinna; Gipp, Bela; Langer, Stefan (2015). Research-paper recommender systems: A literature survey. *International Journal on Digital Libraries*, 17(4), 305–338. doi:10.1007/s00799-015-0156-0.)

# %%
tfidf(dtm_POS).head(10)
# Out:
#                                               APPGE        AT       AT1  \
# doc_id
# kaggle_LAST_THIRD_CELLS_votes_notebooks    0.002965  0.033718  0.012397
# kaggle_SECOND_THIRD_CELLS_votes_notebooks  0.003561  0.035161  0.012626
# kaggle_FIRST_THIRD_CELLS_notebooks         0.003740  0.034857  0.012627
#
#                                                 BCL        CC       CCB  \
# doc_id
# kaggle_LAST_THIRD_CELLS_votes_notebooks    0.000179  0.013622  0.001656
# kaggle_SECOND_THIRD_CELLS_votes_notebooks  0.000161  0.014146  0.001515
# kaggle_FIRST_THIRD_CELLS_notebooks         0.000222  0.014423  0.001437
#
#                                                  CS       CSA       CSN  \
# doc_id
# kaggle_LAST_THIRD_CELLS_votes_notebooks    0.004907  0.002032  0.001506
# kaggle_SECOND_THIRD_CELLS_votes_notebooks  0.004490  0.001971  0.001525
# kaggle_FIRST_THIRD_CELLS_notebooks         0.004940  0.001725  0.001386
#
#                                                 CST  ...       VVD       VVG  \
# doc_id                                               ...
# kaggle_LAST_THIRD_CELLS_votes_notebooks    0.005248  ...  0.003150  0.009552
# kaggle_SECOND_THIRD_CELLS_votes_notebooks  0.005231  ...  0.003523  0.008598
# kaggle_FIRST_THIRD_CELLS_notebooks         0.004793  ...  0.003119  0.009978
#
#                                                VVGK       VVI       VVN  \
# doc_id
# kaggle_LAST_THIRD_CELLS_votes_notebooks    0.000257  0.016205  0.009892
# kaggle_SECOND_THIRD_CELLS_votes_notebooks  0.000097  0.016396  0.009576
# kaggle_FIRST_THIRD_CELLS_notebooks         0.000192  0.017083  0.009756
#
#                                                VVNK       VVZ        XX  \
# doc_id
# kaggle_LAST_THIRD_CELLS_votes_notebooks    0.000000  0.006766  0.003347
# kaggle_SECOND_THIRD_CELLS_votes_notebooks  0.000000  0.006547  0.003496
# kaggle_FIRST_THIRD_CELLS_notebooks         0.000005  0.006433  0.002816
#
#                                                 ZZ1       ZZ2
# doc_id
# kaggle_LAST_THIRD_CELLS_votes_notebooks    0.004620  0.000000
# kaggle_SECOND_THIRD_CELLS_votes_notebooks  0.003845  0.000007
# kaggle_FIRST_THIRD_CELLS_notebooks         0.003821  0.000007
#
# [3 rows x 130 columns]

# %%
tfidf(dtm_DS).head(10)
# Out:
#                                            AcademicTerms  \
# doc_id
# kaggle_LAST_THIRD_CELLS_votes_notebooks         0.055699
# kaggle_SECOND_THIRD_CELLS_votes_notebooks       0.054805
# kaggle_FIRST_THIRD_CELLS_notebooks              0.054919
#
#                                            AcademicWritingMoves  Character  \
# doc_id
# kaggle_LAST_THIRD_CELLS_votes_notebooks                0.004029   0.024819
# kaggle_SECOND_THIRD_CELLS_votes_notebooks              0.003609   0.023765
# kaggle_FIRST_THIRD_CELLS_notebooks                     0.004837   0.022404
#
#                                            Citation  CitationAuthority  \
# doc_id
# kaggle_LAST_THIRD_CELLS_votes_notebooks    0.001387           0.000806
# kaggle_SECOND_THIRD_CELLS_votes_notebooks  0.001417           0.000756
# kaggle_FIRST_THIRD_CELLS_notebooks         0.001303           0.000667
#
#                                            CitationHedged  ConfidenceHedged  \
# doc_id
# kaggle_LAST_THIRD_CELLS_votes_notebooks          0.000147          0.007070
# kaggle_SECOND_THIRD_CELLS_votes_notebooks        0.000082          0.007773
# kaggle_FIRST_THIRD_CELLS_notebooks               0.000053          0.006579
#
#                                            ConfidenceHigh  ConfidenceLow  \
# doc_id
# kaggle_LAST_THIRD_CELLS_votes_notebooks          0.003384       0.000035
# kaggle_SECOND_THIRD_CELLS_votes_notebooks        0.003660       0.000025
# kaggle_FIRST_THIRD_CELLS_notebooks               0.003492       0.000046
#
#                                            Contingent  ...  Narrative  \
# doc_id                                                 ...
# kaggle_LAST_THIRD_CELLS_votes_notebooks      0.004309  ...   0.025597
# kaggle_SECOND_THIRD_CELLS_votes_notebooks    0.003767  ...   0.026832
# kaggle_FIRST_THIRD_CELLS_notebooks           0.003499  ...   0.027853
#
#                                            Negative  Positive  PublicTerms  \
# doc_id
# kaggle_LAST_THIRD_CELLS_votes_notebooks    0.013005  0.011639     0.003791
# kaggle_SECOND_THIRD_CELLS_votes_notebooks  0.012301  0.011457     0.003571
# kaggle_FIRST_THIRD_CELLS_notebooks         0.011497  0.011659     0.004872
#
#                                            Reasoning  Responsibility  \
# doc_id
# kaggle_LAST_THIRD_CELLS_votes_notebooks     0.009824        0.000575
# kaggle_SECOND_THIRD_CELLS_votes_notebooks   0.009870        0.000422
# kaggle_FIRST_THIRD_CELLS_notebooks          0.009864        0.000597
#
#                                            Strategic  Uncertainty  Untagged  \
# doc_id
# kaggle_LAST_THIRD_CELLS_votes_notebooks     0.009438     0.000561  0.204815
# kaggle_SECOND_THIRD_CELLS_votes_notebooks   0.008843     0.000794  0.209065
# kaggle_FIRST_THIRD_CELLS_notebooks          0.009534     0.000657  0.209287
#
#                                             Updates
# doc_id
# kaggle_LAST_THIRD_CELLS_votes_notebooks    0.001492
# kaggle_SECOND_THIRD_CELLS_votes_notebooks  0.001436
# kaggle_FIRST_THIRD_CELLS_notebooks         0.001605
#
# [3 rows x 37 columns]

# %% [markdown]
# ## 4.5 Application: Your turn to explore the data

# %% [markdown]
# Go back through the sections above. Explore the words and tags of your own interest. Consider importing a different dataset in the following folder `../data/04-textual-analysis`:
#
# Recall how this notebook uses data that I collected for a study on Kaggle notebooks. This NB uses data that I processed by sampling markdown cells by the position in which it occurs in the NB: the first third, second third, and last third ('../data/04-textual-analysis/kaggle-nb-examples/by-position'). Feel free to import the following other datasets and explore them.
#
# - **Kaggle NBs divded by distribution of their total votes**: `../data/04-textual-analysis/kaggle-nb-examples/by-votes`
# - **Amazon "Video Game" reviews by product ratings (1-5)** ([src](https://cseweb.ucsd.edu/~jmcauley/datasets/amazon_v2/)): `../data/04-textual-analysis/amazon`
# - **Jeopardy questions**: `../data/04-textual-analysis/jeopardy`

# %% [markdown]
# ## 4.6 Other Codebits

# %%
samp = """Who knew language and media were so tangled up with code, data, and computation?!"""
demo_doc = nlp_web_sm(samp)
options = {"compact": True, "distance": 50, "color": "yellow", "bg": "black", "font": "Gill Sans"}
displacy.render(demo_doc, style="dep", options=options)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[52], line 2
#       1 samp = """Who knew language and media were so tangled up with code, data, and computation?!"""
# ----> 2 demo_doc = nlp_web_sm(samp)
#       3 options = {"compact": True, "distance": 50, "color": "yellow", "bg": "black", "font": "Gill Sans"}
#       4 displacy.render(demo_doc, style="dep", options=options)
#
# NameError: name 'nlp_web_sm' is not defined
